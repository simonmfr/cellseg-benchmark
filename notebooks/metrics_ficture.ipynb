# %%
import os
import re

import pandas as pd
import scanpy as sc

from cellseg_benchmark._constants import (
    factor_to_celltype,
    true_cluster,
)
from cellseg_benchmark.metrics import compute_f1

# %% [markdown]
# ## Method 1: use area overlap
# Issue: different coordinate systems between ficture and boundaries, results in very low F1 scores, because small overlap between images

# %%
def rename(colnames):
    """Rename column names."""
    mapper = {}
    for col in colnames:
        mapper[col] = factor_to_celltype[re.split("_", col)[1]]
    return mapper

# %%
# constants
base_path = "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/"

cohort = "aging"
method = "Cellpose_1_nuclei_model"
celltype_name = "cell_type_revised"
obsm_key = "ficture_area"

# read data
data_path = os.path.join(base_path, "analysis", cohort, method)
adata = sc.read_h5ad(os.path.join(data_path, "adatas", "adata_integrated.h5ad.gz"))

# %%
correct_celltypes = {}
for i in factor_to_celltype.keys():
    correct_celltypes[factor_to_celltype[i]] = true_cluster[factor_to_celltype[i]]

# %%
general_stats_dic = {}
for sample in os.listdir(os.path.join(base_path, "samples")):
    if sample.startswith(cohort) and os.path.exists(
        os.path.join(
            base_path, "samples", sample, "results", "Ficture", "general_stats.csv"
        )
    ):
        tmp = pd.read_csv(
            os.path.join(
                base_path, "samples", sample, "results/Ficture/general_stats.csv"
            ),
            index_col=0,
        )
        tmp.rename(columns=factor_to_celltype, inplace=True)
        general_stats_dic[sample] = tmp

# %%
data = {}
for key in general_stats_dic.keys():
    data[key] = adata[adata.obs["sample"] == key].obsm[obsm_key].copy()
    data[key].rename(columns=rename(data[key].columns), inplace=True)
    data[key]["celltype"] = adata[adata.obs["sample"] == key].obs[celltype_name].values

# %%
results = {}
for key in data.keys():
    results[key] = compute_f1(
        data[key],
        general_stats=general_stats_dic[key],
        flavor="all",
        correct_celltypes=correct_celltypes,
        weighted=False,
    )

results = pd.concat(results, names=["sample", "metric"])
results.index = results.index.droplevel(1)

results
# Out:
#                   ABCs  Astrocytes      BAMs  Bergmann       ECs  Ependymal  \
# sample
# aging_s10_r0  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# aging_s10_r1  0.020894    0.000000  0.001701  0.008378  0.014810   0.000000
# aging_s11_r0  0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# aging_s8_r1   0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# aging_s5_r1   0.008864    0.000000  0.000669  0.002889  0.009346   0.000000
# aging_s6_r0   0.008070    0.003639  0.001443  0.001534  0.004746   0.000000
# aging_s7_r2   0.013762    0.002076  0.001960  0.002595  0.009532   0.000000
# aging_s10_r2  0.005470    0.041534  0.000507  0.004248  0.023400   0.000064
# aging_s11_r1  0.012950    0.016033  0.002863  0.007802  0.008555   0.000886
# aging_s12_r0  0.010808    0.002299  0.000000  0.005240  0.000000   0.000000
# aging_s11_r2  0.012601    0.005395  0.002340  0.004972  0.010972   0.000000
# aging_s5_r0   0.000000    0.000000  0.000000  0.000000  0.000000   0.000000
# aging_s5_r2           0.299978       0.059789   0.0  0.007904
#
#               Oligodendrocytes  Pericytes      SMCs     VLMCs  macro F1_score  \
# sample
# aging_s10_r0          0.000000   0.000000  0.000000  0.000000        0.000000
# aging_s10_r1          0.036246   0.000000  0.000549  0.001160        0.030884
# aging_s11_r0          0.000000   0.000000  0.000000  0.000000        0.000000
# aging_s8_r1           0.000000   0.000000  0.000000  0.000000        0.000000
# aging_s5_r1           0.014557   0.000000  0.000375  0.001011        0.031871
# aging_s6_r0           0.006627   0.000040  0.002068  0.000094        0.034126
# aging_s7_r2           0.115511   0.000000  0.001630  0.000992        0.030186
# aging_s10_r2          0.019890   0.005154  0.000181  0.001660        0.041684
# aging_s11_r1          0.071761   0.000038  0.000592  0.000643        0.035047
# aging_s12_r0          0.083562   0.000000  0.000084  0.000693        0.033695
# aging_s11_r2          0.022363   0.035612  0.000643  0.000827        0.040610
# aging_s5_r0           0.000000   0.000000  0.000000  0.000000        0.000000
# aging_s8_r0           0.109799   0.000000  0.000138  0.001008        0.028541
# aging_s8_r2           0.013645   0.006704  0.000754  0.000677        0.042399
# aging_s1_r0           0.026572   0.001834  0.000274  0.000721        0.032465
# aging_s5_r2           0.012508   0.000000  0.000051  0.000946        0.037812
#
#               micro F1_score
# sample
# aging_s10_r0        0.000000
# aging_s10_r1        0.068168
# aging_s11_r0        0.000000
# aging_s8_r1         0.000000
# aging_s5_r1         0.055931
# aging_s6_r0         0.054901
# aging_s7_r2         0.061943
# aging_s10_r2        0.072028
# aging_s11_r1        0.051195
# aging_s12_r0        0.050119
# aging_s11_r2        0.065951
# aging_s5_r0         0.000000
# aging_s8_r0         0.040601
# aging_s8_r2         0.078259
# aging_s1_r0         0.037267
# aging_s5_r2         0.073824
#
# [16 rows x 23 columns]

# %%
f1 = pd.DataFrame({"F1_statistics": results.mean(axis=0)}).T
f1
# Out:
#                    ABCs  Astrocytes      BAMs  Bergmann       ECs  Ependymal  \
# F1_statistics  0.011271    0.006393  0.001173   0.00383  0.010689   0.000083
#
#                Immune-Other  Microglia  Neurons-Dopa  Neurons-Dopa-Gaba  ...  \
# F1_statistics      0.000605   0.001516      0.008414           0.042941  ...
#
#                Neurons-Immature  Neurons-Other  OECs      OPCs  \
# F1_statistics          0.218282       0.051524   0.0  0.003468
#
#                Oligodendrocytes  Pericytes      SMCs     VLMCs  \
# F1_statistics          0.033315   0.003086  0.000459  0.000652
#
#                macro F1_score  micro F1_score
# F1_statistics        0.026207        0.044387
#
# [1 rows x 23 columns]
