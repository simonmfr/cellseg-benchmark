# %%
# ruff: noqa
import argparse
import logging
import os
from os.path import join
import sys
import warnings

from spatialdata import read_zarr

sys.path.insert(1, "/dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark")

from cellseg_benchmark import sdata_utils as su
# Out:
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
# warnings.filterwarnings("ignore")

# %%
logger = logging.getLogger("shape_mapping")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setFormatter(logging.Formatter("%(asctime)s [%(levelname)s]: %(message)s"))
logger.addHandler(handler)

# %%
def get_args(test_args=None):  # noqa: D103
    p = argparse.ArgumentParser(
        description="Creates a master sdata for a given sample, containing multiple segmentation results."
    )
    p.add_argument("sample", help="Sample name.")
    p.add_argument(
        "data_path",
        help="Path to folder with merscope output data (e.g. /cohort1/slide2/region0).",
    )
    p.add_argument(
        "zmode",
        choices=["z3"],
        help="Mode of master sdata. Either 'z3' or '3d' (currently only z3 is implemented).",
    )
    p.add_argument("data_dir", help="Output data folder.")
    p.add_argument(
        "--n_ficture",
        default=21,
        type=int,
        help="Consider Ficture model with n_ficture factors.",
    )
    p.add_argument("--run_date", type=str, help="run date (YYYYMMDD).", default=None)
    p.add_argument("--organism", type=str, help="organism.", default=None)
    p.add_argument("--slide", type=str, help="slide.", default=None)
    p.add_argument("--region", type=str, help="region.", default=None)
    p.add_argument("--cohort", type=str, help="cohort.", default=None)
    p.add_argument(
        "--obs",
        action="append",
        default=[],
        metavar="KEY=VAL",
        help="Extra covariates to add to adata.obs (repeatable), e.g. --obs tissue=brain.",
    )
    if test_args is not None:
        return p.parse_args(test_args)
    else:
        return p.parse_args()

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "SynergyLung_s1_r0",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/Synergy-projects-temp/MouseLung-Sijia/output-20250704_AGLiesz-Sijia-MouseLung-Slide1-Stroke_VMSC03901/region_R1-Stroke",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "SynergyLung",
        "--slide",
        "1",
        "--region",
        "0",
        "--organism",
        "mouse",
        "--run_date",
        "20250704",
        "--obs",
        "condition=stroke",
    ]
)

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "aging_s11_r0",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "aging",
        "--slide",
        "11",
        "--region",
        "0",
        "--organism",
        "mouse",
        "--run_date",
        "20250526",
        "--obs",
        "genotype=WT",
        "--obs",
        "age_months=18",
        "--obs",
        "animal_id=232",
    ]
)

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "htra1_s4_r1",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20240829_Htra1-Slide04-cp-TG69-KO305/region_1-TG69",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "htra1",
        "--slide",
        "4",
        "--region",
        "1",
        "--organism",
        "mouse",
        "--run_date",
        "20240829",
        "--obs",
        "genotype=TG",
        "--obs",
        "age_months=6",
        "--obs",
        "animal_id=69",
    ]
)

# %%
args
# Out:
# Namespace(sample='aging_s11_r0', data_path='/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m', zmode='z3', data_dir='/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark', n_ficture=21, run_date='20250526', organism='mouse', slide='11', region='0', cohort='aging', obs=['genotype=WT', 'age_months=18', 'animal_id=232'])

# %%
NONES = {"", "None", "none", "null", "NULL", None}
for k in ["organism", "slide", "region", "cohort"]:
    if getattr(args, k) in NONES:
        setattr(args, k, None)

# %%
extra_obs = {}
for kv in args.obs:
    k, v = kv.split("=", 1)
    extra_obs[k] = None if v in NONES else v

# %%
extra_obs
# Out:
# {'genotype': 'WT', 'age_months': '18', 'animal_id': '232'}

# %%
# %%time
logger.info("Importing images and points...")
su.process_merscope(args.sample, args.data_dir, args.data_path, zmode=args.zmode)
# Out:
# 2025-11-10 18:33:45,598 [INFO]: Importing images and points...
# Skipping aging_s11_r0: z3 file already exists
# CPU times: user 0 ns, sys: 1.96 ms, total: 1.96 ms
# Wall time: 1.85 ms

# %%
sdata_path = join(args.data_dir, "samples", args.sample)
sdata_main = read_zarr(join(sdata_path, "sdata_z3.zarr"))
# Out:
# /tmp/ipykernel_2351466/1871646594.py:2: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata_main = read_zarr(join(sdata_path, "sdata_z3.zarr"))

# %%
sdata_main
# Out:
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
# SpatialData object, with associated Zarr store: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/samples/aging_s11_r0/sdata_z3.zarr
# ├── Images
# │     └── 'aging_s11_r0_z3': DataTree[cyx] (8, 35656, 65455), (8, 17828, 32727), (8, 8914, 16363), (8, 4457, 8181), (8, 2228, 4090)
# ├── Points
# │     └── 'aging_s11_r0_transcripts': DataFrame with shape: (<Delayed>, 9) (2D points)
# └── Shapes
#       ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2': GeoDataFrame shape: (128972, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8': GeoDataFrame shape: (113076, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2': GeoDataFrame shape: (122471, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8': GeoDataFrame shape: (92417, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0': GeoDataFrame shape: (121914, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2': GeoDataFrame shape: (123512, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8': GeoDataFrame shape: (100144, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2': GeoDataFrame shape: (120557, 1) (2D shapes)
#       ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8': GeoDataFrame shape: (89977, 1) (2D shapes)
#       ├── 'boundaries_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (35248, 1) (2D shapes)
#       ├── 'boundaries_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (66718, 1) (2D shapes)
#       ├── 'boundaries_Cellpose_1_Merlin': GeoDataFrame shape: (55471, 9) (2D shapes)
#       ├── 'boundaries_Cellpose_1_nuclei_model': GeoDataFrame shape: (35649, 1) (2D shapes)
#       ├── 'boundaries_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (48076, 1) (2D shapes)
#       ├── 'boundaries_Cellpose_2_DAPI_Transcripts': GeoDataFrame shape: (57575, 1) (2D shapes)
#       ├── 'boundaries_ComSeg_Cellpose_1_nuclei_model': GeoDataFrame shape: (35649, 1) (2D shapes)
#       ├── 'boundaries_Negative_Control_Rastered_5': GeoDataFrame shape: (1090194, 3) (2D shapes)
#       ├── 'boundaries_Negative_Control_Rastered_10': GeoDataFrame shape: (272902, 3) (2D shapes)
#       ├── 'boundaries_Negative_Control_Rastered_25': GeoDataFrame shape: (43865, 3) (2D shapes)
#       ├── 'boundaries_Negative_Control_Voronoi': GeoDataFrame shape: (221959, 1) (2D shapes)
#       ├── 'boundaries_Proseg_3D_Cellpose_1_nuclei_model': GeoDataFrame shape: (249409, 4) (2D shapes)
#       ├── 'boundaries_Proseg_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (101269, 4) (2D shapes)
#       ├── 'boundaries_Proseg_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (203637, 4) (2D shapes)
#       ├── 'boundaries_Proseg_Cellpose_1_nuclei_model': GeoDataFrame shape: (93454, 4) (2D shapes)
#       ├── 'boundaries_Proseg_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (143754, 4) (2D shapes)
#       ├── 'boundaries_Proseg_Cellpose_2_DAPI_Transcripts': GeoDataFrame shape: (177284, 4) (2D shapes)
#       ├── 'boundaries_Proseg_pure': GeoDataFrame shape: (130553, 4) (2D shapes)
#       ├── 'boundaries_vpt_2D_DAPI_PolyT': GeoDataFrame shape: (59793, 9) (2D shapes)
#       ├── 'boundaries_vpt_2D_DAPI_PolyT_nuclei': GeoDataFrame shape: (58377, 9) (2D shapes)
#       ├── 'boundaries_vpt_2D_DAPI_nuclei': GeoDataFrame shape: (41105, 9) (2D shapes)
#       ├── 'boundaries_vpt_3D_DAPI_PolyT': GeoDataFrame shape: (268625, 5) (2D shapes)
#       ├── 'boundaries_vpt_3D_DAPI_PolyT_nuclei': GeoDataFrame shape: (322483, 5) (2D shapes)
#       └── 'boundaries_vpt_3D_DAPI_nuclei': GeoDataFrame shape: (264165, 5) (2D shapes)
# with coordinate systems:
#     ▸ 'global', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_Proseg_pure (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)
#     ▸ 'micron', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_Proseg_pure (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)
#     ▸ 'pixel', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_Proseg_pure (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs.columns

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["age_months"]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["genotype"]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["animal_id"]

# %%
logger.info("Integrating segmentation data from available methods into main sdata...")
seg_methods = [
    method
    for method in os.listdir(join(sdata_path, "results"))
    if os.path.isdir(join(sdata_path, "results", method, "sdata.zarr"))
]
# Out:
# 2025-11-10 18:34:06,985 [INFO]: Integrating segmentation data from available methods into main sdata...

# %%
seg_methods
# Out:
# ['Proseg_3D_Cellpose_1_nuclei_model',
#  'Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8',
#  'vpt_2D_DAPI_nuclei',
#  'Cellpose_1_nuclei_model',
#  'Baysor_2D_Cellpose_2_DAPI_PolyT_0.2',
#  'Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8',
#  'Negative_Control_Rastered_5',
#  'Cellpose_2_DAPI_PolyT',
#  'Proseg_pure',
#  'vpt_3D_DAPI_PolyT_nuclei',
#  'Proseg_3D_Cellpose_1_DAPI_Transcripts',
#  'Proseg_Cellpose_1_DAPI_Transcripts',
#  'Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2',
#  'Baysor_2D_Cellpose_1_DAPI_PolyT_0.2',
#  'Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2',
#  'Cellpose_1_DAPI_PolyT',
#  'Negative_Control_Rastered_10',
#  'Negative_Control_Voronoi',
#  'Proseg_3D_Cellpose_2_DAPI_PolyT',
#  'vpt_3D_DAPI_nuclei',
#  'Proseg_Cellpose_2_DAPI_Transcripts',
#  'ComSeg_Cellpose_1_nuclei_model',
#  'Proseg_Cellpose_1_nuclei_model',
#  'Cellpose_2_DAPI_Transcripts',
#  'Cellpose_1_Merlin',
#  'Negative_Control_Rastered_25',
#  'vpt_2D_DAPI_PolyT',
#  'Cellpose_1_DAPI_Transcripts',
#  'Proseg_3D_Cellpose_1_DAPI_PolyT',
#  'Baysor_2D_Cellpose_2_DAPI_PolyT_0.8',
#  'Baysor_2D_Cellpose_1_nuclei_model_1.0',
#  'vpt_2D_DAPI_PolyT_nuclei',
#  'vpt_3D_DAPI_PolyT',
#  'Proseg_Cellpose_2_DAPI_PolyT',
#  'Baysor_2D_Cellpose_1_DAPI_PolyT_0.8',
#  'Proseg_Cellpose_1_DAPI_PolyT']

# %%
extra_obs
# Out:
# {'genotype': 'WT', 'age_months': '18', 'animal_id': '232'}

# %%
args.data_path
# Out:
# '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m'

# %%
su.integrate_segmentation_data(
    sdata_path,
    seg_methods,
    sdata_main,
    run_date=args.run_date,
    organism=args.organism,
    slide=args.slide,
    region=args.region,
    cohort=args.cohort,
    write_to_disk=True,
    data_path=args.data_path,
    logger=logger,
    **extra_obs,
)
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]2025-11-10 18:34:07,040 [INFO]: Adding Proseg_3D_Cellpose_1_nuclei_model...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:34:08,133 [WARNING]: Skipping boundary import of Proseg_3D_Cellpose_1_nuclei_model as boundaries_Proseg_3D_Cellpose_1_nuclei_model exist already.
# 2025-11-10 18:34:08,134 [INFO]: Adding adata for Proseg_3D_Cellpose_1_nuclei_model...
# 2025-11-10 18:34:08,196 [WARNING]: No annotation files found for Proseg_3D_Cellpose_1_nuclei_model. Skipping
# 2025-11-10 18:34:15,950 [INFO]: Collecting volume metadata for Proseg_3D_Cellpose_1_nuclei_model
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/xarray_schema/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# 2025-11-10 18:35:03,396 [WARNING]: No Ficture_stats files found for Proseg_3D_Cellpose_1_nuclei_model. Skipping.
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#   3%|▎         | 1/36 [01:00<35:03, 60.10s/it]2025-11-10 18:35:07,138 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:35:08,819 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 as boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 exist already.
# 2025-11-10 18:35:08,820 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# 2025-11-10 18:35:08,972 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# 2025-11-10 18:35:12,660 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8
# 2025-11-10 18:35:24,319 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#   6%|▌         | 2/36 [01:26<22:43, 40.11s/it]2025-11-10 18:35:33,261 [INFO]: Adding vpt_2D_DAPI_nuclei...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:35:34,933 [WARNING]: Skipping boundary import of vpt_2D_DAPI_nuclei as boundaries_vpt_2D_DAPI_nuclei exist already.
# 2025-11-10 18:35:34,937 [INFO]: Adding adata for vpt_2D_DAPI_nuclei...
# 2025-11-10 18:35:35,076 [INFO]: Adding cell type annotations for vpt_2D_DAPI_nuclei...
# 2025-11-10 18:35:36,769 [INFO]: Calculate volume metrics vpt_2D_DAPI_nuclei
# 2025-11-10 18:35:42,966 [INFO]: Adding Ficture stats to vpt_2D_DAPI_nuclei...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#   8%|▊         | 3/36 [01:46<17:03, 31.02s/it]2025-11-10 18:35:53,464 [INFO]: Adding Cellpose_1_nuclei_model...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:35:54,172 [WARNING]: Skipping boundary import of Cellpose_1_nuclei_model as boundaries_Cellpose_1_nuclei_model exist already.
# 2025-11-10 18:35:54,173 [INFO]: Adding adata for Cellpose_1_nuclei_model...
# 2025-11-10 18:35:54,252 [INFO]: Adding cell type annotations for Cellpose_1_nuclei_model...
# 2025-11-10 18:35:55,827 [INFO]: Calculate volume metrics Cellpose_1_nuclei_model
# 2025-11-10 18:36:01,220 [INFO]: Adding Ficture stats to Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  11%|█         | 4/36 [02:01<13:12, 24.78s/it]2025-11-10 18:36:08,671 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:36:10,545 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 as boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 exist already.
# 2025-11-10 18:36:10,546 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# 2025-11-10 18:36:10,746 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# 2025-11-10 18:36:15,531 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_PolyT_0.2
# 2025-11-10 18:36:32,344 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  14%|█▍        | 5/36 [02:35<14:24, 27.90s/it]2025-11-10 18:36:42,106 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:36:43,834 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 as boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 exist already.
# 2025-11-10 18:36:43,836 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# 2025-11-10 18:36:43,993 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# 2025-11-10 18:36:47,615 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8
# 2025-11-10 18:36:59,673 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  31%|███       | 11/36 [13:01<46:54, 112.56s/it]2025-11-10 18:47:09,028 [INFO]: Adding Proseg_Cellpose_1_DAPI_Transcripts...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:47:11,452 [WARNING]: Skipping boundary import of Proseg_Cellpose_1_DAPI_Transcripts as boundaries_Proseg_Cellpose_1_DAPI_Transcripts exist already.
# 2025-11-10 18:47:11,453 [INFO]: Adding adata for Proseg_Cellpose_1_DAPI_Transcripts...
# 2025-11-10 18:47:11,692 [INFO]: Adding cell type annotations for Proseg_Cellpose_1_DAPI_Transcripts...
# 2025-11-10 18:47:19,191 [INFO]: Collecting volume metadata for Proseg_Cellpose_1_DAPI_Transcripts
# 2025-11-10 18:48:28,863 [INFO]: Adding Ficture stats to Proseg_Cellpose_1_DAPI_Transcripts...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  33%|███▎      | 12/36 [14:31<42:16, 105.67s/it]2025-11-10 18:48:38,943 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:48:41,073 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 as boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 exist already.
# 2025-11-10 18:48:41,075 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# 2025-11-10 18:48:41,275 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# 2025-11-10 18:48:46,072 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2
# 2025-11-10 18:49:02,731 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  36%|███▌      | 13/36 [15:05<32:10, 83.93s/it] 2025-11-10 18:49:12,830 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:49:14,873 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 as boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 exist already.
# 2025-11-10 18:49:14,875 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# 2025-11-10 18:49:15,101 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# 2025-11-10 18:49:20,036 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_PolyT_0.2
# 2025-11-10 18:49:37,763 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  39%|███▉      | 14/36 [15:40<25:20, 69.10s/it]2025-11-10 18:49:47,681 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:49:49,883 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 as boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 exist already.
# 2025-11-10 18:49:49,885 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# 2025-11-10 18:49:50,118 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# 2025-11-10 18:49:54,841 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2
# 2025-11-10 18:50:10,691 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  42%|████▏     | 15/36 [16:13<20:21, 58.17s/it]2025-11-10 18:50:20,507 [INFO]: Adding Cellpose_1_DAPI_PolyT...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18

# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:55:50,584 [WARNING]: Skipping boundary import of Proseg_Cellpose_2_DAPI_Transcripts as boundaries_Proseg_Cellpose_2_DAPI_Transcripts exist already.
# 2025-11-10 18:55:50,585 [INFO]: Adding adata for Proseg_Cellpose_2_DAPI_Transcripts...
# 2025-11-10 18:55:50,795 [INFO]: Adding cell type annotations for Proseg_Cellpose_2_DAPI_Transcripts...
# 2025-11-10 18:55:57,235 [INFO]: Collecting volume metadata for Proseg_Cellpose_2_DAPI_Transcripts
# 2025-11-10 18:56:59,835 [INFO]: Adding Ficture stats to Proseg_Cellpose_2_DAPI_Transcripts...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  58%|█████▊    | 21/36 [23:02<18:46, 75.11s/it]2025-11-10 18:57:09,265 [INFO]: Adding ComSeg_Cellpose_1_nuclei_model...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:57:10,177 [WARNING]: Skipping boundary import of ComSeg_Cellpose_1_nuclei_model as boundaries_ComSeg_Cellpose_1_nuclei_model exist already.
# 2025-11-10 18:57:10,178 [INFO]: Adding adata for ComSeg_Cellpose_1_nuclei_model...
# 2025-11-10 18:57:10,258 [WARNING]: No annotation files found for ComSeg_Cellpose_1_nuclei_model. Skipping
# 2025-11-10 18:57:11,462 [INFO]: Calculate volume metrics ComSeg_Cellpose_1_nuclei_model
# 2025-11-10 18:57:16,365 [WARNING]: No Ficture_stats files found for ComSeg_Cellpose_1_nuclei_model. Skipping.
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  61%|██████    | 22/36 [23:12<12:58, 55.58s/it]2025-11-10 18:57:19,313 [INFO]: Adding Proseg_Cellpose_1_nuclei_model...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:57:20,804 [WARNING]: Skipping boundary import of Proseg_Cellpose_1_nuclei_model as boundaries_Proseg_Cellpose_1_nuclei_model exist already.
# 2025-11-10 18:57:20,805 [INFO]: Adding adata for Proseg_Cellpose_1_nuclei_model...
# 2025-11-10 18:57:20,937 [INFO]: Adding cell type annotations for Proseg_Cellpose_1_nuclei_model...
# 2025-11-10 18:57:24,417 [INFO]: Collecting volume metadata for Proseg_Cellpose_1_nuclei_model
# 2025-11-10 18:58:02,536 [INFO]: Adding Ficture stats to Proseg_Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  64%|██████▍   | 23/36 [24:04<11:48, 54.50s/it]2025-11-10 18:58:11,302 [INFO]: Adding Cellpose_2_DAPI_Transcripts...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18:58:12,557 [WARNING]: Skipping boundary import of Cellpose_2_DAPI_Transcripts as boundaries_Cellpose_2_DAPI_Transcripts exist already.
# 2025-11-10 18:58:12,558 [INFO]: Adding adata for Cellpose_2_DAPI_Transcripts...
# 2025-11-10 18:58:12,681 [INFO]: Adding cell type annotations for Cellpose_2_DAPI_Transcripts...
# 2025-11-10 18:58:15,046 [INFO]: Calculate volume metrics Cellpose_2_DAPI_Transcripts
# 2025-11-10 18:58:22,781 [INFO]: Adding Ficture stats to Cellpose_2_DAPI_Transcripts...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  67%|██████▋   | 24/36 [24:24<08:49, 44.09s/it]2025-11-10 18:58:31,115 [INFO]: Adding Cellpose_1_Merlin...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 18

# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 19:04:59,218 [WARNING]: Skipping boundary import of Proseg_Cellpose_2_DAPI_PolyT as boundaries_Proseg_Cellpose_2_DAPI_PolyT exist already.
# 2025-11-10 19:04:59,219 [INFO]: Adding adata for Proseg_Cellpose_2_DAPI_PolyT...
# 2025-11-10 19:04:59,397 [INFO]: Adding cell type annotations for Proseg_Cellpose_2_DAPI_PolyT...
# 2025-11-10 19:05:04,604 [INFO]: Collecting volume metadata for Proseg_Cellpose_2_DAPI_PolyT
# 2025-11-10 19:05:53,791 [INFO]: Adding Ficture stats to Proseg_Cellpose_2_DAPI_PolyT...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  94%|█████████▍| 34/36 [31:56<02:00, 60.39s/it]2025-11-10 19:06:03,216 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 19:06:05,174 [WARNING]: Skipping boundary import of Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 as boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 exist already.
# 2025-11-10 19:06:05,178 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# 2025-11-10 19:06:05,378 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# 2025-11-10 19:06:11,166 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_PolyT_0.8
# 2025-11-10 19:06:26,814 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
#  97%|█████████▋| 35/36 [32:29<00:52, 52.41s/it]2025-11-10 19:06:37,009 [INFO]: Adding Proseg_Cellpose_1_DAPI_PolyT...
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/sdata_utils.py:208: UserWarning: SpatialData is not stored in the most current format. If you want to use Zarr v3, please write the store to a new location using `sdata.write()`.
#   sdata = sd.read_zarr(seg_path)
# 2025-11-10 19:06:38,833 [WARNING]: Skipping boundary import of Proseg_Cellpose_1_DAPI_PolyT as boundaries_Proseg_Cellpose_1_DAPI_PolyT exist already.
# 2025-11-10 19:06:38,834 [INFO]: Adding adata for Proseg_Cellpose_1_DAPI_PolyT...
# 2025-11-10 19:06:38,970 [INFO]: Adding cell type annotations for Proseg_Cellpose_1_DAPI_PolyT...
# 2025-11-10 19:06:42,717 [INFO]: Collecting volume metadata for Proseg_Cellpose_1_DAPI_PolyT
# 2025-11-10 19:07:19,836 [INFO]: Adding Ficture stats to Proseg_Cellpose_1_DAPI_PolyT...
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
# 100%|██████████| 36/36 [33:21<00:00, 55.59s/it]
# /home/ubuntu/miniforge3/envs/sopa/lib/python3.12/site-packages/zarr/core/group.py:3530: ZarrUserWarning: Object at zmetadata is not recognized as a component of a Zarr hierarchy.
#   warnings.warn(
# SpatialData object, with associated Zarr store: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/samples/aging_s11_r0/sdata_z3.zarr
# ├── Images
# │     └── 'aging_s11_r0_z3': DataTree[cyx] (8, 35656, 65455), (8, 17828, 32727), (8, 8914, 16363), (8, 4457, 8181), (8, 2228, 4090)
# ├── Points
# │     └── 'aging_s11_r0_transcripts': DataFrame with shape: (<Delayed>, 9) (2D points)
# ├── Shapes
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2': GeoDataFrame shape: (128972, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8': GeoDataFrame shape: (113076, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2': GeoDataFrame shape: (122471, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8': GeoDataFrame shape: (92417, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0': GeoDataFrame shape: (121914, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2': GeoDataFrame shape: (123512, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8': GeoDataFrame shape: (100144, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2': GeoDataFrame shape: (120557, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8': GeoDataFrame shape: (89977, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (35248, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (66718, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_Merlin': GeoDataFrame shape: (55471, 9) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_nuclei_model': GeoDataFrame shape: (35649, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (48076, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_2_DAPI_Transcripts': GeoDataFrame shape: (57575, 1) (2D shapes)
# │     ├── 'boundaries_ComSeg_Cellpose_1_nuclei_model': GeoDataFrame shape: (35649, 1) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Rastered_5': GeoDataFrame shape: (1090194, 3) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Rastered_10': GeoDataFrame shape: (272902, 3) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Rastered_25': GeoDataFrame shape: (43865, 3) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Voronoi': GeoDataFrame shape: (221959, 1) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (245914, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (464552, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_1_nuclei_model': GeoDataFrame shape: (249409, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (335248, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (101269, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (203637, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_Cellpose_1_nuclei_model': GeoDataFrame shape: (93454, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (143754, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_Cellpose_2_DAPI_Transcripts': GeoDataFrame shape: (177284, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_pure': GeoDataFrame shape: (130553, 4) (2D shapes)
# │     ├── 'boundaries_vpt_2D_DAPI_PolyT': GeoDataFrame shape: (59793, 9) (2D shapes)
# │     ├── 'boundaries_vpt_2D_DAPI_PolyT_nuclei': GeoDataFrame shape: (58377, 9) (2D shapes)
# │     ├── 'boundaries_vpt_2D_DAPI_nuclei': GeoDataFrame shape: (41105, 9) (2D shapes)
# │     ├── 'boundaries_vpt_3D_DAPI_PolyT': GeoDataFrame shape: (268625, 5) (2D shapes)
# │     ├── 'boundaries_vpt_3D_DAPI_PolyT_nuclei': GeoDataFrame shape: (322483, 5) (2D shapes)
# │     └── 'boundaries_vpt_3D_DAPI_nuclei': GeoDataFrame shape: (264165, 5) (2D shapes)
# └── Tables
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2': AnnData (128972, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8': AnnData (113076, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2': AnnData (122471, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8': AnnData (92417, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_nuclei_model_1.0': AnnData (121914, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2': AnnData (123512, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8': AnnData (100144, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2': AnnData (120557, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8': AnnData (89977, 500)
#       ├── 'adata_Cellpose_1_DAPI_PolyT': AnnData (35248, 500)
#       ├── 'adata_Cellpose_1_DAPI_Transcripts': AnnData (66718, 500)
#       ├── 'adata_Cellpose_1_Merlin': AnnData (55471, 500)
#       ├── 'adata_Cellpose_1_nuclei_model': AnnData (35649, 500)
#       ├── 'adata_Cellpose_2_DAPI_PolyT': AnnData (48076, 500)
#       ├── 'adata_Cellpose_2_DAPI_Transcripts': AnnData (57575, 500)
#       ├── 'adata_ComSeg_Cellpose_1_nuclei_model': AnnData (35649, 500)
#       ├── 'adata_Negative_Control_Rastered_5': AnnData (1090194, 500)
#       ├── 'adata_Negative_Control_Rastered_10': AnnData (272902, 500)
#       ├── 'adata_Negative_Control_Rastered_25': AnnData (43865, 500)
#       ├── 'adata_Negative_Control_Voronoi': AnnData (221959, 500)
#       ├── 'adata_Proseg_3D_Cellpose_1_DAPI_PolyT': AnnData (35135, 500)
#       ├── 'adata_Proseg_3D_Cellpose_1_DAPI_Transcripts': AnnData (66376, 500)
#       ├── 'adata_Proseg_3D_Cellpose_1_nuclei_model': AnnData (35639, 500)
#       ├── 'adata_Proseg_3D_Cellpose_2_DAPI_PolyT': AnnData (47927, 500)
#       ├── 'adata_Proseg_Cellpose_1_DAPI_PolyT': AnnData (35240, 500)
#       ├── 'adata_Proseg_Cellpose_1_DAPI_Transcripts': AnnData (66475, 500)
#       ├── 'adata_Proseg_Cellpose_1_nuclei_model': AnnData (35643, 500)
#       ├── 'adata_Proseg_Cellpose_2_DAPI_PolyT': AnnData (48024, 500)
#       ├── 'adata_Proseg_Cellpose_2_DAPI_Transcripts': AnnData (57400, 500)
#       ├── 'adata_Proseg_pure': AnnData (46343, 500)
#       ├── 'adata_vpt_2D_DAPI_PolyT': AnnData (59793, 500)
#       ├── 'adata_vpt_2D_DAPI_PolyT_nuclei': AnnData (58377, 500)
#       ├── 'adata_vpt_2D_DAPI_nuclei': AnnData (41105, 500)
#       ├── 'adata_vpt_3D_DAPI_PolyT': AnnData (85159, 500)
#       ├── 'adata_vpt_3D_DAPI_PolyT_nuclei': AnnData (83790, 500)
#       └── 'adata_vpt_3D_DAPI_nuclei': AnnData (41480, 500)
# with coordinate systems:
#     ▸ 'global', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_Proseg_pure (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)
#     ▸ 'micron', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_Proseg_pure (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)
#     ▸ 'pixel', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Proseg_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_Proseg_pure (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)

# %%
# test sdata #################

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs
# Out:
#            region slide                          spt_region  \
# aaaaaaaa-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaab-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaac-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaad-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaae-1      0    11  boundaries_Cellpose_1_nuclei_model
# ...           ...   ...                                 ...
# aaaaildm-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaildn-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaildo-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaildp-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaailea-1      0    11  boundaries_Cellpose_1_nuclei_model
#
#            cell_type_incl_low_quality_revised  \
# aaaaaaaa-1                   Oligodendrocytes
# aaaaaaab-1                   Oligodendrocytes
# aaaaaaac-1                   Oligodendrocytes
# aaaaaaad-1                   Oligodendrocytes
# aaaaaaae-1                   Oligodendrocytes
# ...                                       ...
# aaaaildm-1                       Neurons-Glut
# aaaaildn-1                   Oligodendrocytes
# aaaaildo-1                                ECs
# aaaaildp-1                       Neurons-Glut
# aaaailea-1                       Neurons-Glut
#
#            cell_type_mmc_incl_low_quality_clusters  \
# aaaaaaaa-1                          Choroid-Plexus
# aaaaaaab-1                        Oligodendrocytes
# aaaaaaac-1                        Oligodendrocytes
# aaaaaaad-1                        Oligodendrocytes
# aaaaaaae-1                          Choroid-Plexus
# ...                                            ...
# aaaaildm-1                            Neurons-Glut
# aaaaildn-1                            Neurons-Glut
# aaaaildo-1                                     ECs
# aaaaildp-1                            Neurons-Glut
# aaaailea-1                            Neurons-Glut
#
#            cell_type_mmc_incl_low_quality cell_type_incl_mixed_revised  \
# aaaaaaaa-1                     Astrocytes             Oligodendrocytes
# aaaaaaab-1                     Astrocytes             Oligodendrocytes
# aaaaaaac-1               Oligodendrocytes             Oligodendrocytes
# aaaaaaad-1               Oligodendrocytes             Oligodendrocytes
# aaaaaaae-1               Oligodendrocytes             Oligodendrocytes
# ...                                   ...                          ...
# aaaaildm-1                   Neurons-Glut                 Neurons-Glut
# aaaaildn-1                   Neurons-Glut             Oligodendrocytes
# aaaaildo-1                            ECs                          ECs
# aaaaildp-1                   Neurons-Glut                 Neurons-Glut
# aaaailea-1                      Undefined                 Neurons-Glut
#
#            cell_type_mmc_incl_mixed_clusters cell_type_mmc_incl_mixed  \
# aaaaaaaa-1                             Mixed                    Mixed
# aaaaaaab-1                  Oligodendrocytes                    Mixed
# aaaaaaac-1                  Oligodendrocytes         Oligodendrocytes
# aaaaaaad-1                  Oligodendrocytes         Oligodendrocytes
# aaaaaaae-1                             Mixed         Oligodendrocytes
# ...                                      ...                      ...
# aaaaildm-1                      Neurons-Glut             Neurons-Glut
# aaaaildn-1                      Neurons-Glut             Neurons-Glut
# aaaaildo-1                               ECs                      ECs
# aaaaildp-1                      Neurons-Glut             Neurons-Glut
# aaaailea-1                      Neurons-Glut             Neurons-Glut
#
#            cell_type_revised  ...  solidity elongation genotype  age_months  \
# aaaaaaaa-1  Oligodendrocytes  ...  0.956813   0.337908       WT          18
# aaaaaaab-1  Oligodendrocytes  ...  1.000000   0.113391       WT          18
# aaaaaaac-1  Oligodendrocytes  ...  1.000000   0.098323       WT          18
# aaaaaaad-1  Oligodendrocytes  ...  1.000000   0.228436       WT          18
# aaaaaaae-1  Oligodendrocytes  ...  1.000000   0.083886       WT          18
# ...                      ...  ...       ...        ...      ...         ...
# aaaaildm-1      Neurons-Glut  ...  0.997871   0.108961       WT          18
# aaaaildn-1  Oligodendrocytes  ...  0.989197   0.240081       WT          18
# aaaaildo-1               ECs  ...  1.000000   0.018043       WT          18
# aaaaildp-1      Neurons-Glut  ...  0.968743   0.055256       WT          18
# aaaailea-1      Neurons-Glut  ...  0.990032   0.207281       WT          18
#
#             run_date  organism  cohort        sample  animal_id  condition
# aaaaaaaa-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaab-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaac-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaad-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaae-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# ...              ...       ...     ...           ...        ...        ...
# aaaaildm-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaildn-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaildo-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaildp-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaailea-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
#
# [35649 rows x 30 columns]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs.columns
# Out:
# Index(['region', 'slide', 'spt_region', 'cell_type_incl_low_quality_revised',
#        'cell_type_mmc_incl_low_quality_clusters',
#        'cell_type_mmc_incl_low_quality', 'cell_type_incl_mixed_revised',
#        'cell_type_mmc_incl_mixed_clusters', 'cell_type_mmc_incl_mixed',
#        'cell_type_revised', 'cell_type_mmc_raw_clusters', 'cell_type_mmc_raw',
#        'cell_id', 'area', 'volume_sum', 'volume_final', 'num_z_planes',
#        'size_normalized', 'surface_to_volume_ratio', 'sphericity', 'solidity',
#        'elongation', 'genotype', 'age_months', 'run_date', 'organism',
#        'cohort', 'sample', 'animal_id', 'condition'],
#       dtype='object')

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["age_months"]
# Out:
# aaaaaaaa-1    18
# aaaaaaab-1    18
# aaaaaaac-1    18
# aaaaaaad-1    18
# aaaaaaae-1    18
#               ..
# aaaaildm-1    18
# aaaaildn-1    18
# aaaaildo-1    18
# aaaaildp-1    18
# aaaailea-1    18
# Name: age_months, Length: 35649, dtype: object

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["condition"]
# Out:
# aaaaaaaa-1    WT_18
# aaaaaaab-1    WT_18
# aaaaaaac-1    WT_18
# aaaaaaad-1    WT_18
# aaaaaaae-1    WT_18
#               ...
# aaaaildm-1    WT_18
# aaaaildn-1    WT_18
# aaaaildo-1    WT_18
# aaaaildp-1    WT_18
# aaaailea-1    WT_18
# Name: condition, Length: 35649, dtype: object

# %%
sdata_main.tables["adata_Cellpose_1_Merlin"].obs.columns
# Out:
# Index(['fov', 'volume', 'center_x', 'center_y', 'min_x', 'min_y', 'max_x',
#        'max_y', 'anisotropy', 'transcript_count', 'perimeter_area_ratio',
#        'Fth1_raw', 'Fth1_high_pass', 'DAPI_raw', 'DAPI_high_pass', 'App_raw',
#        'App_high_pass', 'Aldoc_raw', 'Aldoc_high_pass', 'Sst_raw',
#        'Sst_high_pass', 'Plp1_raw', 'Plp1_high_pass', 'PolyT_raw',
#        'PolyT_high_pass', 'region', 'slide', 'dataset_id', 'cells_region',
#        'spt_region', 'cell_type_incl_low_quality_revised',
#        'cell_type_mmc_incl_low_quality_clusters',
#        'cell_type_mmc_incl_low_quality', 'cell_type_incl_mixed_revised',
#        'cell_type_mmc_incl_mixed_clusters', 'cell_type_mmc_incl_mixed',
#        'cell_type_revised', 'cell_type_mmc_raw_clusters', 'cell_type_mmc_raw',
#        'cell_id', 'area', 'volume_sum', 'volume_final', 'num_z_planes',
#        'size_normalized', 'surface_to_volume_ratio', 'sphericity', 'solidity',
#        'elongation', 'genotype', 'age_months', 'run_date', 'organism',
#        'cohort', 'sample', 'animal_id', 'condition'],
#       dtype='object')

# %%
sdata_main.tables["adata_Cellpose_1_Merlin"].obs
# Out:
#                     fov       volume      center_x      center_y  \
# EntityID
# 248711000003100001  417   808.562111   7231.107147   7198.372446
# 248711000003100002  417   266.361792   7248.592975   7195.647341
# 248711000003100005  417   198.258304   7272.734791   7195.519228
# 248711000003100006  417   360.645661   7285.561699   7196.026506
# 248711000003100010  417   259.700561   7246.363524   7199.820553
# ...                 ...          ...           ...           ...
# 248711000110100127   40  1136.350842  11615.779651  10804.572500
# 248711000110100128   40  1429.615413  11598.700329  10813.752208
# 248711000110100129   40  1275.092968  11571.393604  10818.085659
# 248711000110100130   40   459.810753  11475.060957  10830.734862
# 248711000111100063   14    79.820706  12066.580812  10640.203908
#
#                            min_x         min_y         max_x         max_y  \
# EntityID
# 248711000003100001   7226.604490   7193.764156   7235.853920   7202.938191
# 248711000003100002   7244.526919   7193.764156   7252.066519   7198.191981
# 248711000003100005   7269.911928   7193.764156   7275.837170   7197.394793
# 248711000003100006   7281.029287   7193.788223   7289.651378   7198.719600
# 248711000003100010   7243.445775   7196.495046   7249.041249   7203.355593
# ...                          ...           ...           ...           ...
# 248711000110100127  11610.101084  10798.694083  11622.200637  10810.839648
# 248711000110100128  11591.881941  10806.229373  11605.488999  10820.481903
# 248711000110100129  11565.165457  10810.545320  11576.349561  10824.972732
# 248711000110100130  11470.911481  10827.032940  11479.611647  10834.051085
# 248711000111100063  12064.746971  10638.854103  12068.237773  10641.506134
#
#                     anisotropy  transcript_count  ...  solidity  elongation  \
# EntityID                                          ...
# 248711000003100001    1.013078                 0  ...  1.000000    0.096341
# 248711000003100002    1.704450                 0  ...  1.000000    0.210849
# 248711000003100005    1.647894                 0  ...  1.000000    0.006583
# 248711000003100006    1.755867                 0  ...  1.000000    0.256885
# 248711000003100010    1.636452                 0  ...  1.000000    0.375512
# ...                        ...               ...  ...       ...         ...
# 248711000110100127    1.242970                 1  ...  0.985538    0.216094
# 248711000110100128    1.017308                 2  ...  0.995633    0.040381
# 248711000110100129    1.289438                 2  ...  0.990718    0.100072
# 248711000110100130    1.323253                12  ...  1.000000    0.183094
# 248711000111100063    1.326681                 0  ...  1.000000    0.051042
#
#                     genotype  age_months  run_date  organism  cohort  \
# EntityID
# 248711000003100001        WT          18  20250526     mouse   aging
# 248711000003100002        WT          18  20250526     mouse   aging
# 248711000003100005        WT          18  20250526     mouse   aging
# 248711000003100006        WT          18  20250526     mouse   aging
# 248711000003100010        WT          18  20250526     mouse   aging
# ...                      ...         ...       ...       ...     ...
# 248711000110100127        WT          18  20250526     mouse   aging
# 248711000110100128        WT          18  20250526     mouse   aging
# 248711000110100129        WT          18  20250526     mouse   aging
# 248711000110100130        WT          18  20250526     mouse   aging
# 248711000111100063        WT          18  20250526     mouse   aging
#
#                           sample  animal_id  condition
# EntityID
# 248711000003100001  aging_s11_r0        232      WT_18
# 248711000003100002  aging_s11_r0        232      WT_18
# 248711000003100005  aging_s11_r0        232      WT_18
# 248711000003100006  aging_s11_r0        232      WT_18
# 248711000003100010  aging_s11_r0        232      WT_18
# ...                          ...        ...        ...
# 248711000110100127  aging_s11_r0        232      WT_18
# 248711000110100128  aging_s11_r0        232      WT_18
# 248711000110100129  aging_s11_r0        232      WT_18
# 248711000110100130  aging_s11_r0        232      WT_18
# 248711000111100063  aging_s11_r0        232      WT_18
#
# [55471 rows x 57 columns]

# %%
logger.info("Done.")
# Out:
# 2025-11-10 19:07:28,944 [INFO]: Done.
