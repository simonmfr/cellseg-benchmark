# %%
# ruff: noqa
import argparse
import logging
import os
from os.path import join
import sys
import warnings

from spatialdata import read_zarr

sys.path.insert(1, "/dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark")

from cellseg_benchmark import sdata_utils as su
# Out:
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/__init__.py:44: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   return module_get_attr_redirect(attr_name, deprecated_mapping=_DEPRECATED)

# %%
# warnings.filterwarnings("ignore")

# %%
logger = logging.getLogger("shape_mapping")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setFormatter(logging.Formatter("%(asctime)s [%(levelname)s]: %(message)s"))
logger.addHandler(handler)

# %%
def get_args(test_args=None):  # noqa: D103
    p = argparse.ArgumentParser(
        description="Creates a master sdata for a given sample, containing multiple segmentation results."
    )
    p.add_argument("sample", help="Sample name.")
    p.add_argument(
        "data_path",
        help="Path to folder with merscope output data (e.g. /cohort1/slide2/region0).",
    )
    p.add_argument(
        "zmode",
        choices=["z3"],
        help="Mode of master sdata. Either 'z3' or '3d' (currently only z3 is implemented).",
    )
    p.add_argument("data_dir", help="Output data folder.")
    p.add_argument(
        "--n_ficture",
        default=21,
        type=int,
        help="Consider Ficture model with n_ficture factors.",
    )
    p.add_argument("--run_date", type=str, help="run date (YYYYMMDD).", default=None)
    p.add_argument("--organism", type=str, help="organism.", default=None)
    p.add_argument("--slide", type=str, help="slide.", default=None)
    p.add_argument("--region", type=str, help="region.", default=None)
    p.add_argument("--cohort", type=str, help="cohort.", default=None)
    p.add_argument(
        "--obs",
        action="append",
        default=[],
        metavar="KEY=VAL",
        help="Extra covariates to add to adata.obs (repeatable), e.g. --obs tissue=brain.",
    )
    if test_args is not None:
        return p.parse_args(test_args)
    else:
        return p.parse_args()

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "SynergyLung_s1_r0",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/Synergy-projects-temp/MouseLung-Sijia/output-20250704_AGLiesz-Sijia-MouseLung-Slide1-Stroke_VMSC03901/region_R1-Stroke",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "SynergyLung",
        "--slide",
        "1",
        "--region",
        "0",
        "--organism",
        "mouse",
        "--run_date",
        "20250704",
        "--obs",
        "condition=stroke",
    ]
)

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "aging_s11_r0",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "aging",
        "--slide",
        "11",
        "--region",
        "0",
        "--organism",
        "mouse",
        "--run_date",
        "20250526",
        "--obs",
        "genotype=WT",
        "--obs",
        "age_months=18",
        "--obs",
        "animal_id=232",
    ]
)

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "htra1_s4_r1",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20240829_Htra1-Slide04-cp-TG69-KO305/region_1-TG69",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "htra1",
        "--slide",
        "4",
        "--region",
        "1",
        "--organism",
        "mouse",
        "--run_date",
        "20240829",
        "--obs",
        "genotype=TG",
        "--obs",
        "age_months=6",
        "--obs",
        "animal_id=69",
    ]
)

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "aging_s11_r0",
        "/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m",
        "z3",
        "/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark",
        "--cohort",
        "aging",
        "--slide",
        "11",
        "--region",
        "0",
        "--organism",
        "mouse",
        "--run_date",
        "20250526",
        "--obs",
        "genotype=WT",
        "--obs",
        "age_months=18",
        "--obs",
        "animal_id=232",
    ]
)

# %%
args
# Out:
# Namespace(sample='aging_s11_r0', data_path='/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m', zmode='z3', data_dir='/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark', n_ficture=21, run_date='20250526', organism='mouse', slide='11', region='0', cohort='aging', obs=['genotype=WT', 'age_months=18', 'animal_id=232'])

# %%
NONES = {"", "None", "none", "null", "NULL", None}
for k in ["organism", "slide", "region", "cohort"]:
    if getattr(args, k) in NONES:
        setattr(args, k, None)

# %%
extra_obs = {}
for kv in args.obs:
    k, v = kv.split("=", 1)
    extra_obs[k] = None if v in NONES else v

# %%
extra_obs
# Out:
# {'genotype': 'WT', 'age_months': '18', 'animal_id': '232'}

# %%
# %%time
logger.info("Importing images and points...")
su.process_merscope(args.sample, args.data_dir, args.data_path, zmode=args.zmode)
# Out:
# 2025-11-21 12:54:01,761 [INFO]: Importing images and points...
# Skipping aging_s11_r0: z3 file already exists
# CPU times: user 0 ns, sys: 3.42 ms, total: 3.42 ms
# Wall time: 4.24 ms

# %%
sdata_path = join(args.data_dir, "samples", args.sample)
sdata_path
# Out:
# '/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/samples/aging_s11_r0'

# %%
sdata_main = read_zarr(join(sdata_path, "sdata_z3.zarr"))
# Out:
# version mismatch: detected: RasterFormatV02, requested: FormatV04
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)

# %%
sdata_main
# Out:
# SpatialData object, with associated Zarr store: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/samples/aging_s11_r0/sdata_z3.zarr
# ├── Images
# │     └── 'aging_s11_r0_z3': DataTree[cyx] (8, 35656, 65455), (8, 17828, 32727), (8, 8914, 16363), (8, 4457, 8181), (8, 2228, 4090)
# └── Points
#       └── 'aging_s11_r0_transcripts': DataFrame with shape: (<Delayed>, 9) (2D points)
# with coordinate systems:
#     ▸ 'global', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points)
#     ▸ 'micron', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points)
#     ▸ 'pixel', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points)

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs.columns

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["age_months"]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["genotype"]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["animal_id"]

# %%
logger.info("Integrating segmentation data from available methods into main sdata...")
seg_methods = [
    method
    for method in os.listdir(join(sdata_path, "results"))
    if os.path.isdir(join(sdata_path, "results", method, "sdata.zarr"))
]
# Out:
# 2025-11-21 12:54:17,080 [INFO]: Integrating segmentation data from available methods into main sdata...

# %%
seg_methods
# Out:
# ['Proseg_3D_Cellpose_1_nuclei_model',
#  'Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8',
#  'vpt_2D_DAPI_nuclei',
#  'Cellpose_1_nuclei_model',
#  'Baysor_2D_Cellpose_2_DAPI_PolyT_0.2',
#  'Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8',
#  'Negative_Control_Rastered_5',
#  'Cellpose_2_DAPI_PolyT',
#  'vpt_3D_DAPI_PolyT_nuclei',
#  'Proseg_3D_Cellpose_1_DAPI_Transcripts',
#  'Proseg_Cellpose_1_DAPI_Transcripts',
#  'Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2',
#  'Baysor_2D_Cellpose_1_DAPI_PolyT_0.2',
#  'Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2',
#  'Cellpose_1_DAPI_PolyT',
#  'Negative_Control_Rastered_10',
#  'Negative_Control_Voronoi',
#  'Proseg_3D_Cellpose_2_DAPI_PolyT',
#  'vpt_3D_DAPI_nuclei',
#  'Proseg_Cellpose_2_DAPI_Transcripts',
#  'ComSeg_Cellpose_1_nuclei_model',
#  'Proseg_Cellpose_1_nuclei_model',
#  'Cellpose_2_DAPI_Transcripts',
#  'Cellpose_1_Merlin',
#  'Negative_Control_Rastered_25',
#  'vpt_2D_DAPI_PolyT',
#  'Cellpose_1_DAPI_Transcripts',
#  'Proseg_3D_Cellpose_1_DAPI_PolyT',
#  'Baysor_2D_Cellpose_2_DAPI_PolyT_0.8',
#  'Baysor_2D_Cellpose_1_nuclei_model_1.0',
#  'vpt_2D_DAPI_PolyT_nuclei',
#  'vpt_3D_DAPI_PolyT',
#  'Proseg_Cellpose_2_DAPI_PolyT',
#  'Baysor_2D_Cellpose_1_DAPI_PolyT_0.8',
#  'Proseg_Cellpose_1_DAPI_PolyT']

# %%
# temp workaround
seg_methods = [
    s
    for s in seg_methods
    if not (s.startswith("Proseg_") and not s.startswith("Proseg_3D"))
]

# %%
seg_methods
# Out:
# ['Proseg_3D_Cellpose_1_nuclei_model',
#  'Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8',
#  'vpt_2D_DAPI_nuclei',
#  'Cellpose_1_nuclei_model',
#  'Baysor_2D_Cellpose_2_DAPI_PolyT_0.2',
#  'Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8',
#  'Negative_Control_Rastered_5',
#  'Cellpose_2_DAPI_PolyT',
#  'vpt_3D_DAPI_PolyT_nuclei',
#  'Proseg_3D_Cellpose_1_DAPI_Transcripts',
#  'Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2',
#  'Baysor_2D_Cellpose_1_DAPI_PolyT_0.2',
#  'Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2',
#  'Cellpose_1_DAPI_PolyT',
#  'Negative_Control_Rastered_10',
#  'Negative_Control_Voronoi',
#  'Proseg_3D_Cellpose_2_DAPI_PolyT',
#  'vpt_3D_DAPI_nuclei',
#  'ComSeg_Cellpose_1_nuclei_model',
#  'Cellpose_2_DAPI_Transcripts',
#  'Cellpose_1_Merlin',
#  'Negative_Control_Rastered_25',
#  'vpt_2D_DAPI_PolyT',
#  'Cellpose_1_DAPI_Transcripts',
#  'Proseg_3D_Cellpose_1_DAPI_PolyT',
#  'Baysor_2D_Cellpose_2_DAPI_PolyT_0.8',
#  'Baysor_2D_Cellpose_1_nuclei_model_1.0',
#  'vpt_2D_DAPI_PolyT_nuclei',
#  'vpt_3D_DAPI_PolyT',
#  'Baysor_2D_Cellpose_1_DAPI_PolyT_0.8']

# %%
extra_obs
# Out:
# {'genotype': 'WT', 'age_months': '18', 'animal_id': '232'}

# %%
args.data_path
# Out:
# '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m'

# %%
su.integrate_segmentation_data(
    sdata_path,
    seg_methods,
    sdata_main,
    run_date=args.run_date,
    organism=args.organism,
    slide=args.slide,
    region=args.region,
    cohort=args.cohort,
    write_to_disk=True,
    data_path=args.data_path,
    logger=logger,
    **extra_obs,
)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]2025-11-21 12:54:24,276 [INFO]: Adding Proseg_3D_Cellpose_1_nuclei_model...
# 2025-11-21 12:54:26,217 [INFO]: Adding shapes of Proseg_3D_Cellpose_1_nuclei_model...
# 2025-11-21 12:55:14,671 [INFO]: Adding adata for Proseg_3D_Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:55:14,744 [INFO]: Adding cell type annotations for Proseg_3D_Cellpose_1_nuclei_model...
# 2025-11-21 12:55:22,987 [INFO]: Collecting volume metadata for Proseg_3D_Cellpose_1_nuclei_model
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/__init__.py:44: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   return module_get_attr_redirect(attr_name, deprecated_mapping=_DEPRECATED)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/__init__.py:44: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   return module_get_attr_redirect(attr_name, deprecated_mapping=_DEPRECATED)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/__init__.py:44: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   return module_get_attr_redirect(attr_name, deprecated_mapping=_DEPRECATED)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/__init__.py:44: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   return module_get_attr_redirect(attr_name, deprecated_mapping=_DEPRECATED)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/__init__.py:44: FutureWarning: Importing read_text from `anndata` is deprecated. Import anndata.io.read_text instead.
#   return module_get_attr_redirect(attr_name, deprecated_mapping=_DEPRECATED)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:56:16,148 [INFO]: Adding Ficture stats to Proseg_3D_Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#   3%|▎         | 1/30 [01:54<55:22, 114.58s/it]2025-11-21 12:56:18,853 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# 2025-11-21 12:56:21,436 [INFO]: Adding shapes of Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# 2025-11-21 12:56:22,090 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:56:22,198 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# 2025-11-21 12:56:26,062 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:56:40,360 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#   7%|▋         | 2/30 [02:19<28:53, 61.91s/it] 2025-11-21 12:56:43,901 [INFO]: Adding vpt_2D_DAPI_nuclei...
# 2025-11-21 12:56:47,270 [INFO]: Adding shapes of vpt_2D_DAPI_nuclei...
# 2025-11-21 12:56:47,745 [INFO]: Adding adata for vpt_2D_DAPI_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:56:47,827 [INFO]: Adding cell type annotations for vpt_2D_DAPI_nuclei...
# 2025-11-21 12:56:49,695 [INFO]: Calculate volume metrics vpt_2D_DAPI_nuclei
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:56:57,063 [INFO]: Adding Ficture stats to vpt_2D_DAPI_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  10%|█         | 3/30 [02:36<18:32, 41.20s/it]2025-11-21 12:57:00,459 [INFO]: Adding Cellpose_1_nuclei_model...
# 2025-11-21 12:57:01,680 [INFO]: Adding shapes of Cellpose_1_nuclei_model...
# 2025-11-21 12:57:02,240 [INFO]: Adding adata for Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:57:02,289 [INFO]: Adding cell type annotations for Cellpose_1_nuclei_model...
# 2025-11-21 12:57:03,895 [INFO]: Calculate volume metrics Cellpose_1_nuclei_model
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:57:10,047 [INFO]: Adding Ficture stats to Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  13%|█▎        | 4/30 [02:48<12:54, 29.78s/it]2025-11-21 12:57:12,724 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# 2025-11-21 12:57:15,460 [INFO]: Adding shapes of Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# 2025-11-21 12:57:16,661 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:57:16,801 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# 2025-11-21 12:57:22,001 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_PolyT_0.2
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:57:41,366 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_PolyT_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  17%|█▋        | 5/30 [03:21<12:52, 30.88s/it]2025-11-21 12:57:45,560 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# 2025-11-21 12:57:48,446 [INFO]: Adding shapes of Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# 2025-11-21 12:57:49,577 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:57:49,686 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# 2025-11-21 12:57:53,661 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:58:09,628 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  20%|██        | 6/30 [03:49<11:59, 29.96s/it]2025-11-21 12:58:13,735 [INFO]: Adding Negative_Control_Rastered_5...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# 2025-11-21 12:58:25,162 [INFO]: Adding shapes of Negative_Control_Rastered_5...
# 2025-11-21 12:58:28,703 [INFO]: Adding adata for Negative_Control_Rastered_5...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_5` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 12:58:29,713 [INFO]: Adding cell type annotations for Negative_Control_Rastered_5...
# 2025-11-21 12:59:14,091 [INFO]: Calculate volume metrics Negative_Control_Rastered_5
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_5` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:01:55,781 [INFO]: Adding Ficture stats to Negative_Control_Rastered_5...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_5` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  23%|██▎       | 7/30 [07:48<37:37, 98.16s/it]2025-11-21 13:02:12,308 [INFO]: Adding Cellpose_2_DAPI_PolyT...
# 2025-11-21 13:02:13,497 [INFO]: Adding shapes of Cellpose_2_DAPI_PolyT...
# 2025-11-21 13:02:14,668 [INFO]: Adding adata for Cellpose_2_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_2_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:02:14,733 [INFO]: Adding cell type annotations for Cellpose_2_DAPI_PolyT...
# 2025-11-21 13:02:16,886 [INFO]: Calculate volume metrics Cellpose_2_DAPI_PolyT
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_2_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:02:24,355 [INFO]: Adding Ficture stats to Cellpose_2_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_2_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  27%|██▋       | 8/30 [08:03<26:20, 71.83s/it]2025-11-21 13:02:27,743 [INFO]: Adding vpt_3D_DAPI_PolyT_nuclei...
# 2025-11-21 13:02:31,158 [INFO]: Adding shapes of vpt_3D_DAPI_PolyT_nuclei...
# 2025-11-21 13:02:33,527 [INFO]: Adding adata for vpt_3D_DAPI_PolyT_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_PolyT_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:02:33,850 [INFO]: Adding cell type annotations for vpt_3D_DAPI_PolyT_nuclei...
# 2025-11-21 13:02:45,071 [INFO]: Collecting volume metadata for vpt_3D_DAPI_PolyT_nuclei
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_PolyT_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:04:34,328 [INFO]: Adding Ficture stats to vpt_3D_DAPI_PolyT_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_PolyT_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  30%|███       | 9/30 [10:15<31:44, 90.70s/it]2025-11-21 13:04:39,941 [INFO]: Adding Proseg_3D_Cellpose_1_DAPI_Transcripts...
# 2025-11-21 13:04:42,535 [INFO]: Adding shapes of Proseg_3D_Cellpose_1_DAPI_Transcripts...
# 2025-11-21 13:06:14,787 [INFO]: Adding adata for Proseg_3D_Cellpose_1_DAPI_Transcripts...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:06:14,874 [INFO]: Adding cell type annotations for Proseg_3D_Cellpose_1_DAPI_Transcripts...
# 2025-11-21 13:06:30,650 [INFO]: Collecting volume metadata for Proseg_3D_Cellpose_1_DAPI_Transcripts
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:08:06,712 [INFO]: Adding Ficture stats to Proseg_3D_Cellpose_1_DAPI_Transcripts...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  33%|███▎      | 10/30 [13:46<42:38, 127.94s/it]2025-11-21 13:08:11,264 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# 2025-11-21 13:08:14,083 [INFO]: Adding shapes of Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# 2025-11-21 13:08:16,013 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:08:16,157 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# 2025-11-21 13:08:21,433 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:08:40,845 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  37%|███▋      | 11/30 [14:21<31:28, 99.38s/it] 2025-11-21 13:08:45,899 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# 2025-11-21 13:08:48,331 [INFO]: Adding shapes of Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# 2025-11-21 13:08:50,428 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:08:50,581 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# 2025-11-21 13:08:55,996 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_PolyT_0.2
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:09:17,166 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_PolyT_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  40%|████      | 12/30 [14:57<24:03, 80.20s/it]2025-11-21 13:09:22,233 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# 2025-11-21 13:09:24,960 [INFO]: Adding shapes of Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# 2025-11-21 13:09:27,072 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:09:27,209 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# 2025-11-21 13:09:32,314 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:09:50,883 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  43%|████▎     | 13/30 [15:31<18:44, 66.12s/it]2025-11-21 13:09:55,942 [INFO]: Adding Cellpose_1_DAPI_PolyT...
# 2025-11-21 13:09:57,146 [INFO]: Adding shapes of Cellpose_1_DAPI_PolyT...
# 2025-11-21 13:09:58,979 [INFO]: Adding adata for Cellpose_1_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:09:59,030 [INFO]: Adding cell type annotations for Cellpose_1_DAPI_PolyT...
# 2025-11-21 13:10:00,642 [INFO]: Calculate volume metrics Cellpose_1_DAPI_PolyT
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:10:06,542 [INFO]: Adding Ficture stats to Cellpose_1_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  47%|████▋     | 14/30 [15:45<13:27, 50.46s/it]2025-11-21 13:10:10,232 [INFO]: Adding Negative_Control_Rastered_10...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# 2025-11-21 13:10:14,611 [INFO]: Adding shapes of Negative_Control_Rastered_10...
# 2025-11-21 13:10:17,098 [INFO]: Adding adata for Negative_Control_Rastered_10...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_10` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:10:17,371 [INFO]: Adding cell type annotations for Negative_Control_Rastered_10...
# 2025-11-21 13:10:27,686 [INFO]: Calculate volume metrics Negative_Control_Rastered_10
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_10` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:11:08,860 [INFO]: Adding Ficture stats to Negative_Control_Rastered_10...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_10` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  50%|█████     | 15/30 [16:52<13:47, 55.20s/it]2025-11-21 13:11:16,396 [INFO]: Adding Negative_Control_Voronoi...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# 2025-11-21 13:11:20,012 [INFO]: Adding shapes of Negative_Control_Voronoi...
# 2025-11-21 13:11:22,699 [INFO]: Adding adata for Negative_Control_Voronoi...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Voronoi` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:11:22,935 [INFO]: Adding cell type annotations for Negative_Control_Voronoi...
# 2025-11-21 13:11:34,303 [INFO]: Calculate volume metrics Negative_Control_Voronoi
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Voronoi` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:12:08,898 [INFO]: Adding Ficture stats to Negative_Control_Voronoi...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Voronoi` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  53%|█████▎    | 16/30 [17:52<13:14, 56.77s/it]2025-11-21 13:12:16,830 [INFO]: Adding Proseg_3D_Cellpose_2_DAPI_PolyT...
# 2025-11-21 13:12:18,996 [INFO]: Adding shapes of Proseg_3D_Cellpose_2_DAPI_PolyT...
# 2025-11-21 13:13:22,558 [INFO]: Adding adata for Proseg_3D_Cellpose_2_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_2_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:13:22,629 [INFO]: Adding cell type annotations for Proseg_3D_Cellpose_2_DAPI_PolyT...
# 2025-11-21 13:13:33,651 [INFO]: Collecting volume metadata for Proseg_3D_Cellpose_2_DAPI_PolyT
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_2_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:14:40,505 [INFO]: Adding Ficture stats to Proseg_3D_Cellpose_2_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_2_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  57%|█████▋    | 17/30 [20:21<18:16, 84.36s/it]2025-11-21 13:14:45,334 [INFO]: Adding vpt_3D_DAPI_nuclei...
# 2025-11-21 13:14:47,810 [INFO]: Adding shapes of vpt_3D_DAPI_nuclei...
# 2025-11-21 13:14:50,942 [INFO]: Adding adata for vpt_3D_DAPI_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:14:51,025 [INFO]: Adding cell type annotations for vpt_3D_DAPI_nuclei...
# 2025-11-21 13:15:00,010 [INFO]: Collecting volume metadata for vpt_3D_DAPI_nuclei
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:15:54,191 [INFO]: Adding Ficture stats to vpt_3D_DAPI_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  60%|██████    | 18/30 [21:35<16:15, 81.32s/it]2025-11-21 13:15:59,588 [INFO]: Adding ComSeg_Cellpose_1_nuclei_model...
# 2025-11-21 13:16:01,077 [INFO]: Adding shapes of ComSeg_Cellpose_1_nuclei_model...
# 2025-11-21 13:16:03,446 [INFO]: Adding adata for ComSeg_Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_ComSeg_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:16:03,496 [WARNING]: No annotation files found for ComSeg_Cellpose_1_nuclei_model. Skipping
# 2025-11-21 13:16:04,629 [INFO]: Calculate volume metrics ComSeg_Cellpose_1_nuclei_model
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_ComSeg_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:16:10,519 [INFO]: Adding Ficture stats to ComSeg_Cellpose_1_nuclei_model...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_ComSeg_Cellpose_1_nuclei_model` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  63%|██████▎   | 19/30 [21:50<11:15, 61.43s/it]2025-11-21 13:16:14,685 [INFO]: Adding Cellpose_2_DAPI_Transcripts...
# 2025-11-21 13:16:16,047 [INFO]: Adding shapes of Cellpose_2_DAPI_Transcripts...
# 2025-11-21 13:16:18,680 [INFO]: Adding adata for Cellpose_2_DAPI_Transcripts...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_2_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:16:18,755 [INFO]: Adding cell type annotations for Cellpose_2_DAPI_Transcripts...
# 2025-11-21 13:16:21,272 [INFO]: Calculate volume metrics Cellpose_2_DAPI_Transcripts
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_2_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:16:30,769 [INFO]: Adding Ficture stats to Cellpose_2_DAPI_Transcripts...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_2_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  67%|██████▋   | 20/30 [22:11<08:12, 49.29s/it]2025-11-21 13:16:35,679 [INFO]: Adding Cellpose_1_Merlin...
# 2025-11-21 13:16:39,252 [INFO]: Adding shapes of Cellpose_1_Merlin...
# 2025-11-21 13:16:42,141 [INFO]: Adding adata for Cellpose_1_Merlin...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_Merlin` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:16:42,246 [INFO]: Adding cell type annotations for Cellpose_1_Merlin...
# 2025-11-21 13:16:44,689 [INFO]: Calculate volume metrics Cellpose_1_Merlin
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_Merlin` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:16:54,861 [INFO]: Adding Ficture stats to Cellpose_1_Merlin...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_Merlin` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  70%|███████   | 21/30 [22:36<06:18, 42.03s/it]2025-11-21 13:17:00,789 [INFO]: Adding Negative_Control_Rastered_25...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# 2025-11-21 13:17:02,733 [INFO]: Adding shapes of Negative_Control_Rastered_25...
# 2025-11-21 13:17:05,718 [INFO]: Adding adata for Negative_Control_Rastered_25...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_25` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:17:05,780 [INFO]: Adding cell type annotations for Negative_Control_Rastered_25...
# 2025-11-21 13:17:07,547 [INFO]: Calculate volume metrics Negative_Control_Rastered_25
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_25` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:17:14,642 [INFO]: Adding Ficture stats to Negative_Control_Rastered_25...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Negative_Control_Rastered_25` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  73%|███████▎  | 22/30 [22:55<04:40, 35.03s/it]2025-11-21 13:17:19,486 [INFO]: Adding vpt_2D_DAPI_PolyT...
# 2025-11-21 13:17:23,272 [INFO]: Adding shapes of vpt_2D_DAPI_PolyT...
# 2025-11-21 13:17:26,584 [INFO]: Adding adata for vpt_2D_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:17:26,701 [INFO]: Adding cell type annotations for vpt_2D_DAPI_PolyT...
# 2025-11-21 13:17:29,275 [INFO]: Calculate volume metrics vpt_2D_DAPI_PolyT
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:17:40,934 [INFO]: Adding Ficture stats to vpt_2D_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  77%|███████▋  | 23/30 [23:22<03:49, 32.77s/it]2025-11-21 13:17:46,994 [INFO]: Adding Cellpose_1_DAPI_Transcripts...
# 2025-11-21 13:17:48,762 [INFO]: Adding shapes of Cellpose_1_DAPI_Transcripts...
# 2025-11-21 13:17:52,431 [INFO]: Adding adata for Cellpose_1_DAPI_Transcripts...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:17:52,524 [INFO]: Adding cell type annotations for Cellpose_1_DAPI_Transcripts...
# 2025-11-21 13:17:55,131 [INFO]: Calculate volume metrics Cellpose_1_DAPI_Transcripts
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:18:05,133 [INFO]: Adding Ficture stats to Cellpose_1_DAPI_Transcripts...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Cellpose_1_DAPI_Transcripts` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  80%|████████  | 24/30 [23:46<03:00, 30.03s/it]2025-11-21 13:18:10,628 [INFO]: Adding Proseg_3D_Cellpose_1_DAPI_PolyT...
# 2025-11-21 13:18:12,523 [INFO]: Adding shapes of Proseg_3D_Cellpose_1_DAPI_PolyT...
# 2025-11-21 13:18:59,153 [INFO]: Adding adata for Proseg_3D_Cellpose_1_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:18:59,209 [INFO]: Adding cell type annotations for Proseg_3D_Cellpose_1_DAPI_PolyT...
# 2025-11-21 13:19:07,208 [INFO]: Collecting volume metadata for Proseg_3D_Cellpose_1_DAPI_PolyT
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:19:55,906 [INFO]: Adding Ficture stats to Proseg_3D_Cellpose_1_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Proseg_3D_Cellpose_1_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  83%|████████▎ | 25/30 [25:37<04:31, 54.28s/it]2025-11-21 13:20:01,496 [INFO]: Adding Baysor_2D_Cellpose_2_DAPI_PolyT_0.8...
# 2025-11-21 13:20:04,021 [INFO]: Adding shapes of Baysor_2D_Cellpose_2_DAPI_PolyT_0.8...
# 2025-11-21 13:20:08,540 [INFO]: Adding adata for Baysor_2D_Cellpose_2_DAPI_PolyT_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:20:08,676 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_2_DAPI_PolyT_0.8...
# 2025-11-21 13:20:12,997 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_2_DAPI_PolyT_0.8
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:20:29,223 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_2_DAPI_PolyT_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  87%|████████▋ | 26/30 [26:11<03:13, 48.34s/it]2025-11-21 13:20:35,973 [INFO]: Adding Baysor_2D_Cellpose_1_nuclei_model_1.0...
# 2025-11-21 13:20:38,252 [INFO]: Adding shapes of Baysor_2D_Cellpose_1_nuclei_model_1.0...
# 2025-11-21 13:20:44,041 [INFO]: Adding adata for Baysor_2D_Cellpose_1_nuclei_model_1.0...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_nuclei_model_1.0` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:20:44,186 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_nuclei_model_1.0...
# 2025-11-21 13:20:49,301 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_nuclei_model_1.0
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_nuclei_model_1.0` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:21:07,619 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_nuclei_model_1.0...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_nuclei_model_1.0` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  90%|█████████ | 27/30 [26:50<02:16, 45.59s/it]2025-11-21 13:21:15,145 [INFO]: Adding vpt_2D_DAPI_PolyT_nuclei...
# 2025-11-21 13:21:17,742 [INFO]: Adding shapes of vpt_2D_DAPI_PolyT_nuclei...
# 2025-11-21 13:21:25,331 [INFO]: Adding adata for vpt_2D_DAPI_PolyT_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_PolyT_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:21:25,449 [INFO]: Adding cell type annotations for vpt_2D_DAPI_PolyT_nuclei...
# 2025-11-21 13:21:27,989 [INFO]: Calculate volume metrics vpt_2D_DAPI_PolyT_nuclei
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_PolyT_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:21:38,400 [INFO]: Adding Ficture stats to vpt_2D_DAPI_PolyT_nuclei...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_2D_DAPI_PolyT_nuclei` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  93%|█████████▎| 28/30 [27:23<01:23, 41.81s/it]2025-11-21 13:21:48,133 [INFO]: Adding vpt_3D_DAPI_PolyT...
# 2025-11-21 13:21:52,075 [INFO]: Adding shapes of vpt_3D_DAPI_PolyT...
# 2025-11-21 13:22:02,782 [INFO]: Adding adata for vpt_3D_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:22:02,948 [INFO]: Adding cell type annotations for vpt_3D_DAPI_PolyT...
# 2025-11-21 13:22:11,229 [INFO]: Collecting volume metadata for vpt_3D_DAPI_PolyT
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:23:55,373 [INFO]: Adding Ficture stats to vpt_3D_DAPI_PolyT...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_vpt_3D_DAPI_PolyT` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
#  97%|█████████▋| 29/30 [29:41<01:10, 70.64s/it]2025-11-21 13:24:06,055 [INFO]: Adding Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# 2025-11-21 13:24:08,650 [INFO]: Adding shapes of Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# 2025-11-21 13:24:17,825 [INFO]: Adding adata for Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:24:17,963 [INFO]: Adding cell type annotations for Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# 2025-11-21 13:24:22,755 [INFO]: Calculate volume metrics Baysor_2D_Cellpose_1_DAPI_PolyT_0.8
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 2025-11-21 13:24:41,387 [INFO]: Adding Ficture stats to Baysor_2D_Cellpose_1_DAPI_PolyT_0.8...
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/spatialdata/_core/_elements.py:125: UserWarning: Key `adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8` already exists. Overwriting it in-memory.
#   self._check_key(key, self.keys(), self._shared_keys)
# 100%|██████████| 30/30 [30:30<00:00, 61.02s/it]
# SpatialData object, with associated Zarr store: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/samples/aging_s11_r0/sdata_z3.zarr
# ├── Images
# │     └── 'aging_s11_r0_z3': DataTree[cyx] (8, 35656, 65455), (8, 17828, 32727), (8, 8914, 16363), (8, 4457, 8181), (8, 2228, 4090)
# ├── Points
# │     └── 'aging_s11_r0_transcripts': DataFrame with shape: (<Delayed>, 9) (2D points)
# ├── Shapes
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2': GeoDataFrame shape: (128972, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8': GeoDataFrame shape: (113076, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2': GeoDataFrame shape: (122471, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8': GeoDataFrame shape: (92417, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0': GeoDataFrame shape: (121914, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2': GeoDataFrame shape: (123512, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8': GeoDataFrame shape: (100144, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2': GeoDataFrame shape: (120557, 1) (2D shapes)
# │     ├── 'boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8': GeoDataFrame shape: (89977, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (35248, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (66718, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_Merlin': GeoDataFrame shape: (55471, 9) (2D shapes)
# │     ├── 'boundaries_Cellpose_1_nuclei_model': GeoDataFrame shape: (35649, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (48076, 1) (2D shapes)
# │     ├── 'boundaries_Cellpose_2_DAPI_Transcripts': GeoDataFrame shape: (57575, 1) (2D shapes)
# │     ├── 'boundaries_ComSeg_Cellpose_1_nuclei_model': GeoDataFrame shape: (35649, 1) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Rastered_5': GeoDataFrame shape: (1090194, 3) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Rastered_10': GeoDataFrame shape: (272902, 3) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Rastered_25': GeoDataFrame shape: (43865, 3) (2D shapes)
# │     ├── 'boundaries_Negative_Control_Voronoi': GeoDataFrame shape: (221959, 1) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT': GeoDataFrame shape: (245914, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts': GeoDataFrame shape: (464552, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_1_nuclei_model': GeoDataFrame shape: (249409, 4) (2D shapes)
# │     ├── 'boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT': GeoDataFrame shape: (335248, 4) (2D shapes)
# │     ├── 'boundaries_vpt_2D_DAPI_PolyT': GeoDataFrame shape: (59793, 9) (2D shapes)
# │     ├── 'boundaries_vpt_2D_DAPI_PolyT_nuclei': GeoDataFrame shape: (58377, 9) (2D shapes)
# │     ├── 'boundaries_vpt_2D_DAPI_nuclei': GeoDataFrame shape: (41105, 9) (2D shapes)
# │     ├── 'boundaries_vpt_3D_DAPI_PolyT': GeoDataFrame shape: (268625, 5) (2D shapes)
# │     ├── 'boundaries_vpt_3D_DAPI_PolyT_nuclei': GeoDataFrame shape: (322483, 5) (2D shapes)
# │     └── 'boundaries_vpt_3D_DAPI_nuclei': GeoDataFrame shape: (264165, 5) (2D shapes)
# └── Tables
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2': AnnData (128972, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8': AnnData (113076, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2': AnnData (122471, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8': AnnData (92417, 500)
#       ├── 'adata_Baysor_2D_Cellpose_1_nuclei_model_1.0': AnnData (121914, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2': AnnData (123512, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8': AnnData (100144, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2': AnnData (120557, 500)
#       ├── 'adata_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8': AnnData (89977, 500)
#       ├── 'adata_Cellpose_1_DAPI_PolyT': AnnData (35248, 500)
#       ├── 'adata_Cellpose_1_DAPI_Transcripts': AnnData (66718, 500)
#       ├── 'adata_Cellpose_1_Merlin': AnnData (55471, 500)
#       ├── 'adata_Cellpose_1_nuclei_model': AnnData (35649, 500)
#       ├── 'adata_Cellpose_2_DAPI_PolyT': AnnData (48076, 500)
#       ├── 'adata_Cellpose_2_DAPI_Transcripts': AnnData (57575, 500)
#       ├── 'adata_ComSeg_Cellpose_1_nuclei_model': AnnData (35649, 500)
#       ├── 'adata_Negative_Control_Rastered_5': AnnData (1090194, 500)
#       ├── 'adata_Negative_Control_Rastered_10': AnnData (272902, 500)
#       ├── 'adata_Negative_Control_Rastered_25': AnnData (43865, 500)
#       ├── 'adata_Negative_Control_Voronoi': AnnData (221959, 500)
#       ├── 'adata_Proseg_3D_Cellpose_1_DAPI_PolyT': AnnData (35135, 500)
#       ├── 'adata_Proseg_3D_Cellpose_1_DAPI_Transcripts': AnnData (66376, 500)
#       ├── 'adata_Proseg_3D_Cellpose_1_nuclei_model': AnnData (35639, 500)
#       ├── 'adata_Proseg_3D_Cellpose_2_DAPI_PolyT': AnnData (47927, 500)
#       ├── 'adata_vpt_2D_DAPI_PolyT': AnnData (59793, 500)
#       ├── 'adata_vpt_2D_DAPI_PolyT_nuclei': AnnData (58377, 500)
#       ├── 'adata_vpt_2D_DAPI_nuclei': AnnData (41105, 500)
#       ├── 'adata_vpt_3D_DAPI_PolyT': AnnData (85159, 500)
#       ├── 'adata_vpt_3D_DAPI_PolyT_nuclei': AnnData (83790, 500)
#       └── 'adata_vpt_3D_DAPI_nuclei': AnnData (41480, 500)
# with coordinate systems:
#     ▸ 'global', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)
#     ▸ 'micron', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)
#     ▸ 'pixel', with elements:
#         aging_s11_r0_z3 (Images), aging_s11_r0_transcripts (Points), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_1_DAPI_Transcripts_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_1_nuclei_model_1.0 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_PolyT_0.8 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.2 (Shapes), boundaries_Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8 (Shapes), boundaries_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Cellpose_1_Merlin (Shapes), boundaries_Cellpose_1_nuclei_model (Shapes), boundaries_Cellpose_2_DAPI_PolyT (Shapes), boundaries_Cellpose_2_DAPI_Transcripts (Shapes), boundaries_ComSeg_Cellpose_1_nuclei_model (Shapes), boundaries_Negative_Control_Rastered_5 (Shapes), boundaries_Negative_Control_Rastered_10 (Shapes), boundaries_Negative_Control_Rastered_25 (Shapes), boundaries_Negative_Control_Voronoi (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_PolyT (Shapes), boundaries_Proseg_3D_Cellpose_1_DAPI_Transcripts (Shapes), boundaries_Proseg_3D_Cellpose_1_nuclei_model (Shapes), boundaries_Proseg_3D_Cellpose_2_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT (Shapes), boundaries_vpt_2D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_2D_DAPI_nuclei (Shapes), boundaries_vpt_3D_DAPI_PolyT (Shapes), boundaries_vpt_3D_DAPI_PolyT_nuclei (Shapes), boundaries_vpt_3D_DAPI_nuclei (Shapes)

# %%
# test sdata #################

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs
# Out:
#            region slide                          spt_region  \
# aaaaaaaa-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaab-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaac-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaad-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaaaae-1      0    11  boundaries_Cellpose_1_nuclei_model
# ...           ...   ...                                 ...
# aaaaildm-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaildn-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaildo-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaaildp-1      0    11  boundaries_Cellpose_1_nuclei_model
# aaaailea-1      0    11  boundaries_Cellpose_1_nuclei_model
#
#            cell_type_incl_low_quality_revised  \
# aaaaaaaa-1                   Oligodendrocytes
# aaaaaaab-1                   Oligodendrocytes
# aaaaaaac-1                   Oligodendrocytes
# aaaaaaad-1                   Oligodendrocytes
# aaaaaaae-1                   Oligodendrocytes
# ...                                       ...
# aaaaildm-1                       Neurons-Glut
# aaaaildn-1                   Oligodendrocytes
# aaaaildo-1                                ECs
# aaaaildp-1                       Neurons-Glut
# aaaailea-1                       Neurons-Glut
#
#            cell_type_mmc_incl_low_quality_clusters  \
# aaaaaaaa-1                          Choroid-Plexus
# aaaaaaab-1                        Oligodendrocytes
# aaaaaaac-1                        Oligodendrocytes
# aaaaaaad-1                        Oligodendrocytes
# aaaaaaae-1                          Choroid-Plexus
# ...                                            ...
# aaaaildm-1                            Neurons-Glut
# aaaaildn-1                            Neurons-Glut
# aaaaildo-1                                     ECs
# aaaaildp-1                            Neurons-Glut
# aaaailea-1                            Neurons-Glut
#
#            cell_type_mmc_incl_low_quality cell_type_incl_mixed_revised  \
# aaaaaaaa-1                     Astrocytes             Oligodendrocytes
# aaaaaaab-1                     Astrocytes             Oligodendrocytes
# aaaaaaac-1               Oligodendrocytes             Oligodendrocytes
# aaaaaaad-1               Oligodendrocytes             Oligodendrocytes
# aaaaaaae-1               Oligodendrocytes             Oligodendrocytes
# ...                                   ...                          ...
# aaaaildm-1                   Neurons-Glut                 Neurons-Glut
# aaaaildn-1                   Neurons-Glut             Oligodendrocytes
# aaaaildo-1                            ECs                          ECs
# aaaaildp-1                   Neurons-Glut                 Neurons-Glut
# aaaailea-1                      Undefined                 Neurons-Glut
#
#            cell_type_mmc_incl_mixed_clusters cell_type_mmc_incl_mixed  \
# aaaaaaaa-1                             Mixed                    Mixed
# aaaaaaab-1                  Oligodendrocytes                    Mixed
# aaaaaaac-1                  Oligodendrocytes         Oligodendrocytes
# aaaaaaad-1                  Oligodendrocytes         Oligodendrocytes
# aaaaaaae-1                             Mixed         Oligodendrocytes
# ...                                      ...                      ...
# aaaaildm-1                      Neurons-Glut             Neurons-Glut
# aaaaildn-1                      Neurons-Glut             Neurons-Glut
# aaaaildo-1                               ECs                      ECs
# aaaaildp-1                      Neurons-Glut             Neurons-Glut
# aaaailea-1                      Neurons-Glut             Neurons-Glut
#
#            cell_type_revised  ...  solidity elongation genotype  age_months  \
# aaaaaaaa-1  Oligodendrocytes  ...  0.956813   0.337908       WT          18
# aaaaaaab-1  Oligodendrocytes  ...  1.000000   0.113391       WT          18
# aaaaaaac-1  Oligodendrocytes  ...  1.000000   0.098323       WT          18
# aaaaaaad-1  Oligodendrocytes  ...  1.000000   0.228436       WT          18
# aaaaaaae-1  Oligodendrocytes  ...  1.000000   0.083886       WT          18
# ...                      ...  ...       ...        ...      ...         ...
# aaaaildm-1      Neurons-Glut  ...  0.997871   0.108961       WT          18
# aaaaildn-1  Oligodendrocytes  ...  0.989197   0.240081       WT          18
# aaaaildo-1               ECs  ...  1.000000   0.018043       WT          18
# aaaaildp-1      Neurons-Glut  ...  0.968743   0.055256       WT          18
# aaaailea-1      Neurons-Glut  ...  0.990032   0.207281       WT          18
#
#             run_date  organism  cohort        sample  animal_id  condition
# aaaaaaaa-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaab-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaac-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaad-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaaaae-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# ...              ...       ...     ...           ...        ...        ...
# aaaaildm-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaildn-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaildo-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaaildp-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
# aaaailea-1  20250526     mouse   aging  aging_s11_r0        232      WT_18
#
# [35649 rows x 30 columns]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs.columns
# Out:
# Index(['region', 'slide', 'spt_region', 'cell_type_incl_low_quality_revised',
#        'cell_type_mmc_incl_low_quality_clusters',
#        'cell_type_mmc_incl_low_quality', 'cell_type_incl_mixed_revised',
#        'cell_type_mmc_incl_mixed_clusters', 'cell_type_mmc_incl_mixed',
#        'cell_type_revised', 'cell_type_mmc_raw_clusters', 'cell_type_mmc_raw',
#        'cell_id', 'area', 'volume_sum', 'volume_final', 'num_z_planes',
#        'size_normalized', 'surface_to_volume_ratio', 'sphericity', 'solidity',
#        'elongation', 'genotype', 'age_months', 'run_date', 'organism',
#        'cohort', 'sample', 'animal_id', 'condition'],
#       dtype='object')

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["age_months"]

# %%
sdata_main.tables["adata_Cellpose_1_nuclei_model"].obs["condition"]

# %%
sdata_main.tables["adata_Cellpose_1_Merlin"].obs.columns
# Out:
# Index(['fov', 'volume', 'center_x', 'center_y', 'min_x', 'min_y', 'max_x',
#        'max_y', 'anisotropy', 'transcript_count', 'perimeter_area_ratio',
#        'Fth1_raw', 'Fth1_high_pass', 'DAPI_raw', 'DAPI_high_pass', 'App_raw',
#        'App_high_pass', 'Aldoc_raw', 'Aldoc_high_pass', 'Sst_raw',
#        'Sst_high_pass', 'Plp1_raw', 'Plp1_high_pass', 'PolyT_raw',
#        'PolyT_high_pass', 'region', 'slide', 'dataset_id', 'cells_region',
#        'spt_region', 'cell_type_incl_low_quality_revised',
#        'cell_type_mmc_incl_low_quality_clusters',
#        'cell_type_mmc_incl_low_quality', 'cell_type_incl_mixed_revised',
#        'cell_type_mmc_incl_mixed_clusters', 'cell_type_mmc_incl_mixed',
#        'cell_type_revised', 'cell_type_mmc_raw_clusters', 'cell_type_mmc_raw',
#        'cell_id', 'area', 'volume_sum', 'volume_final', 'num_z_planes',
#        'size_normalized', 'surface_to_volume_ratio', 'sphericity', 'solidity',
#        'elongation', 'genotype', 'age_months', 'run_date', 'organism',
#        'cohort', 'sample', 'animal_id', 'condition'],
#       dtype='object')

# %%
sdata_main.tables["adata_Cellpose_1_Merlin"].obs
# Out:
#                     fov       volume      center_x      center_y  \
# EntityID
# 248711000003100001  417   808.562111   7231.107147   7198.372446
# 248711000003100002  417   266.361792   7248.592975   7195.647341
# 248711000003100005  417   198.258304   7272.734791   7195.519228
# 248711000003100006  417   360.645661   7285.561699   7196.026506
# 248711000003100010  417   259.700561   7246.363524   7199.820553
# ...                 ...          ...           ...           ...
# 248711000110100127   40  1136.350842  11615.779651  10804.572500
# 248711000110100128   40  1429.615413  11598.700329  10813.752208
# 248711000110100129   40  1275.092968  11571.393604  10818.085659
# 248711000110100130   40   459.810753  11475.060957  10830.734862
# 248711000111100063   14    79.820706  12066.580812  10640.203908
#
#                            min_x         min_y         max_x         max_y  \
# EntityID
# 248711000003100001   7226.604490   7193.764156   7235.853920   7202.938191
# 248711000003100002   7244.526919   7193.764156   7252.066519   7198.191981
# 248711000003100005   7269.911928   7193.764156   7275.837170   7197.394793
# 248711000003100006   7281.029287   7193.788223   7289.651378   7198.719600
# 248711000003100010   7243.445775   7196.495046   7249.041249   7203.355593
# ...                          ...           ...           ...           ...
# 248711000110100127  11610.101084  10798.694083  11622.200637  10810.839648
# 248711000110100128  11591.881941  10806.229373  11605.488999  10820.481903
# 248711000110100129  11565.165457  10810.545320  11576.349561  10824.972732
# 248711000110100130  11470.911481  10827.032940  11479.611647  10834.051085
# 248711000111100063  12064.746971  10638.854103  12068.237773  10641.506134
#
#                     anisotropy  transcript_count  ...  solidity  elongation  \
# EntityID                                          ...
# 248711000003100001    1.013078                 0  ...  1.000000    0.096341
# 248711000003100002    1.704450                 0  ...  1.000000    0.210849
# 248711000003100005    1.647894                 0  ...  1.000000    0.006583
# 248711000003100006    1.755867                 0  ...  1.000000    0.256885
# 248711000003100010    1.636452                 0  ...  1.000000    0.375512
# ...                        ...               ...  ...       ...         ...
# 248711000110100127    1.242970                 1  ...  0.985538    0.216094
# 248711000110100128    1.017308                 2  ...  0.995633    0.040381
# 248711000110100129    1.289438                 2  ...  0.990718    0.100072
# 248711000110100130    1.323253                12  ...  1.000000    0.183094
# 248711000111100063    1.326681                 0  ...  1.000000    0.051042
#
#                     genotype  age_months  run_date  organism  cohort  \
# EntityID
# 248711000003100001        WT          18  20250526     mouse   aging
# 248711000003100002        WT          18  20250526     mouse   aging
# 248711000003100005        WT          18  20250526     mouse   aging
# 248711000003100006        WT          18  20250526     mouse   aging
# 248711000003100010        WT          18  20250526     mouse   aging
# ...                      ...         ...       ...       ...     ...
# 248711000110100127        WT          18  20250526     mouse   aging
# 248711000110100128        WT          18  20250526     mouse   aging
# 248711000110100129        WT          18  20250526     mouse   aging
# 248711000110100130        WT          18  20250526     mouse   aging
# 248711000111100063        WT          18  20250526     mouse   aging
#
#                           sample  animal_id  condition
# EntityID
# 248711000003100001  aging_s11_r0        232      WT_18
# 248711000003100002  aging_s11_r0        232      WT_18
# 248711000003100005  aging_s11_r0        232      WT_18
# 248711000003100006  aging_s11_r0        232      WT_18
# 248711000003100010  aging_s11_r0        232      WT_18
# ...                          ...        ...        ...
# 248711000110100127  aging_s11_r0        232      WT_18
# 248711000110100128  aging_s11_r0        232      WT_18
# 248711000110100129  aging_s11_r0        232      WT_18
# 248711000110100130  aging_s11_r0        232      WT_18
# 248711000111100063  aging_s11_r0        232      WT_18
#
# [55471 rows x 57 columns]

# %%
logger.info("Done.")
# Out:
# 2025-11-21 13:25:21,492 [INFO]: Done.

# %%
sdata_path = join(args.data_dir, "samples", "aging_s1_r0")

# %%
# test boundaries #################

# %%
import gzip
import io
import logging
import geopandas as gpd

seg_method = "Proseg_3D_Cellpose_1_DAPI_Transcripts"
boundary_file = join(
    sdata_path,
    "results",
    seg_method,
    "sdata.zarr",
    ".sopa_cache",
    "transcript_patches",
    "0",
    "cell-polygons-layers.geojson.gz",
)

# 1. Load boundary GeoJSON as DataFrame
with gzip.open(boundary_file, "rt", encoding="utf-8") as f:
    geojson_text = f.read()
gdf = gpd.read_file(io.StringIO(geojson_text))

# %%
print("Loaded boundaries shape:", gdf.shape)
print("Boundary columns:", gdf.columns)
print(gdf.head())
# Out:
# Loaded boundaries shape: (744836, 3)
# Boundary columns: Index(['cell', 'layer', 'geometry'], dtype='object')
#    cell  layer                                           geometry
# 0     0      0  MULTIPOLYGON (((5065.7813 5726.773, 5065.7813 ...
# 1     0      1  MULTIPOLYGON (((5065.7813 5724.773, 5065.7813 ...
# 2     0      2  MULTIPOLYGON (((5064.7813 5726.773, 5064.7813 ...
# 3     0      3  MULTIPOLYGON (((5066.7813 5725.773, 5066.7813 ...
# 4     0      4  MULTIPOLYGON (((5068.7813 5725.773, 5068.7813 ...

# %%
gdf.shape
# Out:
# (744836, 3)

# %%
print("Loaded boundaries shape:", gdf.shape)
print("Boundary columns:", gdf.columns)
print(gdf.head())
# Out:
# Loaded boundaries shape: (338478, 3)
# Boundary columns: Index(['cell', 'layer', 'geometry'], dtype='object')
#    cell  layer                                           geometry
# 0     0      0  MULTIPOLYGON (((7609 8946, 7609 8945, 7610 894...
# 1     0      1  MULTIPOLYGON (((7608 8949, 7608 8950, 7609 895...
# 2     1      0  MULTIPOLYGON (((6640 8576, 6640 8580, 6642 858...
# 3     1      1  MULTIPOLYGON (((6641 8579, 6641 8581, 6642 858...
# 4     1      2  MULTIPOLYGON (((6645 8581, 6645 8586, 6648 858...

# %%
gdf.shape
# Out:
# (338478, 3)

# %%
# 2. Check for required columns
expected_cols = ["cell", "cell_id"]
missing = [col for col in expected_cols if col not in gdf.columns]
print("Missing columns in boundaries:", missing)
# Out:
# Missing columns in boundaries: ['cell_id']

# %%
# 4. Simulate annotation table (replace with your actual)
adata_obs = pd.DataFrame(
    {
        "cell": gdf["cell"].unique(),
        "cell_id": gdf["cell_id"].unique(),
        "dummy": range(len(gdf["cell"].unique())),
    }
)
print("Annotation table shape:", adata_obs.shape)

# 5. Merge boundaries with annotation
merged = gdf.merge(adata_obs[["cell", "cell_id"]], on="cell")
print("Merged boundaries shape:", merged.shape)
print(merged.head())

# 6. Any cells missing from boundaries?
missing_cells = set(adata_obs["cell"]) - set(gdf["cell"])
print("Cells in annotation not in boundaries:", len(missing_cells))

# 7. Downstream: Create dummy morphology DataFrame and test merge
df_morph = pd.DataFrame(
    {
        "cell_id": gdf["cell_id"],
        "volume": [42] * len(gdf),  # dummy
    }
)
merged_obs = adata_obs.merge(df_morph, on="cell_id", how="left")
print("Merge with morphology (for .obs) shape:", merged_obs.shape)
print(merged_obs.head())
print("Number of missing volume values:", merged_obs["volume"].isnull().sum())
