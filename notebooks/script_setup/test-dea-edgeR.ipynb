# %%
# ruff: noqa
import argparse
import logging
import re
import sys
import warnings
from pathlib import Path

import anndata as ad
import anndata2ri
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rpy2.rinterface_lib.callbacks as rcb
import rpy2.robjects as ro
import scanpy as sc
from rpy2.rinterface_lib.embedded import RRuntimeError
from rpy2.robjects.conversion import localconverter

plt.rcParams["font.family"] = (
    "Arial" if "Arial" in [f.name for f in fm.fontManager.ttflist] else "sans-serif"
)
plt.rcParams["font.weight"] = "normal"

sys.path.insert(1, "/dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark")
from cellseg_benchmark._constants import cell_type_colors
from cellseg_benchmark.adata_utils import plot_pseudobulk_pca
from cellseg_benchmark.dea_utils import (
    add_ensembl_id,
    add_group_sample_counts,
    prepare_adata_for_rpy2,
    pseudobulk_aggregate_and_filter,
    safe_sheet,
)

warnings.filterwarnings("ignore", message=".*Observation names are not unique*")
VALID_METHODS = {"LRT", "QL"}


def get_args(test_args=None):  # noqa: D103
    p = argparse.ArgumentParser(description="Run edgeR pseudobulk-based DEA")
    p.add_argument("cohort", help="Cohort name, e.g. foxf2")
    p.add_argument(
        "seg_method", help="Segmentation method, e.g. Cellpose_1_nuclei_model"
    )
    p.add_argument(
        "--sample_key", default="sample", help="obs column for donor/sample ID"
    )
    p.add_argument(
        "--subset_key",
        default="cell_type",
        help="obs column used to subset data (e.g. cell_type, cluster, region)",
    )
    p.add_argument(
        "--subset_values",
        nargs="+",
        default=None,
        help="Values of subset_key to process (default: all unique values)",
    )
    p.add_argument(
        "--condition_key",
        default="genotype",
        help="obs column for condition (e.g. genotype)",
    )
    p.add_argument(
        "--batch_key",
        default="slide",
        help="optional batch key for inclusion as covariate (default: slide)",
    )
    p.add_argument("--ref", default="WT", help="Reference group (default: WT)")
    p.add_argument(
        "--test_groups",
        nargs="+",
        default=None,
        help="Groups to test vs reference (default: all groups in condition_key except --ref)",
    )
    p.add_argument(
        "--edger_methods",
        nargs="+",
        default=["LRT"],
        choices=sorted(VALID_METHODS),
        help="edgeR method(s) to run (default: LRT)",
    )
    p.add_argument("--min_cells", type=int, default=15, help="Minimum cells per donor")
    p.add_argument(
        "--replicates_per_patient",
        type=int,
        default=1,
        help="Number of pseudoreplicates per donor",
    )
    p.add_argument(
        "--overwrite",
        type=lambda x: str(x).lower() in ["true", "1", "yes"],
        default=True,
        help="Overwrite existing result files (default: True)",
    )
    if test_args is not None:
        return p.parse_args(test_args)
    else:
        return p.parse_args()

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "foxf2",
        "Cellpose_1_nuclei_model",
        "--sample_key",
        "sample",
        "--subset_key",
        "cell_type",
        "--condition_key",
        "genotype",
        "--ref",
        "WT",
        "--edger_methods",
        "LRT",
        "--overwrite",
        "False",
    ]
)

# %%
# Simulate CLI arguments inside Jupyter
args = get_args(
    [
        "aging",
        "Cellpose_1_nuclei_model",
        "--sample_key",
        "sample",
        "--subset_key",
        "cell_type",
        "--condition_key",
        "condition",
        "--ref",
        "WT_3",
        "--edger_methods",
        "LRT",
        "--overwrite",
        "False",
    ]
)

# %%
args
# Out:
# Namespace(cohort='aging', seg_method='Cellpose_1_nuclei_model', sample_key='sample', subset_key='cell_type', subset_values=None, condition_key='condition', batch_key='slide', ref='WT_3', test_groups=None, edger_methods=['LRT'], min_cells=15, replicates_per_patient=1, overwrite=False)

# %%
# Logger setup
logger = logging.getLogger("dea")
if not logger.handlers:
    handler = logging.StreamHandler()
    handler.setFormatter(logging.Formatter("%(asctime)s [%(levelname)s]: %(message)s"))
    logger.addHandler(handler)
    logger.setLevel(logging.INFO)
    logger.propagate = False
rcb.logger.handlers = logger.handlers
# rcb.consolewrite_print = lambda x: logger.debug(f"R: {x.strip()}")
rcb.consolewrite_error = lambda x: (_ for _ in ()).throw(RRuntimeError(x.strip()))
# rcb.consolewrite_message = lambda x: logger.info(f"R: {x.strip()}")
rcb.consolewrite_warn = lambda x: (
    logger.warning if x.lstrip().lower().startswith("warning") else logger.info
)(f"R: {x.strip()}")
setattr(rcb, "consolewrite_warnerror", rcb.consolewrite_warn)

# %%
# R setup
conv = ro.default_converter + ro.pandas2ri.converter + anndata2ri.converter
r_script = Path(sys.path[1]) / "cellseg_benchmark" / "dea_utils.r"
ro.r["source"](str(r_script))
edgeR_loop = ro.globalenv["edgeR_loop"]

# %%
base_path = Path("/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark")
method_path = base_path / "analysis" / args.cohort / args.seg_method
output_dir = method_path / "dea"
output_dir.mkdir(parents=True, exist_ok=True)

# %%
logger.info("Loading integrated AnnData...")
adata = sc.read_h5ad(method_path / "adatas" / "adata_integrated.h5ad.gz")
adata.obs["cell_type"] = adata.obs["cell_type_revised"]
# Out:
# 2025-10-31 16:11:27,865 [INFO]: Loading integrated AnnData...

# %%
# re-group cell types
adata.obs["cell_type"] = (
    adata.obs["cell_type"]
    .astype(str)
    .replace(
        {
            "Tanycytes": "Ependymal",
            "Astroependymal": "Astrocytes",
            "Neurons-Glyc-Gaba": "Neurons-Other",
        }
    )
    .astype("category")
)

# %%
adata.obs["cell_type"].value_counts()
# Out:
# cell_type
# Oligodendrocytes            131904
# Neurons-Glut                124130
# Neurons-Dopa                 77224
# Astrocytes                   75424
# ECs                          49431
# Neurons-Granule-Immature     42337
# Neurons-Other                40619
# Undefined                    32012
# Microglia                    29106
# OPCs                         20832
# Pericytes                    15056
# VLMCs                         8346
# Ependymal                     6539
# SMCs                          5928
# Choroid-Plexus                5657
# Neurons-Gaba                  3499
# BAMs                          1933
# Immune-Other                   566
# Name: count, dtype: int64

# %%
# Clean up group names for R conversion
adata.obs[args.subset_key] = [
    key.replace(" ", "_")
    .replace("-", "_")
    .replace("/", "_")
    .replace("+", "")
    .replace("(", "")
    .replace(")", "")
    if not pd.isna(key)
    else key
    for key in adata.obs[args.subset_key]
]
for col in [args.condition_key, args.sample_key, args.subset_key]:
    adata.obs[col] = adata.obs[col].astype("category")
if args.test_groups is None:
    groups = adata.obs[args.condition_key].dropna().unique().tolist()
    args.test_groups = [g for g in groups if g != args.ref]
    msg = (
        f"Test groups inferred from '{args.condition_key}': {', '.join(map(str, args.test_groups))}"
        if args.test_groups
        else f"No test groups found different from ref '{args.ref}' under '{args.condition_key}'."
    )
    logger.info(msg)

# print sample overview
if args.subset_values is None:
    groups_to_process = sorted(adata.obs[args.subset_key].unique())
else:
    groups_to_process = args.subset_values
for cond, df in adata.obs.groupby(args.condition_key, observed=True):
    samples = df[args.sample_key].unique()
    logger.info(f"{cond}: {len(samples)} samples → {', '.join(samples)}")
# Out:
# 2025-10-31 16:12:12,017 [INFO]: Test groups inferred from 'condition': WT_6, WT_12, WT_18, WT_24
# 2025-10-31 16:12:12,111 [INFO]: WT_3: 3 samples → aging_s8_r1, aging_s10_r1, aging_s10_r2
# 2025-10-31 16:12:12,113 [INFO]: WT_6: 3 samples → aging_s1_r0, aging_s5_r1, aging_s7_r2
# 2025-10-31 16:12:12,115 [INFO]: WT_12: 3 samples → aging_s5_r2, aging_s8_r0, aging_s12_r0
# 2025-10-31 16:12:12,117 [INFO]: WT_18: 3 samples → aging_s6_r0, aging_s8_r2, aging_s11_r0
# 2025-10-31 16:12:12,119 [INFO]: WT_24: 3 samples → aging_s10_r0, aging_s11_r1, aging_s11_r2

# %%
adata.obs["n_cells_sum"] = adata.obs.groupby(
    [args.subset_key, args.sample_key], observed=True
)[args.sample_key].transform("count")
adata.obs["volume_mean"] = adata.obs.groupby(
    [args.subset_key, args.sample_key], observed=True
)["volume_final"].transform("mean")
adata.obs["volume_sum"] = adata.obs.groupby(
    [args.subset_key, args.sample_key], observed=True
)["volume_final"].transform("sum")

# %%
adata.X = adata.layers["counts"].copy()
assert np.issubdtype(adata.X.dtype, np.integer)

# %%
obs_to_keep = [
    args.condition_key,
    args.subset_key,
    args.sample_key,
    "n_cells_sum",
    "volume_mean",
    "volume_sum",
]
if args.batch_key and args.batch_key in adata.obs.columns:
    obs_to_keep.append(args.batch_key)
else:
    logger.warning(
        f"Batch column '{args.batch_key}' was not found in adata.obs "
        "or is invalid. Continuing **without** a batch covariate."
    )
    args.batch_key = None

# %%
logger.info("Run pseudobulking...")
total = len(groups_to_process)
logger.info(f"Processing {groups_to_process[0]} ({1}/{total})")
adata_pb = pseudobulk_aggregate_and_filter(
    adata,
    subset_value=groups_to_process[0],
    sample_key=args.sample_key,
    subset_key=args.subset_key,
    obs_to_keep=obs_to_keep,
    min_cells=args.min_cells,
    replicates_per_patient=args.replicates_per_patient,
    logger=logger,
)
for i, group in enumerate(groups_to_process[1:], 2):
    logger.info(f"Processing {group} ({i}/{total})")
    adata_pb_i = pseudobulk_aggregate_and_filter(
        adata,
        subset_value=group,
        sample_key=args.sample_key,
        subset_key=args.subset_key,
        obs_to_keep=obs_to_keep,
        min_cells=args.min_cells,
        replicates_per_patient=args.replicates_per_patient,
        logger=logger,
    )
    adata_pb = ad.concat(
        [adata_pb, adata_pb_i], join="outer", label=None, index_unique=None
    )
adata_pb.obs_names_make_unique()
# Add whole brain: pseudobulk per sample across all groups
adata_pb_i = pseudobulk_aggregate_and_filter(
    adata,
    subset_value=None,
    sample_key=args.sample_key,
    subset_key=args.subset_key,
    obs_to_keep=obs_to_keep,
    min_cells=args.min_cells,
    replicates_per_patient=args.replicates_per_patient,
    logger=logger,
)
adata_pb_i.obs[args.subset_key] = "all"
adata_pb = ad.concat([adata_pb, adata_pb_i])
del adata
# Out:
# 2025-10-31 16:12:12,660 [INFO]: Run pseudobulking...
# 2025-10-31 16:12:12,661 [INFO]: Processing Astrocytes (1/18)
# 2025-10-31 16:12:13,804 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:16,377 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:16,544 [INFO]: Processing BAMs (2/18)
# 2025-10-31 16:12:16,756 [INFO]: 	Processing donor 1/14...
# 2025-10-31 16:12:18,352 [INFO]: 	Processing donor 14/14...
# 2025-10-31 16:12:18,480 [INFO]: Processing Choroid_Plexus (3/18)
# 2025-10-31 16:12:18,697 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:20,443 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:20,571 [INFO]: Processing ECs (4/18)
# 2025-10-31 16:12:21,373 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:23,632 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:23,918 [INFO]: Processing Ependymal (5/18)
# 2025-10-31 16:12:24,137 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:25,881 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:26,003 [INFO]: Processing Immune_Other (6/18)
# 2025-10-31 16:12:26,178 [INFO]: 	Dropping samples with <15 cells: {'aging_s10_r2': 12}
# 2025-10-31 16:12:26,180 [INFO]: 	Processing donor 1/5...
# 2025-10-31 16:12:26,591 [INFO]: 	Processing donor 5/5...
# 2025-10-31 16:12:26,704 [INFO]: Processing Microglia (7/18)
# 2025-10-31 16:12:27,188 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:29,188 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:29,456 [INFO]: Processing Neurons_Dopa (8/18)
# 2025-10-31 16:12:30,646 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:33,201 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:33,377 [INFO]: Processing Neurons_Gaba (9/18)
# 2025-10-31 16:12:33,637 [INFO]: 	Processing donor 1/14...
# 2025-10-31 16:12:35,255 [INFO]: 	Processing donor 14/14...
# 2025-10-31 16:12:35,374 [INFO]: Processing Neurons_Glut (10/18)
# 2025-10-31 16:12:37,071 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:40,142 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:40,354 [INFO]: Processing Neurons_Granule_Immature (11/18)
# 2025-10-31 16:12:41,034 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:43,166 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:43,330 [INFO]: Processing Neurons_Other (12/18)
# 2025-10-31 16:12:43,986 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:46,121 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:46,257 [INFO]: Processing OPCs (13/18)
# 2025-10-31 16:12:46,664 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:48,571 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:48,705 [INFO]: Processing Oligodendrocytes (14/18)
# 2025-10-31 16:12:50,416 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:53,566 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:53,797 [INFO]: Processing Pericytes (15/18)
# 2025-10-31 16:12:54,135 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:56,134 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:56,263 [INFO]: Processing SMCs (16/18)
# 2025-10-31 16:12:56,486 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:12:58,227 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:12:58,355 [INFO]: Processing Undefined (17/18)
# 2025-10-31 16:12:58,861 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:13:00,875 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:13:01,029 [INFO]: Processing VLMCs (18/18)
# 2025-10-31 16:13:01,286 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:13:03,096 [INFO]: 	Processing donor 15/15...
# 2025-10-31 16:13:03,221 [INFO]: Processing all data (no subsetting by cell_type)
# 2025-10-31 16:13:06,930 [INFO]: 	Processing donor 1/15...
# 2025-10-31 16:13:17,226 [INFO]: 	Processing donor 15/15...

# %%
plot_pseudobulk_pca(adata_pb, args, output_dir, cell_type_colors, logger)
# Out:
# 2025-10-31 16:13:18,044 [INFO]: Skipping PCA plot, file already exists: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/analysis/aging/Cellpose_1_nuclei_model/dea/pseudobulk_pca.png

# %%
logger.info("Run DEA...")
adata_pb = prepare_adata_for_rpy2(adata_pb, key=args.subset_key)
adatas_pb = {}
unique_groups = adata_pb.obs[args.subset_key].unique().tolist()
for key in unique_groups:
    tmp = adata_pb[adata_pb.obs[args.subset_key] == key].copy()
    adatas_pb[key] = tmp
# Out:
# 2025-10-31 16:13:18,104 [INFO]: Run DEA...

# %%
adatas_pb
# Out:
# {'Astrocytes': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'BAMs': AnnData object with n_obs × n_vars = 14 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Choroid_Plexus': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'ECs': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Ependymal': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Immune_Other': AnnData object with n_obs × n_vars = 5 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Microglia': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Neurons_Dopa': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Neurons_Gaba': AnnData object with n_obs × n_vars = 14 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Neurons_Glut': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Neurons_Granule_Immature': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Neurons_Other': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'OPCs': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Oligodendrocytes': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Pericytes': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'SMCs': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'Undefined': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'VLMCs': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample',
#  'all': AnnData object with n_obs × n_vars = 15 × 500
#      obs: 'condition', 'cell_type', 'n_cells_sum', 'volume_mean', 'volume_sum', 'slide', 'sample'}

# %%
adatas_pb["ECs"].X.todense()
# Out:
# matrix([[1756., 7463., 2459., ..., 3440., 4956., 1449.],
#         [ 416., 3015., 1207., ..., 1316., 2401., 1032.],
#         [ 674., 3962., 1005., ..., 1467., 1977.,  538.],
#         ...,
#         [ 361., 1928., 1236., ...,  829., 2706., 1066.],
#         [ 462., 2598.,  881., ...,  981., 2747., 1311.],
#         [  99., 1251.,  545., ...,  321., 1171.,  908.]],
#        shape=(15, 500), dtype=float32)

# %%
# loop over cell types

# %%
all_degs = {}
for group_i in adatas_pb:
    adata_tmp = adatas_pb[group_i]
    with localconverter(conv):
        combined_results = edgeR_loop(
            adata=adata_tmp,
            group_i=group_i,
            edger_methods=args.edger_methods,
            test_groups=args.test_groups,
            ref_group=args.ref,
            condition_col=args.condition_key,
            batch_col=args.batch_key,
        )
    if combined_results is not ro.NULL:
        all_degs[group_i] = combined_results
# Out:
# 2025-10-29 15:36:04,571 [INFO]: R: Astrocytes: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:04,660 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:10,224 [INFO]: R: BAMs: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:10,232 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:15,957 [INFO]: R: Choroid_Plexus: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:15,965 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:20,103 [INFO]: R: ECs: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:20,110 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:24,053 [INFO]: R: Ependymal: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:24,061 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:28,219 [INFO]: R: Immune_Other: skip (ref_group/test_groups missing)
# 2025-10-29 15:36:28,334 [INFO]: R: Microglia: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:28,340 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:32,230 [INFO]: R: Neurons_Dopa: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:32,238 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:36,179 [INFO]: R: Neurons_Gaba: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:36,186 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:38,949 [INFO]: R: Neurons_Glut: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:38,956 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:42,990 [INFO]: R: Neurons_Granule_Immature: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:42,997 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:47,741 [INFO]: R: Neurons_Other: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:47,749 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:51,651 [INFO]: R: OPCs: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:51,658 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:55,469 [INFO]: R: Oligodendrocytes: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:55,475 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:36:59,377 [INFO]: R: Pericytes: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:36:59,384 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:37:03,103 [INFO]: R: SMCs: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:37:03,110 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:37:06,779 [INFO]: R: Undefined: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:37:06,786 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:37:10,887 [INFO]: R: VLMCs: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:37:10,893 [INFO]: R: Design: ~ condition + slide
# 2025-10-29 15:37:14,632 [INFO]: R: all: WT_6/WT_12/WT_18/WT_24 vs WT_3
# 2025-10-29 15:37:14,639 [INFO]: R: Design: ~ condition + slide

# %%
# format and export

# %%
logger.info("Format output table...")
collapsed_df = pd.concat(
    [pd.DataFrame(v).assign(subset=k) for k, v in all_degs.items()], ignore_index=True
).drop(columns=["result_id"], errors="ignore")

collapsed_df = add_group_sample_counts(
    collapsed_df,
    adatas_pb,
    condition_key=args.condition_key,
    sample_key=args.sample_key,
    ref=args.ref,
    test_groups=args.test_groups,
    subset_group="subset",
)
collapsed_df = collapsed_df.set_index("gene")
collapsed_df.insert(collapsed_df.columns.get_loc("FC"), "gene", collapsed_df.index)

order = [
    "subset",
    "gene",
    "FC",
    "logFC",
    "PValue",
    "FDR",
    "logCPM",
    "LR",
    "method",
    "test_group",
    "ref",
    "test",
]
collapsed_df = collapsed_df[order + [c for c in collapsed_df.columns if c not in order]]

logger.info("Add ensembl gene ids...")
collapsed_df = add_ensembl_id(collapsed_df, logger=logger)
# Out:
# 2025-10-31 16:23:30,497 [INFO]: Format output table...
# 2025-10-31 16:23:30,545 [INFO]: Add ensembl gene ids...
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 3 input query terms found no hit:	['H2afj', 'Pifo', 'Ctps']
# Input sequence provided is already in string format. No operation performed
# Input sequence provided is already in string format. No operation performed
# 2025-10-31 16:23:34,067 [INFO]: 500 unique symbols -> 500 mapped (100.0%)
# 2025-10-31 16:23:34,069 [INFO]: Renamed aliases: H2afj->H2aj, Pifo->Cimap3, Ctps->Ctps1

# %%
collapsed_df
# Out:
#        subset    gene        FC     logFC    PValue       FDR    logCPM  \
# gene
# Rspo1     ECs   Rspo1  0.293731 -1.767434  0.000013  0.005180  7.807830
# Cdkn1a    ECs  Cdkn1a  0.262400 -1.930162  0.000036  0.005180  9.824937
# Gata3     ECs   Gata3  4.540910  2.182982  0.000037  0.005180  6.708165
# Spp1      ECs    Spp1  3.722140  1.896132  0.000041  0.005180  8.567996
# Mgp       ECs     Mgp  3.313243  1.728244  0.000147  0.014732  8.531981
# ...       ...     ...       ...       ...       ...       ...       ...
# Folr1     ECs   Folr1  0.990512 -0.013754  0.962358  0.970119  5.414683
# Mag       ECs     Mag  1.005573  0.008018  0.974067  0.979947  8.655519
# Itgb5     ECs   Itgb5  1.002281  0.003287  0.989200  0.991908  9.199109
# Tjp3      ECs    Tjp3  1.001661  0.002394  0.991654  0.991908  7.567088
# Notch2    ECs  Notch2  0.998305 -0.002447  0.991908  0.991908  9.239917
#
#                LR     method test_group   ref         test  test_group_n  \
# gene
# Rspo1   19.002640  edgeR_LRT       WT_6  WT_3   WT_6vsWT_3             3
# Cdkn1a  17.067461  edgeR_LRT       WT_6  WT_3   WT_6vsWT_3             3
# Gata3   17.000073  edgeR_LRT       WT_6  WT_3   WT_6vsWT_3             3
# Spp1    16.804434  edgeR_LRT       WT_6  WT_3   WT_6vsWT_3             3
# Mgp     14.406213  edgeR_LRT       WT_6  WT_3   WT_6vsWT_3             3
# ...           ...        ...        ...   ...          ...           ...
# Folr1    0.002227  edgeR_LRT      WT_24  WT_3  WT_24vsWT_3             3
# Mag      0.001057  edgeR_LRT      WT_24  WT_3  WT_24vsWT_3             3
# Itgb5    0.000183  edgeR_LRT      WT_24  WT_3  WT_24vsWT_3             3
# Tjp3     0.000109  edgeR_LRT      WT_24  WT_3  WT_24vsWT_3             3
# Notch2   0.000103  edgeR_LRT      WT_24  WT_3  WT_24vsWT_3             3
#
#         ref_n          ensembl_id
# gene
# Rspo1       3  ENSMUSG00000028871
# Cdkn1a      3  ENSMUSG00000023067
# Gata3       3  ENSMUSG00000015619
# Spp1        3  ENSMUSG00000029304
# Mgp         3  ENSMUSG00000030218
# ...       ...                 ...
# Folr1       3  ENSMUSG00000001827
# Mag         3  ENSMUSG00000036634
# Itgb5       3  ENSMUSG00000022817
# Tjp3        3  ENSMUSG00000034917
# Notch2      3  ENSMUSG00000027878
#
# [2000 rows x 15 columns]

# %%
logger.info("Export table(s)...")
subset_key_clean = re.sub(r"[_-]", "", args.subset_key)
# Out:
# 2025-10-31 16:23:42,138 [INFO]: Export table(s)...

# %%
name = f"{args.cohort}-by-{subset_key_clean}_pseudobulk_edgeR"
name
# Out:
# 'aging-by-celltype_pseudobulk_edgeR'

# %%
# name = f"{args.cohort}-by-{subset_key_clean}_pseudobulk_edgeR_libnorm"
# name
# Out:
# 'aging-by-celltype_pseudobulk_edgeR_libnorm'

# %%
for (method, test), df_mt in collapsed_df.groupby(["method", "test"]):
    df_mt = df_mt.loc[:, df_mt.notna().any()]  # drop all-NaN cols
    xlsx = output_dir / f"{name}_{method.split('_', 1)[-1]}_{test}.xlsx"
    if xlsx.exists() and not args.overwrite:
        logger.info(f"  Exists, skip: {xlsx}")
        continue
    used = set()
    with pd.ExcelWriter(xlsx, engine="xlsxwriter") as writer:
        for gid, g in df_mt.groupby("subset", sort=True):
            g.sort_values("PValue").to_excel(
                writer, sheet_name=safe_sheet(gid, used), index=False
            )
    logger.info(f"  Wrote: {xlsx}")

logger.info("Done.")
# Out:
# 2025-10-31 16:31:53,965 [INFO]:   Wrote: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/analysis/aging/Cellpose_1_nuclei_model/dea/aging-by-celltype_pseudobulk_edgeR_libnorm_LRT_WT_12vsWT_3.xlsx
# 2025-10-31 16:31:54,064 [INFO]:   Wrote: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/analysis/aging/Cellpose_1_nuclei_model/dea/aging-by-celltype_pseudobulk_edgeR_libnorm_LRT_WT_18vsWT_3.xlsx
# 2025-10-31 16:31:54,162 [INFO]:   Wrote: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/analysis/aging/Cellpose_1_nuclei_model/dea/aging-by-celltype_pseudobulk_edgeR_libnorm_LRT_WT_24vsWT_3.xlsx
# 2025-10-31 16:31:54,265 [INFO]:   Wrote: /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/analysis/aging/Cellpose_1_nuclei_model/dea/aging-by-celltype_pseudobulk_edgeR_libnorm_LRT_WT_6vsWT_3.xlsx
# 2025-10-31 16:31:54,266 [INFO]: Done.

# %%
# dissect loop manually

# %%
# %load_ext rpy2.ipython

# %%
group_i = "ECs"
adata = adatas_pb[group_i]
condition_col = args.condition_key
test_groups = args.test_groups
ref_group = args.ref
batch_col = args.batch_key
edger_method = "LRT"

# %%
edger_method
# Out:
# 'LRT'

# %%
batch_col
# Out:
# 'slide'

# %%
condition_col
# Out:
# 'condition'

# %%
test_groups
# Out:
# ['WT_6', 'WT_12', 'WT_18', 'WT_24']

# %%
adata.obs.head()
# Out:
#                       condition cell_type  n_cells_sum  volume_mean  \
# donor_aging_s1_r0_0-3      WT_6       ECs         3728  1552.182742
# donor_aging_s5_r1_0-3      WT_6       ECs         2798  1431.079209
# donor_aging_s5_r2_0-3     WT_12       ECs         3223  1503.273870
# donor_aging_s6_r0_0-3     WT_18       ECs         3349  1316.456750
# donor_aging_s7_r2_0-3      WT_6       ECs         3062  1276.856319
#
#                          volume_sum slide       sample
# donor_aging_s1_r0_0-3  5.786537e+06     1  aging_s1_r0
# donor_aging_s5_r1_0-3  4.004160e+06     5  aging_s5_r1
# donor_aging_s5_r2_0-3  4.845052e+06     5  aging_s5_r2
# donor_aging_s6_r0_0-3  4.408814e+06     6  aging_s6_r0
# donor_aging_s7_r2_0-3  3.909734e+06     7  aging_s7_r2

# %%
#

# %%
# %%R -c conv -i adata -i condition_col -i test_groups -i group_i -i ref_group -i batch_col -i edger_method -o design
#
# condition <- droplevels(factor(colData(adata)[[condition_col]]))
# condition <- stats::relevel(condition, ref = ref_group)
#
# # use batch covariate if exists and has >1 level
# use_batch <- !is.null(batch_col) && batch_col %in% colnames(colData(adata)) &&
#              nlevels(droplevels(factor(colData(adata)[[batch_col]]))) > 1
#
# design <- if (use_batch) {
#   batch <- droplevels(factor(colData(adata)[[batch_col]]))
#   model.matrix(~ condition + batch)
# } else {
#   model.matrix(~ condition)
# }
#
# message("  Design: ~ ", condition_col, if (use_batch) paste0(" + ", batch_col) else "")
#
# rdof <- nrow(design) - qr(design)$rank
# if (rdof <= 0) {
#   message("  Skip: no residual df (likely too few samples or condition confounded with batch)")
#   return(NULL)
# }
# Out:
#   Design: ~ condition + slide

# %%
# compare lib size normalization with usual volume-based norm

# %%
# %%R -o libsize -o vol_sum
# libsize <- colSums(SummarizedExperiment::assay(adata, "X"))
# vol_sum <- colData(adata)$volume_sum

# %%
np.corrcoef(libsize, vol_sum)[0, 1]
# Out:
# np.float64(0.7396053761788448)

# %%
# %%R
# min_count = 2
# y <- edgeR::DGEList(assay(adata, "X"), group = condition)
# keep <- edgeR::filterByExpr(y, min.count = min_count, design = design)
# y <- y[keep, , keep.lib.sizes = FALSE]

# %%
# %%R
# # replace library sizes with volume
# vol <- colData(adata)[["volume_sum"]]
# if (is.null(vol) || any(vol <= 0)) stop("Invalid volume in colData(sce), expects 'volume_sum'.")
# y$samples$lib.size <- vol
# y <- edgeR::calcNormFactors(y)
# y$samples
# Out:
#                        group lib.size norm.factors
# donor_aging_s1_r0_0-3   WT_6  5786537    1.6520609
# donor_aging_s5_r1_0-3   WT_6  4004160    1.0459383
# donor_aging_s5_r2_0-3  WT_12  4845052    0.7929747
# donor_aging_s6_r0_0-3  WT_18  4408814    1.0758775
# donor_aging_s7_r2_0-3   WT_6  3909734    0.9092402
# donor_aging_s8_r0_0-3  WT_12  4560863    1.2528785
# donor_aging_s8_r1_0-3   WT_3  5041294    1.3993642
# donor_aging_s8_r2_0-3  WT_18  5789520    1.0354382
# donor_aging_s10_r0_0-3 WT_24  4848763    0.8257560
# donor_aging_s10_r1_0-3  WT_3  4507851    1.2900732
# donor_aging_s10_r2_0-3  WT_3  5734632    1.3349858
# donor_aging_s11_r0_0-3 WT_18  4025104    0.9739872
# donor_aging_s11_r1_0-3 WT_24  4965043    0.7945015
# donor_aging_s11_r2_0-3 WT_24  5106148    0.7781083
# donor_aging_s12_r0_0-2 WT_12  3817003    0.4799239

# %%
# OR

# %%
# %%R
# y <- edgeR::calcNormFactors(y, method="TMM")
# y$samples
# Out:
#                        group lib.size norm.factors
# donor_aging_s1_r0_0-3   WT_6  1743002    1.0336947
# donor_aging_s5_r1_0-3   WT_6   783658    1.0010397
# donor_aging_s5_r2_0-3  WT_12   725441    0.9932803
# donor_aging_s6_r0_0-3  WT_18   842409    1.0799021
# donor_aging_s7_r2_0-3   WT_6   706624    0.9302237
# donor_aging_s8_r0_0-3  WT_12  1047030    1.0292272
# donor_aging_s8_r1_0-3   WT_3  1413525    0.9576344
# donor_aging_s8_r2_0-3  WT_18  1130092    0.9948433
# donor_aging_s10_r0_0-3 WT_24   787150    0.9669853
# donor_aging_s10_r1_0-3  WT_3  1179334    0.9603020
# donor_aging_s10_r2_0-3  WT_3  1433232    1.0382107
# donor_aging_s11_r0_0-3 WT_18   727508    1.0331344
# donor_aging_s11_r1_0-3 WT_24   752044    1.0252157
# donor_aging_s11_r2_0-3 WT_24   797327    0.9509489
# donor_aging_s12_r0_0-2 WT_12   355197    1.0171961

# %%
# %%R
# fit <- if (edger_method == "QL") {
#   edgeR::glmQLFit(edgeR::estimateDisp(y, design), design)
# } else if (edger_method == "LRT") {
#   edgeR::glmFit(edgeR::estimateGLMRobustDisp(y, design), design)
# }

# %%
# %%R
# condition <- droplevels(factor(colData(adata)[[condition_col]]))
# if (is.null(condition) || nlevels(condition) < 2) { message(group_i, ": skip (condition invalid or <2 levels)"); return(NULL) }
# present <- intersect(test_groups, levels(condition))
# if (!(ref_group %in% levels(condition)) || !length(present)) { message(group_i, ": skip (ref_group/test_groups missing)"); return(NULL) }
# missing <- setdiff(test_groups, present)
# message(group_i, ": ", paste(present, collapse="/"), " vs ", ref_group,
#         if (length(missing)) paste0(" (missing:", paste(missing, collapse=","), ")") else "")
# Out:
# ECs: WT_6/WT_12/WT_18/WT_24 vs WT_3

# %%
# %%R
# present
# Out:
# [[1]]
# [1] "WT_6"
#
# [[2]]
# [1] "WT_12"
#
# [[3]]
# [1] "WT_18"
#
# [[4]]
# [1] "WT_24"

# %%
# %%R
# res <- list()
# for (tg in present) {
#   tmp <- edgeR_run_test(fit, design, edger_method, tg, ref_group)
#   if (is.null(tmp)) next
#   tmp <- dplyr::mutate(as.data.frame(tmp), FC = 2^logFC, edgeR_method = edger_method, test_group = tg, ref = ref_group)
#   res[[paste(tg, edger_method, sep="_")]] <- tmp
# }

# %%
# %%R
# res <- list()
# for (tg in present) {
#   tmp <- edgeR_run_test(fit, design, edger_method, tg, ref_group)
#   if (is.null(tmp)) next
#   met <- paste0("edgeR_", edger_method)
#   tmp <- dplyr::mutate(as.data.frame(tmp), FC = 2^logFC, method = met, test_group = tg, ref = ref_group)
#   res[[paste(tg, met, sep="_")]] <- tmp
# }

# %%
# %%R
# head(res)
# Out:
# $WT_6_edgeR_LRT
#                       logFC    logCPM           LR       PValue         FDR
# Rspo1         -1.767434e+00  7.807830 1.900264e+01 1.305377e-05 0.005179547
# Cdkn1a        -1.930162e+00  9.824937 1.706746e+01 3.607513e-05 0.005179547
# Gata3          2.182982e+00  6.708165 1.700007e+01 3.737839e-05 0.005179547
# Spp1           1.896132e+00  8.567996 1.680443e+01 4.143637e-05 0.005179547
# Mgp            1.728244e+00  8.531981 1.440621e+01 1.473154e-04 0.014731543
# Cx3cl1        -1.246154e+00 12.069438 1.369450e+01 2.150837e-04 0.017923644
# Arpp21        -1.614785e+00 11.579817 1.310281e+01 2.948529e-04 0.021060920
# Acta2          1.856266e+00  7.289953 1.274139e+01 3.576526e-04 0.022353288
# Drd1          -1.793780e+00  8.071460 1.206626e+01 5.134265e-04 0.028523696
# Adora2a       -1.921533e+00  8.412108 1.130381e+01 7.734838e-04 0.038674191
# Lamp5         -1.983745e+00 10.533813 1.089927e+01 9.620227e-04 0.043728305
# AI593442      -1.121516e+00 11.798480 8.082912e+00 4.468459e-03 0.172692313
# Pde3a          1.269556e+00  7.730412 8.074197e+00 4.490000e-03 0.172692313
# Cfh            1.482860e+00 10.746894 7.684896e+00 5.568490e-03 0.198874653
# Rad54b        WT_12vsWT_3 0.5599397 edgeR_LRT      WT_12 WT_3
# Car4          WT_12vsWT_3 0.5766010 edgeR_LRT      WT_12 WT_3
# Cfh           WT_12vsWT_3 1.9139101 edgeR_LRT      WT_12 WT_3
# Kcnj10        WT_12vsWT_3 0.6603542 edgeR_LRT      WT_12 WT_3
# Fgf5          WT_12vsWT_3 0.5545256 edgeR_LRT      WT_12 WT_3
# Prox1         WT_12vsWT_3 0.5084342 edgeR_LRT      WT_12 WT_3
# C4b           WT_12vsWT_3 1.9644811 edgeR_LRT      WT_12 WT_3
# Apcs          WT_12vsWT_3 1.6416409 edgeR_LRT      WT_12 WT_3
# Cd163         WT_12vsWT_3 1.7719549 edgeR_LRT      WT_12 WT_3
# Mmp2          WT_12vsWT_3 1.6934116 edgeR_LRT      WT_12 WT_3
# Dcn           WT_12vsWT_3 2.3349414 edgeR_LRT      WT_12 WT_3
# Efemp1        WT_12vsWT_3 1.7032856 edgeR_LRT      WT_12 WT_3
# Ctnnd2        WT_12vsWT_3 0.5720518 edgeR_LRT      WT_12 WT_3
# Jph3          WT_12vsWT_3 0.6587037 edgeR_LRT      WT_12 WT_3
# Plekhg1       WT_12vsWT_3 0.5551097 edgeR_LRT      WT_12 WT_3
# Bmp6          WT_12vsWT_3 2.0531099 edgeR_LRT      WT_12 WT_3
# Lama5         WT_12vsWT_3 0.6315955 edgeR_LRT      WT_12 WT_3
# Myh11         WT_12vsWT_3 1.9503768 edgeR_LRT      WT_12 WT_3
# Anpep         WT_12vsWT_3 1.8830067 edgeR_LRT      WT_12 WT_3
# Meg3          WT_12vsWT_3 1.7564448 edgeR_LRT      WT_12 WT_3
# AI593442      WT_12vsWT_3 0.6575318 edgeR_LRT      WT_12 WT_3
# Slc1a3        WT_12vsWT_3 0.6698459 edgeR_LRT      WT_12 WT_3
# Cd248         WT_12vsWT_3 1.4859982 edgeR_LRT      WT_12 WT_3
# Lamp5         WT_12vsWT_3 0.5334028 edgeR_LRT      WT_12 WT_3
# Gad1          WT_12vsWT_3 1.5267006 edgeR_LRT      WT_12 WT_3
# Acta2         WT_12vsWT_3 1.6825160 edgeR_LRT      WT_12 WT_3
# Slc7a5        WT_12vsWT_3 0.6752679 edgeR_LRT      WT_12 WT_3
# Rorb          WT_12vsWT_3 0.6548853 edgeR_LRT      WT_12 WT_3
# Slc16a1       WT_12vsWT_3 0.6957359 edgeR_LRT      WT_12 WT_3
# Col23a1       WT_12vsWT_3 1.4986849 edgeR_LRT      WT_12 WT_3
# Aldh1a2       WT_12vsWT_3 2.1502843 edgeR_LRT      WT_12 WT_3
# Slc17a7       WT_12vsWT_3 0.6643216 edgeR_LRT      WT_12 WT_3
# Tnf           WT_12vsWT_3 1.5314202 edgeR_LRT      WT_12 WT_3
# Tmem119       WT_12vsWT_3 1.4144736 edgeR_LRT      WT_12 WT_3
# Grip2         WT_12vsWT_3 1.5162900 edgeR_LRT      WT_12 WT_3
# Prdx6         WT_12vsWT_3 0.7034087 edgeR_LRT      WT_12 WT_3
# Adamts1       WT_12vsWT_3 0.6394380 edgeR_LRT      WT_12 WT_3
# Gkn3          WT_12vsWT_3 1.6374640 edgeR_LRT      WT_12 WT_3
# ...
# Rest          WT_24vsWT_3 1.1953180 edgeR_LRT      WT_24 WT_3
# Egln1         WT_24vsWT_3 0.8655212 edgeR_LRT      WT_24 WT_3
# Itga6         WT_24vsWT_3 0.8641055 edgeR_LRT      WT_24 WT_3
# C1qc          WT_24vsWT_3 1.2032891 edgeR_LRT      WT_24 WT_3
# Jag2          WT_24vsWT_3 0.8296871 edgeR_LRT      WT_24 WT_3
# Trim65        WT_24vsWT_3 0.8125509 edgeR_LRT      WT_24 WT_3
# Col18a1       WT_24vsWT_3 1.1889318 edgeR_LRT      WT_24 WT_3
# Eno1          WT_24vsWT_3 1.1872161 edgeR_LRT      WT_24 WT_3
# Sema3g        WT_24vsWT_3 0.8245564 edgeR_LRT      WT_24 WT_3
# Nosip         WT_24vsWT_3 1.1981776 edgeR_LRT      WT_24 WT_3
# Col23a1       WT_24vsWT_3 1.1878440 edgeR_LRT      WT_24 WT_3
# Dnm2          WT_24vsWT_3 1.1945710 edgeR_LRT      WT_24 WT_3
# Prdm16        WT_24vsWT_3 1.1917357 edgeR_LRT      WT_24 WT_3
# Mki67         WT_24vsWT_3 1.1666355 edgeR_LRT      WT_24 WT_3
# Vcl           WT_24vsWT_3 1.1610177 edgeR_LRT      WT_24 WT_3
# Nfe2l2        WT_24vsWT_3 0.8340358 edgeR_LRT      WT_24 WT_3
# Lamc2         WT_24vsWT_3 1.1818538 edgeR_LRT      WT_24 WT_3
# Prdx2         WT_24vsWT_3 1.1598557 edgeR_LRT      WT_24 WT_3
# Gja1          WT_24vsWT_3 1.1392565 edgeR_LRT      WT_24 WT_3
# C1qa          WT_24vsWT_3 1.1878625 edgeR_LRT      WT_24 WT_3
# Cdkn1a        WT_24vsWT_3 0.8377378 edgeR_LRT      WT_24 WT_3
# Tpx2          WT_24vsWT_3 1.1690816 edgeR_LRT      WT_24 WT_3
# Gclm          WT_24vsWT_3 0.8381218 edgeR_LRT      WT_24 WT_3
# Ctsc          WT_24vsWT_3 0.8636828 edgeR_LRT      WT_24 WT_3
# Ang4          WT_24vsWT_3 1.2419528 edgeR_LRT      WT_24 WT_3
# Edil3         WT_24vsWT_3 0.8074737 edgeR_LRT      WT_24 WT_3
# Ccnd1         WT_24vsWT_3 1.1540400 edgeR_LRT      WT_24 WT_3
# Kansl1        WT_24vsWT_3 1.1190653 edgeR_LRT      WT_24 WT_3
# Sod1          WT_24vsWT_3 0.8679655 edgeR_LRT      WT_24 WT_3
# Timp3         WT_24vsWT_3 1.1706734 edgeR_LRT      WT_24 WT_3
# Arpp21        WT_24vsWT_3 0.8524004 edgeR_LRT      WT_24 WT_3
# Lamp5         WT_24vsWT_3 0.8101199 edgeR_LRT      WT_24 WT_3
# Lpar1         WT_24vsWT_3 1.1615857 edgeR_LRT      WT_24 WT_3
# Ccl4          WT_24vsWT_3 0.8248500 edgeR_LRT      WT_24 WT_3
# Rgcc          WT_24vsWT_3 0.8423597 edgeR_LRT      WT_24 WT_3
# Slc1a3        WT_24vsWT_3 0.8740827 edgeR_LRT      WT_24 WT_3
# Pf4           WT_24vsWT_3 1.1932315 edgeR_LRT      WT_24 WT_3
# Plvap         WT_24vsWT_3 1.1664798 edgeR_LRT      WT_24 WT_3
# Acsl4         WT_24vsWT_3 0.8429656 edgeR_LRT      WT_24 WT_3
# Itgav         WT_24vsWT_3 0.8461387 edgeR_LRT      WT_24 WT_3
# Tgfbr1        WT_24vsWT_3 1.1701287 edgeR_LRT      WT_24 WT_3
# Eln           WT_24vsWT_3 1.1905557 edgeR_LRT      WT_24 WT_3
# Laptm5        WT_24vsWT_3 1.1976673 edgeR_LRT      WT_24 WT_3
# Wbp2          WT_24vsWT_3 1.1313620 edgeR_LRT      WT_24 WT_3
# Fscn1         WT_24vsWT_3 0.8834127 edgeR_LRT      WT_24 WT_3
# Tnfrsf1a      WT_24vsWT_3 1.1684348 edgeR_LRT      WT_24 WT_3
# Col4a2        WT_24vsWT_3 0.8769254 edgeR_LRT      WT_24 WT_3
# Gkn3          WT_24vsWT_3 0.8328320 edgeR_LRT      WT_24 WT_3
# Myc           WT_24vsWT_3 1.1708532 edgeR_LRT      WT_24 WT_3
# Cltc          WT_24vsWT_3 0.8924999 edgeR_LRT      WT_24 WT_3
# Mapt          WT_24vsWT_3 1.1192324 edgeR_LRT      WT_24 WT_3
# Itga7         WT_24vsWT_3 0.8567782 edgeR_LRT      WT_24 WT_3
# Grip2         WT_24vsWT_3 0.8657334 edgeR_LRT      WT_24 WT_3
# Jag1          WT_24vsWT_3 0.8649893 edgeR_LRT      WT_24 WT_3
# Spp1          WT_24vsWT_3 1.1548724 edgeR_LRT      WT_24 WT_3
# Edn1          WT_24vsWT_3 0.8777193 edgeR_LRT      WT_24 WT_3
# Ly6a          WT_24vsWT_3 0.8629418 edgeR_LRT      WT_24 WT_3
# Higd1b        WT_24vsWT_3 0.8610470 edgeR_LRT      WT_24 WT_3
# Fn1           WT_24vsWT_3 0.8668766 edgeR_LRT      WT_24 WT_3
# Mlc1          WT_24vsWT_3 0.8915270 edgeR_LRT      WT_24 WT_3
# B4galt5       WT_24vsWT_3 0.8472274 edgeR_LRT      WT_24 WT_3
# A830036E02Rik WT_24vsWT_3 1.1683585 edgeR_LRT      WT_24 WT_3
# Cemip         WT_24vsWT_3 1.1862498 edgeR_LRT      WT_24 WT_3
# Nid2          WT_24vsWT_3 1.1233265 edgeR_LRT      WT_24 WT_3
# Lama1         WT_24vsWT_3 1.1617935 edgeR_LRT      WT_24 WT_3
# Rbfox3        WT_24vsWT_3 0.8840911 edgeR_LRT      WT_24 WT_3
# Hif3a         WT_24vsWT_3 1.1634698 edgeR_LRT      WT_24 WT_3
# Myh11         WT_24vsWT_3 1.2015159 edgeR_LRT      WT_24 WT_3
# Mtor          WT_24vsWT_3 0.9054696 edgeR_LRT      WT_24 WT_3
# Ctnna2        WT_24vsWT_3 1.1357469 edgeR_LRT      WT_24 WT_3
# Jam2          WT_24vsWT_3 0.9082231 edgeR_LRT      WT_24 WT_3
# Thbd          WT_24vsWT_3 0.8727900 edgeR_LRT      WT_24 WT_3
# Wdr12         WT_24vsWT_3 0.8733120 edgeR_LRT      WT_24 WT_3
# Cx3cl1        WT_24vsWT_3 0.9098525 edgeR_LRT      WT_24 WT_3
# Vcan          WT_24vsWT_3 1.1150616 edgeR_LRT      WT_24 WT_3
# Il18          WT_24vsWT_3 0.8993491 edgeR_LRT      WT_24 WT_3
# Tie1          WT_24vsWT_3 0.8968270 edgeR_LRT      WT_24 WT_3
# Dll3          WT_24vsWT_3 1.1806193 edgeR_LRT      WT_24 WT_3
# Acan          WT_24vsWT_3 0.8695485 edgeR_LRT      WT_24 WT_3
# Pdk1          WT_24vsWT_3 1.1267947 edgeR_LRT      WT_24 WT_3
# Rrm2          WT_24vsWT_3 1.1082275 edgeR_LRT      WT_24 WT_3
# Itgb8         WT_24vsWT_3 0.8912295 edgeR_LRT      WT_24 WT_3
# Ctnna3        WT_24vsWT_3 1.1373871 edgeR_LRT      WT_24 WT_3
# Ccn2          WT_24vsWT_3 1.1756918 edgeR_LRT      WT_24 WT_3
# Prkcg         WT_24vsWT_3 1.0919544 edgeR_LRT      WT_24 WT_3
# Sulf2         WT_24vsWT_3 0.8889330 edgeR_LRT      WT_24 WT_3
# Hmox1         WT_24vsWT_3 0.8926182 edgeR_LRT      WT_24 WT_3
# Vegfd         WT_24vsWT_3 1.1235135 edgeR_LRT      WT_24 WT_3
# Tacc3         WT_24vsWT_3 0.8903155 edgeR_LRT      WT_24 WT_3
# B2m           WT_24vsWT_3 1.1217739 edgeR_LRT      WT_24 WT_3
# Top2a         WT_24vsWT_3 1.1124143 edgeR_LRT      WT_24 WT_3
# Kcnj8         WT_24vsWT_3 1.1125939 edgeR_LRT      WT_24 WT_3
# Serpine2      WT_24vsWT_3 0.9178125 edgeR_LRT      WT_24 WT_3
# Nbeal1        WT_24vsWT_3 0.8986862 edgeR_LRT      WT_24 WT_3
# Notch3        WT_24vsWT_3 1.1277498 edgeR_LRT      WT_24 WT_3
# Lama2         WT_24vsWT_3 1.1249460 edgeR_LRT      WT_24 WT_3
# Plxnb3        WT_24vsWT_3 0.8811494 edgeR_LRT      WT_24 WT_3
# Pttg1         WT_24vsWT_3 1.1100019 edgeR_LRT      WT_24 WT_3
# Rspo1         WT_24vsWT_3 0.9059100 edgeR_LRT      WT_24 WT_3
# Ulk4          WT_24vsWT_3 0.9003893 edgeR_LRT      WT_24 WT_3
# Kif23         WT_24vsWT_3 1.1063611 edgeR_LRT      WT_24 WT_3
# Gphn          WT_24vsWT_3 0.9166379 edgeR_LRT      WT_24 WT_3
# Axl           WT_24vsWT_3 0.8964363 edgeR_LRT      WT_24 WT_3
# Slc20a2       WT_24vsWT_3 1.1082713 edgeR_LRT      WT_24 WT_3
# Opa1          WT_24vsWT_3 0.9219069 edgeR_LRT      WT_24 WT_3
# Prdx6         WT_24vsWT_3 0.9152466 edgeR_LRT      WT_24 WT_3
# Trp53         WT_24vsWT_3 1.1133033 edgeR_LRT      WT_24 WT_3
# Wnt7a         WT_24vsWT_3 0.9086998 edgeR_LRT      WT_24 WT_3
# Cxcl12        WT_24vsWT_3 0.9245265 edgeR_LRT      WT_24 WT_3
# Itgb1bp1      WT_24vsWT_3 1.1029185 edgeR_LRT      WT_24 WT_3
# Pdgfa         WT_24vsWT_3 0.9053196 edgeR_LRT      WT_24 WT_3
# Tgfb3         WT_24vsWT_3 1.0951922 edgeR_LRT      WT_24 WT_3
# Ica1l         WT_24vsWT_3 0.8946866 edgeR_LRT      WT_24 WT_3
# Abca1         WT_24vsWT_3 0.9029252 edgeR_LRT      WT_24 WT_3
# Col4a3        WT_24vsWT_3 1.1017794 edgeR_LRT      WT_24 WT_3
# Fgf2          WT_24vsWT_3 1.0910391 edgeR_LRT      WT_24 WT_3
# Ptprc         WT_24vsWT_3 1.0917041 edgeR_LRT      WT_24 WT_3
# Rgs5          WT_24vsWT_3 1.0721686 edgeR_LRT      WT_24 WT_3
# Tagln         WT_24vsWT_3 1.1151345 edgeR_LRT      WT_24 WT_3
# Pdgfra        WT_24vsWT_3 1.1139641 edgeR_LRT      WT_24 WT_3
# Fxyd5         WT_24vsWT_3 1.0960241 edgeR_LRT      WT_24 WT_3
# Jph3          WT_24vsWT_3 0.9278332 edgeR_LRT      WT_24 WT_3
# Fgfbp1        WT_24vsWT_3 1.1304031 edgeR_LRT      WT_24 WT_3
# Cav1          WT_24vsWT_3 0.9007950 edgeR_LRT      WT_24 WT_3
# Kdr           WT_24vsWT_3 1.0757114 edgeR_LRT      WT_24 WT_3
# Epn2          WT_24vsWT_3 0.9360417 edgeR_LRT      WT_24 WT_3
# Dnm1          WT_24vsWT_3 0.9324451 edgeR_LRT      WT_24 WT_3
# Cnn1          WT_24vsWT_3 1.0897785 edgeR_LRT      WT_24 WT_3
# Ly6e          WT_24vsWT_3 1.0683686 edgeR_LRT      WT_24 WT_3
# Abcc9         WT_24vsWT_3 0.9112551 edgeR_LRT      WT_24 WT_3
# Zcchc14       WT_24vsWT_3 0.9182626 edgeR_LRT      WT_24 WT_3
# S100a6        WT_24vsWT_3 0.9178057 edgeR_LRT      WT_24 WT_3
# Gclc          WT_24vsWT_3 1.0858771 edgeR_LRT      WT_24 WT_3
# Fbn2          WT_24vsWT_3 1.0840105 edgeR_LRT      WT_24 WT_3
# Tmem119       WT_24vsWT_3 0.9234307 edgeR_LRT      WT_24 WT_3
# C1qtnf4       WT_24vsWT_3 0.9226557 edgeR_LRT      WT_24 WT_3
# Cd93          WT_24vsWT_3 0.9402649 edgeR_LRT      WT_24 WT_3
# Mapk9         WT_24vsWT_3 0.9361878 edgeR_LRT      WT_24 WT_3
# Krt12         WT_24vsWT_3 0.9102794 edgeR_LRT      WT_24 WT_3
# Nanos1        WT_24vsWT_3 0.9210064 edgeR_LRT      WT_24 WT_3
# Spp2          WT_24vsWT_3 0.9227144 edgeR_LRT      WT_24 WT_3
# Srf           WT_24vsWT_3 1.0869925 edgeR_LRT      WT_24 WT_3
# Vegfb         WT_24vsWT_3 1.0774868 edgeR_LRT      WT_24 WT_3
# Pde1a         WT_24vsWT_3 0.9352625 edgeR_LRT      WT_24 WT_3
# Tbr1          WT_24vsWT_3 0.9153316 edgeR_LRT      WT_24 WT_3
# Arf6          WT_24vsWT_3 0.9460160 edgeR_LRT      WT_24 WT_3
# Matn2         WT_24vsWT_3 1.0645817 edgeR_LRT      WT_24 WT_3
# Meg3          WT_24vsWT_3 1.0958035 edgeR_LRT      WT_24 WT_3
# Dpp10         WT_24vsWT_3 1.0657982 edgeR_LRT      WT_24 WT_3
# Gatm          WT_24vsWT_3 1.0686245 edgeR_LRT      WT_24 WT_3
# Fezf2         WT_24vsWT_3 0.9223133 edgeR_LRT      WT_24 WT_3
# Notch4        WT_24vsWT_3 0.9292275 edgeR_LRT      WT_24 WT_3
# P2ry12        WT_24vsWT_3 0.9147829 edgeR_LRT      WT_24 WT_3
# Lpl           WT_24vsWT_3 0.9278232 edgeR_LRT      WT_24 WT_3
# Pln           WT_24vsWT_3 0.9286016 edgeR_LRT      WT_24 WT_3
# Tshz2         WT_24vsWT_3 0.9231034 edgeR_LRT      WT_24 WT_3
# Tgfb1         WT_24vsWT_3 1.0720097 edgeR_LRT      WT_24 WT_3
# Dcakd         WT_24vsWT_3 0.9396590 edgeR_LRT      WT_24 WT_3
# Nkg7          WT_24vsWT_3 0.9253040 edgeR_LRT      WT_24 WT_3
# Ccdc153       WT_24vsWT_3 1.0685628 edgeR_LRT      WT_24 WT_3
# Clta          WT_24vsWT_3 0.9505260 edgeR_LRT      WT_24 WT_3
# Slc11a2       WT_24vsWT_3 0.9384698 edgeR_LRT      WT_24 WT_3
# Bbc3          WT_24vsWT_3 1.0587999 edgeR_LRT      WT_24 WT_3
# Bmp4          WT_24vsWT_3 0.9378430 edgeR_LRT      WT_24 WT_3
# Itga11        WT_24vsWT_3 0.9291034 edgeR_LRT      WT_24 WT_3
# Slc17a7       WT_24vsWT_3 1.0602249 edgeR_LRT      WT_24 WT_3
# Vip           WT_24vsWT_3 0.9196093 edgeR_LRT      WT_24 WT_3
# Rorb          WT_24vsWT_3 0.9462819 edgeR_LRT      WT_24 WT_3
# Erp29         WT_24vsWT_3 0.9419044 edgeR_LRT      WT_24 WT_3
# Prox1         WT_24vsWT_3 1.0759026 edgeR_LRT      WT_24 WT_3
# Fga           WT_24vsWT_3 0.9297248 edgeR_LRT      WT_24 WT_3
# Nkx2-2        WT_24vsWT_3 0.9488513 edgeR_LRT      WT_24 WT_3
# Mmp12         WT_24vsWT_3 1.0782565 edgeR_LRT      WT_24 WT_3
# Wnt2b         WT_24vsWT_3 1.0549886 edgeR_LRT      WT_24 WT_3
# Serpine1      WT_24vsWT_3 1.0634521 edgeR_LRT      WT_24 WT_3
# Gm12371       WT_24vsWT_3 1.0497321 edgeR_LRT      WT_24 WT_3
# Igf2          WT_24vsWT_3 1.0765197 edgeR_LRT      WT_24 WT_3
# Pmaip1        WT_24vsWT_3 1.0533424 edgeR_LRT      WT_24 WT_3
# Col1a1        WT_24vsWT_3 0.9335251 edgeR_LRT      WT_24 WT_3
# Slc13a3       WT_24vsWT_3 1.0466212 edgeR_LRT      WT_24 WT_3
# S100b         WT_24vsWT_3 1.0456859 edgeR_LRT      WT_24 WT_3
# Nr2f2         WT_24vsWT_3 1.0642586 edgeR_LRT      WT_24 WT_3
# Ccl3          WT_24vsWT_3 0.9490118 edgeR_LRT      WT_24 WT_3
# Fnbp4         WT_24vsWT_3 1.0452680 edgeR_LRT      WT_24 WT_3
# Arl15         WT_24vsWT_3 0.9558401 edgeR_LRT      WT_24 WT_3
# Scube1        WT_24vsWT_3 1.0495685 edgeR_LRT      WT_24 WT_3
# Nmt1          WT_24vsWT_3 0.9638130 edgeR_LRT      WT_24 WT_3
# Cdh6          WT_24vsWT_3 1.0522927 edgeR_LRT      WT_24 WT_3
# Carf          WT_24vsWT_3 0.9532155 edgeR_LRT      WT_24 WT_3
# Bace1         WT_24vsWT_3 1.0510729 edgeR_LRT      WT_24 WT_3
# Vegfc         WT_24vsWT_3 0.9431528 edgeR_LRT      WT_24 WT_3
# Egfl8         WT_24vsWT_3 1.0452698 edgeR_LRT      WT_24 WT_3
# Tjp2          WT_24vsWT_3 1.0385231 edgeR_LRT      WT_24 WT_3
# Ccne1         WT_24vsWT_3 0.9510824 edgeR_LRT      WT_24 WT_3
# Plekhg1       WT_24vsWT_3 0.9488775 edgeR_LRT      WT_24 WT_3
# Sox9          WT_24vsWT_3 0.9608981 edgeR_LRT      WT_24 WT_3
# Slc7a14       WT_24vsWT_3 1.0458520 edgeR_LRT      WT_24 WT_3
# Snta1         WT_24vsWT_3 1.0423570 edgeR_LRT      WT_24 WT_3
# Susd5         WT_24vsWT_3 0.9599742 edgeR_LRT      WT_24 WT_3
# Nostrin       WT_24vsWT_3 1.0373113 edgeR_LRT      WT_24 WT_3
# Kcnj10        WT_24vsWT_3 1.0299503 edgeR_LRT      WT_24 WT_3
# Pcna          WT_24vsWT_3 0.9623978 edgeR_LRT      WT_24 WT_3
# Cemip2        WT_24vsWT_3 0.9647625 edgeR_LRT      WT_24 WT_3
# Foxf1         WT_24vsWT_3 0.9638198 edgeR_LRT      WT_24 WT_3
# Bcl2          WT_24vsWT_3 0.9664772 edgeR_LRT      WT_24 WT_3
# Slc26a10      WT_24vsWT_3 0.9657585 edgeR_LRT      WT_24 WT_3
# Dll4          WT_24vsWT_3 1.0348642 edgeR_LRT      WT_24 WT_3
# Csf1r         WT_24vsWT_3 1.0420858 edgeR_LRT      WT_24 WT_3
# Ms4a7         WT_24vsWT_3 1.0333893 edgeR_LRT      WT_24 WT_3
# AI593442      WT_24vsWT_3 0.9734325 edgeR_LRT      WT_24 WT_3
# Matn3         WT_24vsWT_3 0.9651120 edgeR_LRT      WT_24 WT_3
# Atg7          WT_24vsWT_3 1.0307854 edgeR_LRT      WT_24 WT_3
# Cnp           WT_24vsWT_3 1.0234010 edgeR_LRT      WT_24 WT_3
# Cdh2          WT_24vsWT_3 0.9807405 edgeR_LRT      WT_24 WT_3
# Itgb6         WT_24vsWT_3 0.9736258 edgeR_LRT      WT_24 WT_3
# Fbn1          WT_24vsWT_3 1.0244361 edgeR_LRT      WT_24 WT_3
# Fadd          WT_24vsWT_3 0.9792113 edgeR_LRT      WT_24 WT_3
# Il33          WT_24vsWT_3 0.9734656 edgeR_LRT      WT_24 WT_3
# Angptl1       WT_24vsWT_3 0.9757309 edgeR_LRT      WT_24 WT_3
# Pecam1        WT_24vsWT_3 0.9827849 edgeR_LRT      WT_24 WT_3
# Pdgfc         WT_24vsWT_3 1.0194054 edgeR_LRT      WT_24 WT_3
# Stat1         WT_24vsWT_3 0.9725077 edgeR_LRT      WT_24 WT_3
# Pvalb         WT_24vsWT_3 1.0287216 edgeR_LRT      WT_24 WT_3
# Ctnnb1        WT_24vsWT_3 0.9846664 edgeR_LRT      WT_24 WT_3
# Opalin        WT_24vsWT_3 0.9825590 edgeR_LRT      WT_24 WT_3
# Pifo          WT_24vsWT_3 1.0220524 edgeR_LRT      WT_24 WT_3
# Enpp6         WT_24vsWT_3 1.0225067 edgeR_LRT      WT_24 WT_3
# Mmp9          WT_24vsWT_3 0.9768949 edgeR_LRT      WT_24 WT_3
# Nefl          WT_24vsWT_3 0.9834873 edgeR_LRT      WT_24 WT_3
# Casp3         WT_24vsWT_3 1.0152319 edgeR_LRT      WT_24 WT_3
# Cfp           WT_24vsWT_3 1.0191229 edgeR_LRT      WT_24 WT_3
# Egfl7         WT_24vsWT_3 1.0136059 edgeR_LRT      WT_24 WT_3
# Cxcr4         WT_24vsWT_3 1.0193134 edgeR_LRT      WT_24 WT_3
# Dll1          WT_24vsWT_3 0.9806186 edgeR_LRT      WT_24 WT_3
# Acta2         WT_24vsWT_3 1.0189975 edgeR_LRT      WT_24 WT_3
# Apoe          WT_24vsWT_3 1.0144843 edgeR_LRT      WT_24 WT_3
# Meox1         WT_24vsWT_3 1.0136878 edgeR_LRT      WT_24 WT_3
# Foxp1         WT_24vsWT_3 0.9882602 edgeR_LRT      WT_24 WT_3
# Aqp4          WT_24vsWT_3 0.9894461 edgeR_LRT      WT_24 WT_3
# Trpc1         WT_24vsWT_3 0.9881431 edgeR_LRT      WT_24 WT_3
# Fbln2         WT_24vsWT_3 1.0131530 edgeR_LRT      WT_24 WT_3
# Sox10         WT_24vsWT_3 0.9855302 edgeR_LRT      WT_24 WT_3
# Vtn           WT_24vsWT_3 0.9792957 edgeR_LRT      WT_24 WT_3
# Itga3         WT_24vsWT_3 1.0130884 edgeR_LRT      WT_24 WT_3
# Adora2a       WT_24vsWT_3 0.9836822 edgeR_LRT      WT_24 WT_3
# Ncam1         WT_24vsWT_3 1.0117417 edgeR_LRT      WT_24 WT_3
# Hapln2        WT_24vsWT_3 1.0154406 edgeR_LRT      WT_24 WT_3
# Jam3          WT_24vsWT_3 0.9897094 edgeR_LRT      WT_24 WT_3
# Galntl6       WT_24vsWT_3 0.9915238 edgeR_LRT      WT_24 WT_3
# Eno2          WT_24vsWT_3 0.9915935 edgeR_LRT      WT_24 WT_3
# Reln          WT_24vsWT_3 0.9896899 edgeR_LRT      WT_24 WT_3
# Nrip2         WT_24vsWT_3 1.0078420 edgeR_LRT      WT_24 WT_3
# Lrp1          WT_24vsWT_3 1.0060226 edgeR_LRT      WT_24 WT_3
# Folr1         WT_24vsWT_3 0.9905117 edgeR_LRT      WT_24 WT_3
# Mag           WT_24vsWT_3 1.0055732 edgeR_LRT      WT_24 WT_3
# Itgb5         WT_24vsWT_3 1.0022810 edgeR_LRT      WT_24 WT_3
# Tjp3          WT_24vsWT_3 1.0016606 edgeR_LRT      WT_24 WT_3
# Notch2        WT_24vsWT_3 0.9983052 edgeR_LRT      WT_24 WT_3

# %%
# %%R -o out # noqa: F821
# if (!length(res)) return(NULL)
# out <- dplyr::bind_rows(res, .id="result_id")
# out$gene <- sub("[.][.][.].*", "", rownames(out)); rownames(out) <- NULL
# out <- dplyr::select(out, gene, FC, dplyr::everything())

# %%
out  # noqa: F821
# Out:
#         gene        FC        result_id     logFC    logCPM         LR  \
# 1      Rspo1  0.293731   WT_6_edgeR_LRT -1.767434  7.807830  19.002640
# 2     Cdkn1a  0.262400   WT_6_edgeR_LRT -1.930162  9.824937  17.067461
# 3      Gata3  4.540910   WT_6_edgeR_LRT  2.182982  6.708165  17.000073
# 4       Spp1  3.722140   WT_6_edgeR_LRT  1.896132  8.567996  16.804434
# 5        Mgp  3.313243   WT_6_edgeR_LRT  1.728244  8.531981  14.406213
# ...      ...       ...              ...       ...       ...        ...
# 1996   Folr1  0.990512  WT_24_edgeR_LRT -0.013754  5.414683   0.002227
# 1997     Mag  1.005573  WT_24_edgeR_LRT  0.008018  8.655519   0.001057
# 1998   Itgb5  1.002281  WT_24_edgeR_LRT  0.003287  9.199109   0.000183
# 1999    Tjp3  1.001661  WT_24_edgeR_LRT  0.002394  7.567088   0.000109
# 2000  Notch2  0.998305  WT_24_edgeR_LRT -0.002447  9.239917   0.000103
#
#         PValue       FDR         test     method test_group   ref
# 1     0.000013  0.005180   WT_6vsWT_3  edgeR_LRT       WT_6  WT_3
# 2     0.000036  0.005180   WT_6vsWT_3  edgeR_LRT       WT_6  WT_3
# 3     0.000037  0.005180   WT_6vsWT_3  edgeR_LRT       WT_6  WT_3
# 4     0.000041  0.005180   WT_6vsWT_3  edgeR_LRT       WT_6  WT_3
# 5     0.000147  0.014732   WT_6vsWT_3  edgeR_LRT       WT_6  WT_3
# ...        ...       ...          ...        ...        ...   ...
# 1996  0.962358  0.970119  WT_24vsWT_3  edgeR_LRT      WT_24  WT_3
# 1997  0.974067  0.979947  WT_24vsWT_3  edgeR_LRT      WT_24  WT_3
# 1998  0.989200  0.991908  WT_24vsWT_3  edgeR_LRT      WT_24  WT_3
# 1999  0.991654  0.991908  WT_24vsWT_3  edgeR_LRT      WT_24  WT_3
# 2000  0.991908  0.991908  WT_24vsWT_3  edgeR_LRT      WT_24  WT_3
#
# [2000 rows x 12 columns]

# %%
group_i
# Out:
# 'ECs'

# %%
all_degs = {}
if out is not ro.NULL:
    all_degs[group_i] = out

# %%
# end
