# %% [markdown]
# # General statistics
# * cell area / volume
# * cell roundness
# * cell elongation
# * DAPI/PolyT brightness
# * ovrlpy stats

# %% [markdown]
# ## Compute general stats
# NOTE: intensities not computed for vpt_2D_DAPI_nuclei, vpt_3D_DAPI_PolyT_nuclei, vpt_3D_DAPI_nuclei, Cellpose_1_Merlin, vpt_2D_DAPI_PolyT, vpt_2D_DAPI_PolyT_nuclei, vpt_3D_DAPI_PolyT

# %%
from cellseg_benchmark.metrics import (
    compute_metric_for_all_methods,
    extract_general_stats,
)

# %%
compute_metric_for_all_methods(
    extract_general_stats,
    results_name="general_stats/general_stats.csv",
    cohort="aging",
    celltype_name="cell_type_revised",
    adata_name="adata_integrated",
    overwrite=False,
)
# Out:
# 1/30 extract_general_stats already computed for Proseg_3D_Cellpose_1_nuclei_model. Set overwrite=True to recompute
# 2/30 extract_general_stats already computed for Baysor_2D_Cellpose_2_DAPI_Transcripts_0.8. Set overwrite=True to recompute
# 3/30 Running extract_general_stats for vpt_2D_DAPI_nuclei
# intensities not found in obsm! Skipping intensities.
# intensities not found in obsm! Skipping intensities.
# /dss/dsshome1/0E/ra64luf2/projects/cellsegmentation_benchmark/st-bsb/cellseg_benchmark/metrics/general.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   results = df[['sample', celltype_name] + columns].groupby(['sample', celltype_name]).mean()
# ...

# %% [markdown]
# ## Plot general stats

# %%
from cellseg_benchmark.metrics import plot_general_stats

# %%
for metric in [
    "volume_final",
    "area",
    "sphericity",
    "elongation",
    "intensities_PolyT",
    "intensities_DAPI",
    "Ovrlpy_stats_mean_integrity",
]:
    plot_general_stats("aging", metric, show=True)
