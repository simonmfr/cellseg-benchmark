# %% [markdown]
# # Morphology properties
# * total transcripts
# * cell area / volume
# * cell roundness
# * cell elongation
# * DAPI/PolyT brightness
# *

# %%
from cellseg_benchmark.metrics import read_adata

# %%
adata = read_adata("aging")
# Out:
# Reading adata_integrated for method Proseg_3D_Cellpose_1_nuclei_model

# %%
adata.obs.columns
# Out:
# Index(['cell', 'original_cell_id', 'centroid_x', 'centroid_y', 'centroid_z',
#        'component', 'volume', 'surface_area', 'scale', 'region', 'slide',
#        'cell_type_incl_low_quality_revised',
#        'cell_type_mmc_incl_low_quality_clusters',
#        'cell_type_mmc_incl_low_quality', 'cell_type_incl_mixed_revised',
#        'cell_type_mmc_incl_mixed_clusters', 'cell_type_mmc_incl_mixed',
#        'cell_type_revised', 'cell_type_mmc_raw_clusters', 'cell_type_mmc_raw',
#        'area', 'volume_sum', 'volume_trapz', 'volume_final', 'num_z_planes',
#        'size_normalized', 'surface_to_volume_ratio', 'sphericity', 'solidity',
#        'elongation', 'genotype', 'age_months', 'run_date', 'organism',
#        'cohort', 'sample', 'animal_id', 'condition', 'n_counts', 'n_genes',
#        'path', 'spatial_outlier', 'low_quality_cell', 'volume_outlier_cell',
#        'fov'],
#       dtype='object')

# %%
adata.obsm["Ovrlpy_stats"]
# Out:
#               mean_integrity  variance
# aaaaaaaa-1          0.821117  0.456002
# aaaaaaab-1          0.790138  0.331503
# aaaaaaac-1          0.801383  0.708477
# aaaaaaad-1          0.874341  0.437607
# aaaaaaae-1          0.820528  0.473899
# ...                      ...       ...
# aaaalfma-1-9        0.639256  0.317012
# aaaalfmb-1-9        0.608563  0.217885
# aaaalfme-1-9        0.530731  0.280629
# aaaalfmf-1-9        0.574817  0.211674
# aaaalfmg-1-9        0.568003  0.288153
#
# [667954 rows x 2 columns]

# %%
adata.var
# Out:
#                         gene  total_count  lambda_bg_0  lambda_bg_1  \
# A830036E02Rik  A830036E02Rik       145589     0.000065     0.000155
# AI593442            AI593442       689767     0.000907     0.001257
# Abca1                  Abca1       115069     0.000179     0.000232
# Abcb1a                Abcb1a        71331     0.000143     0.000164
# Abcb1b                Abcb1b         8114     0.000017     0.000055
# ...                      ...          ...          ...          ...
# Wnt7a                  Wnt7a        39849     0.000156     0.000241
# Xirp1                  Xirp1        12881     0.000067     0.000050
# Zcchc14              Zcchc14       214574     0.001469     0.001471
# Zeb1                    Zeb1       230102     0.001164     0.001297
# Zic3                    Zic3        14394     0.000032     0.000116
#
#                lambda_bg_2  lambda_bg_3  lambda_bg_4  lambda_bg_5  \
# A830036E02Rik     0.000124     0.000108     0.000020     0.000234
# ...

# %%
import os

import spatialdata as sd
# Out:
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(

# %%
data_dir = os.path.abspath("/home/ubuntu/gitrepos/cellseg-benchmark/data")
# !ls -l $data_dir
# Out:
# lrwxrwxrwx 1 ra64luf2 pn52go 53 Aug 27 19:11 /home/ubuntu/gitrepos/cellseg-benchmark/data -> /dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark

# %%
sample_name = "foxf2_s2_r1"
sdata_path = os.path.join(data_dir, "samples", sample_name, "sdata_z3.zarr")
if "sdata" not in locals():
    sdata = sd.read_zarr(sdata_path)
# Out:
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
#   compressor, fill_value = _kwargs_compat(compressor, fill_value, kwargs)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/zarr/creation.py:610: UserWarning: ignoring keyword argument 'read_only'
# ...

# %%
# check if sdata points table contains any annotation of boundaries. Check if can compute this.
# need to get stats of number of transcripts overall, and number of transcripts per gene
# check if this info is also in adata.var already (for comparing annotated transcripts per gene)
