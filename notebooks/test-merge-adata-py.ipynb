# %%
import argparse
import logging
import os
import sys
import warnings
from concurrent.futures import ProcessPoolExecutor, as_completed
from pathlib import Path
from typing import Tuple

import scanpy as sc
import yaml
from anndata import AnnData
from spatialdata import read_zarr

sys.path.insert(1, "/dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark")
from cellseg_benchmark.adata_utils import (
    filter_genes,
    filter_low_quality_cells,
    filter_spatial_outlier_cells,
    integration_harmony,
    merge_adatas,
    normalize_counts,
    pca_umap_single,
)


def _load_one(
    sample_dir: Path, seg_method: str, logger: logging.Logger
) -> Tuple[str, AnnData | None]:
    """Load AnnData from one master sdata."""
    sdata = read_zarr(sample_dir / "sdata_z3.zarr", selection=("tables",))
    if f"adata_{seg_method}" not in sdata.tables.keys():
        if logger:
            logger.warning(f"Skipping {seg_method}. No such key: {seg_method}")
        return sample_dir.name, None
    return sample_dir.name, sdata[f"adata_{seg_method}"]


warnings.filterwarnings("ignore", ".*The table is annotating*", UserWarning)

sc.settings.n_jobs = -1

# Logger setup
logger = logging.getLogger("integrate_adatas")
logger.setLevel(logging.INFO)
handler = logging.StreamHandler()
handler.setFormatter(logging.Formatter("%(asctime)s [%(levelname)s]: %(message)s"))
logger.addHandler(handler)
# Out:
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/dask/dataframe/__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(

# %%
# CLI args
sys.argv = ["notebook", "foxf2", "Cellpose_1_nuclei_model"]
# sys.argv = ["notebook", "foxf2", "Proseg_Cellpose_1_nuclei_model"]

parser = argparse.ArgumentParser(
    description="Integrate adatas from a selected segmentation method."
)
parser.add_argument("cohort", help="Cohort name, e.g., 'foxf2'")
parser.add_argument(
    "seg_method", help="Segmentation method, e.g., 'Cellpose_1_nuclei_model'"
)
args = parser.parse_args()
args
# Out:
# Namespace(cohort='foxf2', seg_method='Cellpose_1_nuclei_model')

# %%
base_path = Path("/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark")
samples_path = base_path / "samples"
save_path = base_path / "analysis" / args.cohort / args.seg_method
save_path.mkdir(parents=True, exist_ok=True)

# %%
sample_metadata_file, excluded = (
    yaml.safe_load(open(base_path / "misc" / f))
    for f in ["sample_metadata.yaml", "samples_excluded.yaml"]
)  ###############
sample_metadata_file
# Out:
# {'foxf2_s1_r0': {'cohort': 'foxf2',
#   'slide': 1,
#   'region': 0,
#   'genotype': 'ECKO',
#   'age_months': 6,
#   'run_date': '20240229',
#   'animal_id': '000',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240229_Foxf2-Slide01-cp-WT-ECKO/region_0-ECKO000'},
#  'foxf2_s1_r1': {'cohort': 'foxf2',
#   'slide': 1,
#   'region': 1,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20240229',
#   'animal_id': '000',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240229_Foxf2-Slide01-cp-WT-ECKO/region_1-WT000'},
#  'foxf2_s2_r1': {'cohort': 'foxf2',
#   'slide': 2,
#   'region': 1,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20240322',
#   'animal_id': '536',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240322_Foxf2-Slide02-cp-WT-PCKO/region_1-WT536'},
#  'foxf2_s2_r2': {'cohort': 'foxf2',
#   'slide': 2,
#   'region': 2,
#   'genotype': 'PCKO',
#   'age_months': 6,
#   'run_date': '20240322',
#   'animal_id': '239',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240322_Foxf2-Slide02-cp-WT-PCKO/region_2-PCKO239'},
#  'foxf2_s4_r0': {'cohort': 'foxf2',
#   'slide': 4,
#   'region': 0,
#   'genotype': 'PCKO',
#   'age_months': 6,
#   'run_date': '20240304',
#   'animal_id': '421',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240304_Foxf2-Slide04-cp-ECKO-PCKO/region_0-PCKO421'},
#  'foxf2_s4_r1': {'cohort': 'foxf2',
#   'slide': 4,
#   'region': 1,
#   'genotype': 'ECKO',
#   'age_months': 6,
#   'run_date': '20240304',
#   'animal_id': '557',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240304_Foxf2-Slide04-cp-ECKO-PCKO/region_1-ECKO557'},
#  'foxf2_s5_r0': {'cohort': 'foxf2',
#   'slide': 5,
#   'region': 0,
#   'genotype': 'PCKO',
#   'age_months': 6,
#   'run_date': '20240628',
#   'animal_id': '238',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240628_Foxf2-Slide05-cp-PCKO-ECKO/region_0-PCKO238'},
#  'foxf2_s5_r1': {'cohort': 'foxf2',
#   'slide': 5,
#   'region': 1,
#   'genotype': 'ECKO',
#   'age_months': 6,
#   'run_date': '20240628',
#   'animal_id': '544',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240628_Foxf2-Slide05-cp-PCKO-ECKO/region_1-ECKO544'},
#  'foxf2_s6_r0': {'cohort': 'foxf2',
#   'slide': 6,
#   'region': 0,
#   'genotype': 'GLKO',
#   'age_months': 6,
#   'run_date': '20240729',
#   'animal_id': '890',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240729_Foxf2-Slide06-cp-WT-GLKO-GLKO/region_0-KO890'},
#  'foxf2_s6_r1': {'cohort': 'foxf2',
#   'slide': 6,
#   'region': 1,
#   'genotype': 'GLKO',
#   'age_months': 6,
#   'run_date': '20240729',
#   'animal_id': '883',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240729_Foxf2-Slide06-cp-WT-GLKO-GLKO/region_1-KO883'},
#  'foxf2_s6_r2': {'cohort': 'foxf2',
#   'slide': 6,
#   'region': 2,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20240729',
#   'animal_id': '897',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240729_Foxf2-Slide06-cp-WT-GLKO-GLKO/region_2-WT897'},
#  'foxf2_s7_r0': {'cohort': 'foxf2',
#   'slide': 7,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20240805',
#   'animal_id': '886',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240805_Foxf2-Slide07-cp-WT-GLKO/region_0-WT886'},
#  'foxf2_s7_r1': {'cohort': 'foxf2',
#   'slide': 7,
#   'region': 1,
#   'genotype': 'GLKO',
#   'age_months': 6,
#   'run_date': '20240805',
#   'animal_id': '885',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202402-Foxf2/merfish_output/20240805_Foxf2-Slide07-cp-WT-GLKO/region_1-KO885'},
#  'aging_s1_r0': {'cohort': 'aging',
#   'slide': 1,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20240516',
#   'animal_id': '308',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20240516_Htra1-Slide01-cp-WT308-KO307/region_0-WT308_6m'},
#  'aging_s5_r0': {'cohort': 'aging',
#   'slide': 5,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 18,
#   'run_date': '20241220',
#   'animal_id': '1377',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20241220_Htra1-and-Aging-Slide05-cp-WT1377_18m-WT1332_6m-WT_eNOS_12m/region_0-WT1377_18m'},
#  'aging_s5_r1': {'cohort': 'aging',
#   'slide': 5,
#   'region': 1,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20241220',
#   'animal_id': '1332',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20241220_Htra1-and-Aging-Slide05-cp-WT1377_18m-WT1332_6m-WT_eNOS_12m/region_1-WT1332_6m'},
#  'aging_s5_r2': {'cohort': 'aging',
#   'slide': 5,
#   'region': 2,
#   'genotype': 'WT',
#   'age_months': 12,
#   'run_date': '20241220',
#   'animal_id': '2',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20241220_Htra1-and-Aging-Slide05-cp-WT1377_18m-WT1332_6m-WT_eNOS_12m/region_2-WT2eNos_12m'},
#  'aging_s6_r0': {'cohort': 'aging',
#   'slide': 6,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 18,
#   'run_date': '20250113',
#   'animal_id': '421',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250113_Htra1-and-Aging-Slide06-cp-WT421_18m-KO278_18m-KO276_18m/region_0-WT421_18m'},
#  'aging_s7_r2': {'cohort': 'aging',
#   'slide': 7,
#   'region': 2,
#   'genotype': 'WT',
#   'age_months': 6,
#   'run_date': '20250127',
#   'animal_id': '58',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250127_Htra1-Slide07-cp-TG79-WT58-rerunSlide02/region_2-WT58_6m'},
#  'aging_s8_r0': {'cohort': 'aging',
#   'slide': 8,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 12,
#   'run_date': '20250203',
#   'animal_id': '1',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250203_Aging-Slide08-cp-WT_eNos_12m-WT1377_18m-WT121_3m/region_0-WT1eNos_12m'},
#  'aging_s8_r1': {'cohort': 'aging',
#   'slide': 8,
#   'region': 1,
#   'genotype': 'WT',
#   'age_months': 3,
#   'run_date': '20250203',
#   'animal_id': '121',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250203_Aging-Slide08-cp-WT_eNos_12m-WT1377_18m-WT121_3m/region_1-WT121_3m'},
#  'aging_s8_r2': {'cohort': 'aging',
#   'slide': 8,
#   'region': 2,
#   'genotype': 'WT',
#   'age_months': 18,
#   'run_date': '20250203',
#   'animal_id': '1337',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250203_Aging-Slide08-cp-WT_eNos_12m-WT1377_18m-WT121_3m/region_2-WT1337_18m'},
#  'aging_s10_r0': {'cohort': 'aging',
#   'slide': 10,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 24,
#   'run_date': '20250508',
#   'animal_id': '132',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250508_Aging-Slide10-cp-WT308_3m-WT309_3m-WT132_24m/region_0-WT132_24m'},
#  'aging_s10_r1': {'cohort': 'aging',
#   'slide': 10,
#   'region': 1,
#   'genotype': 'WT',
#   'age_months': 3,
#   'run_date': '20250508',
#   'animal_id': '308',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250508_Aging-Slide10-cp-WT308_3m-WT309_3m-WT132_24m/region_1-WT308_3m'},
#  'aging_s10_r2': {'cohort': 'aging',
#   'slide': 10,
#   'region': 2,
#   'genotype': 'WT',
#   'age_months': 3,
#   'run_date': '20250508',
#   'animal_id': '309',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250508_Aging-Slide10-cp-WT308_3m-WT309_3m-WT132_24m/region_2-WT309_3m'},
#  'aging_s11_r0': {'cohort': 'aging',
#   'slide': 11,
#   'region': 3,
#   'genotype': 'WT',
#   'age_months': 18,
#   'run_date': '20250526',
#   'animal_id': '232',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_3-WT232_18m'},
#  'aging_s11_r1': {'cohort': 'aging',
#   'slide': 11,
#   'region': 1,
#   'genotype': 'WT',
#   'age_months': 24,
#   'run_date': '20250526',
#   'animal_id': '999',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_1-WT999_24m'},
#  'aging_s11_r2': {'cohort': 'aging',
#   'slide': 11,
#   'region': 2,
#   'genotype': 'WT',
#   'age_months': 24,
#   'run_date': '20250526',
#   'animal_id': '888',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250526_Aging-Slide11-cp-WT232_18m-WT999_24m-WT888_24m/region_2-WT888_24m'},
#  'aging_s12_r0': {'cohort': 'aging',
#   'slide': 12,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': 12,
#   'run_date': '20250623',
#   'animal_id': '279',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0000/202405-Htra1-and-Aging/merfish_output/20250623_Aging-Slide12-cp-WT279_12m/region_0-WT279_12m'},
#  'VizgenMouseBrain_s1_r0': {'cohort': 'VizgenMouseBrain',
#   'slide': 1,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20210501',
#   'animal_id': 'Vizgen1',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-BrainReceptorShowcase-500plex/Slice2/Replicate1'},
#  'VizgenMouseBrain_s2_r0': {'cohort': 'VizgenMouseBrain',
#   'slide': 2,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20210501',
#   'animal_id': 'Vizgen1',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-BrainReceptorShowcase-500plex/Slice3/Replicate1'},
#  'VizgenMouseBrain_s3_r0': {'cohort': 'VizgenMouseBrain',
#   'slide': 3,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20210501',
#   'animal_id': 'Vizgen2',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-BrainReceptorShowcase-500plex/Slice2/Replicate2'},
#  'VizgenMouseBrain_s4_r0': {'cohort': 'VizgenMouseBrain',
#   'slide': 4,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20210501',
#   'animal_id': 'Vizgen2',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-BrainReceptorShowcase-500plex/Slice3/Replicate2'},
#  'VizgenMouseBrain_s5_r0': {'cohort': 'VizgenMouseBrain',
#   'slide': 5,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20210501',
#   'animal_id': 'Vizgen3',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-BrainReceptorShowcase-500plex/Slice2/Replicate3'},
#  'VizgenMouseBrain_s6_r0': {'cohort': 'VizgenMouseBrain',
#   'slide': 6,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20210501',
#   'animal_id': 'Vizgen3',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-BrainReceptorShowcase-500plex/Slice3/Replicate3'},
#  'ABCAtlas_s1_r0': {'cohort': 'ABCAtlas',
#   'slide': 1,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20220906',
#   'animal_id': '638850',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/ABCAtlas-MouseBrain-500plex/1199650959'},
#  'ABCAtlas_s2_r0': {'cohort': 'ABCAtlas',
#   'slide': 2,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20220929',
#   'animal_id': '638850',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/ABCAtlas-MouseBrain-500plex/1199651002'},
#  'ABCAtlas_s3_r0': {'cohort': 'ABCAtlas',
#   'slide': 3,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20220916',
#   'animal_id': '638850',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/ABCAtlas-MouseBrain-500plex/1199651036'},
#  'ABCAtlas_s4_r0': {'cohort': 'ABCAtlas',
#   'slide': 4,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20220919',
#   'animal_id': '638850',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/ABCAtlas-MouseBrain-500plex/1199651048'},
#  'ABCAtlas_s5_r0': {'cohort': 'ABCAtlas',
#   'slide': 5,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20220922',
#   'animal_id': '638850',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/ABCAtlas-MouseBrain-500plex/1199651078'},
#  'ABCAtlas_s6_r0': {'cohort': 'ABCAtlas',
#   'slide': 6,
#   'region': 0,
#   'genotype': 'WT',
#   'age_months': None,
#   'run_date': '20220927',
#   'animal_id': '638850',
#   'organism': 'mouse',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/ABCAtlas-MouseBrain-500plex/1199651112'},
#  'VizgenHumanBrain_s1_r0': {'cohort': 'VizgenHumanBrain',
#   'slide': 1,
#   'region': 0,
#   'genotype': None,
#   'age_months': None,
#   'run_date': '20240801',
#   'animal_id': None,
#   'organism': 'human',
#   'path': '/dss/dssfs03/pn52re/pn52re-dss-0001/merfish-public-data/Vizgen-HumanBrain-AD-1000plex/region_0'}}

# %%
excluded_samples = set(excluded.get(args.cohort, []))  ###############
excluded_samples
# Out:
# {'foxf2_s2_r0', 'foxf2_s3_r0', 'foxf2_s3_r1'}

# %%
# Load sdata
logger.info("Loading data...")
loads = []
for sample_dir in samples_path.glob(f"{args.cohort}*"):  ###############
    if sample_dir.name in excluded_samples:
        continue
    if not (sample_dir / "sdata_z3.zarr").exists():
        logger.error("master sdata in %s not found.", sample_dir)
        continue
    loads.append(sample_dir)

# drop samples where AnnData could not be loaded (missing or invalid), e.g. aging s8 r1 Cellpose 2 Transcripts
with ProcessPoolExecutor(max_workers=int(os.getenv("SLURM_CPUS_PER_TASK", 1))) as ex:
    futures = {ex.submit(_load_one, p, args.seg_method, logger): p for p in loads}
    adata_list = [f.result() for f in as_completed(futures)]
adata_list = [(x, y) for x, y in adata_list if y is not None]
# Out:
# 2025-09-17 09:48:03,935 [INFO]: Loading data...

# %%
# Merge and process
adata = merge_adatas(
    adata_list,
    seg_method=args.seg_method,
    logger=logger,
    plot_qc_stats=True,
    save_path=save_path / "plots",
)
del adata_list
# Out:
# 2025-09-17 09:53:16,658 [INFO]: Merging adatas of Cellpose_1_nuclei_model
# 100%|██████████| 13/13 [00:00<00:00, 40.39it/s]
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1774: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# 2025-09-17 09:53:17,985 [INFO]: Cellpose_1_nuclei_model: # of cells: 595581, # of samples: 13
# 2025-09-17 09:53:18,010 [INFO]: Cellpose_1_nuclei_model: # of cells: 595581, # of samples: 13
# 2025-09-17 09:53:18,017 [INFO]: Plotting QC results
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:197: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/anndata/_core/anndata.py:1158: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:245: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:259: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata_tmp.var["n_counts"] = adata_tmp.X.sum(axis=0).T
# /dss/dsshome1/0C/ra98gaq/Git/cellseg-benchmark/cellseg_benchmark/adata_utils.py:286: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# /home/ubuntu/miniforge3/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:269: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
# workaround to fix adata.obs formatting ###############
adata.obs["sample"] = adata.obs["sample"].str.replace(
    rf"^{args.cohort}_(\d+)_(\d+)$", rf"{args.cohort}_s\1_r\2", regex=True
)
adata.obs.drop(columns=["spt_region"], inplace=True, errors="ignore")
adata.obs["condition"] = (
    adata.obs["genotype"].astype(str) + "_" + adata.obs["age_months"].astype(str)
)

# %%
adata.obs["sample"].value_counts()
# Out:
# sample
# foxf2_s5_r1    58868
# foxf2_s5_r0    56940
# foxf2_s4_r0    49649
# foxf2_s2_r1    47686
# foxf2_s6_r2    47030
# foxf2_s1_r0    46814
# foxf2_s2_r2    45477
# foxf2_s6_r1    44109
# foxf2_s1_r1    42513
# foxf2_s7_r0    42204
# foxf2_s7_r1    41277
# foxf2_s6_r0    37142
# foxf2_s4_r1    35872
# Name: count, dtype: int64

# %%
adata.obs["condition"].value_counts()
# Out:
# condition
# WT_6      179433
# PCKO_6    152066
# ECKO_6    141554
# GLKO_6    122528
# Name: count, dtype: int64

# %%
adata.obs.columns
# Out:
# Index(['region', 'slide', 'cell_type_mmc_incl_low_quality_revised',
#        'cell_type_mmc_incl_low_quality_clusters',
#        'cell_type_mmc_incl_low_quality', 'cell_type_mmc_incl_mixed_revised',
#        'cell_type_mmc_incl_mixed_clusters', 'cell_type_mmc_incl_mixed',
#        'cell_type_mmc_raw_revised', 'cell_type_mmc_raw_clusters',
#        'cell_type_mmc_raw', 'area', 'volume_sum', 'volume_final',
#        'num_z_planes', 'size_normalized', 'surface_to_volume_ratio',
#        'sphericity', 'solidity', 'elongation', 'genotype', 'age_months',
#        'run_date', 'animal_id', 'organism', 'cohort', 'sample', 'n_counts',
#        'n_genes', 'condition'],
#       dtype='object')

# %%
adata.obsm["spatial"] = adata.obsm.get("spatial_microns", adata.obsm["spatial"])
adata = filter_spatial_outlier_cells(
    adata,
    data_dir=str(base_path),
    sample_metadata_file=sample_metadata_file,  ############
    save_path=save_path / "plots",
    logger=logger,
)
# Out:
# 2025-09-17 09:54:24,996 [INFO]: # total cells before filtering spatial outliers: 595581
# 2025-09-17 09:54:24,997 [INFO]: # spatial_outlier:       13221
# 2025-09-17 09:54:26,290 [INFO]: # total cells after filtering spatial outliers:  582360

# %%
# Special case: rerun filter_low_quality_cells with lower threshold for vpt_3D
if "vpt_3D" in args.seg_method:
    logger.info(
        "Segmentation method contains 'vpt_3D': applying low-quality cell filtering with min_counts=10 due to smaller cell sizes."
    )
    adata = filter_low_quality_cells(
        adata,
        save_path=save_path / "plots",
        min_counts=10,
        logger=logger,
    )
else:
    adata = filter_low_quality_cells(
        adata,
        save_path=save_path / "plots",
        logger=logger,
    )

adata = filter_genes(adata, save_path=save_path / "plots", logger=logger)

adata = normalize_counts(
    adata, save_path=save_path / "plots", seg_method=args.seg_method, logger=logger
)
# Out:
# 2025-09-17 09:54:39,681 [INFO]: # total cells before filtering low-quality or volume outliers: 582360
# 2025-09-17 09:54:39,681 [INFO]: # low_quality_cell:             5003
# 2025-09-17 09:54:39,682 [INFO]: # volume_outlier_cell:       66
# 2025-09-17 09:54:44,426 [INFO]: # total cells after filtering low-quality or volume outliers:  577291
# 2025-09-17 09:54:44,427 [INFO]: # genes before filtering: 500
# 2025-09-17 09:54:46,475 [INFO]: # genes after filtering: 500
# 2025-09-17 09:54:48,020 [INFO]: Normalizing counts...
# 2025-09-17 09:54:49,426 [INFO]: Cells before/after outlier removal during normalization: 577291 -> 565745
# /home/ubuntu/miniforge3/lib/python3.12/functools.py:909: UserWarning: zero-centering a sparse array/matrix densifies it.
#   return dispatch(args[0].__class__)(*args, **kw)

# %%
adata = pca_umap_single(adata, save_path=save_path / "plots", logger=logger)
# Out:
# 2025-09-17 09:55:01,040 [INFO]: Dimensionality reduction: PCA
# 2025-09-17 09:55:37,665 [INFO]: Dimensionality reduction: UMAP with {'n_neighbors': 20, 'n_pcs': 50, 'key': 'X_umap_20_50'}

# %%
# !mamba install bioconda::harmonypy -y
# Out:
# Looking for: ['bioconda::harmonypy']
#
# warning  libmamba Cache file "/home/ubuntu/miniforge3/pkgs/cache/497deca9.json" was modified by another program
# warning  libmamba Cache file "/home/ubuntu/miniforge3/pkgs/cache/09cdf8bf.json" was modified by another program
# [+] 0.0s
# [+] 0.1s
# bioconda/linux-64 (check zst) ━━━━━━━━━━━━━━━   0.0 B @  ??.?MB/s Checking  0.1sbioconda/linux-64 (check zst)                       Checked  0.1s
# [+] 0.0s
# bioconda/noarch (check zst) ━━━━━━━━━━━━╸━━━━   0.0 B @  ??.?MB/s Checking  0.0sbioconda/noarch (check zst)                         Checked  0.0s
# [+] 0.0s
# conda-forge/linux-64 ━━━━━━━━━━━━━━╸━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━  60.7kB /  47.0MB @   1.2MB/s  0.1s
# conda-forge/noarch   ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/linux-64    ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/noarch      ━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━   1.5MB /  47.0MB @   9.9MB/s  0.2s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━━━━━━ 205.3kB /  22.2MB @   1.3MB/s  0.2s
# bioconda/linux-64    ━━━━━━━━━━━━━━━━━━━━━━━ 188.2kB /   5.3MB @   1.2MB/s  0.2s
# bioconda/noarch      ━╸━━━━━━━━━━━━━━━━━━━━━ 617.5kB /   5.0MB @   3.8MB/s  0.2s[+] 0.3s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━━━━━━━━   4.2MB /  47.0MB @  15.9MB/s  0.3s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━━━━━━━   2.8MB /  22.2MB @  10.5MB/s  0.3s
# bioconda/linux-64    ━━━━━━━━━━╸━━━━━━━━━━━━   2.8MB /   5.3MB @  10.3MB/s  0.3s
# bioconda/noarch      ━━━━━━━━━━━━━╸━━━━━━━━━   3.2MB /   5.0MB @  12.0MB/s  0.3sbioconda/noarch                                      5.0MB @  15.1MB/s  0.3s
# bioconda/linux-64                                    5.3MB @  15.0MB/s  0.4s
# [+] 0.4s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━━━━━━   8.0MB /  47.0MB @  21.7MB/s  0.4s
# conda-forge/noarch   ━━━━━╸━━━━━━━━━━━━━━━━━   6.7MB /  22.2MB @  18.0MB/s  0.4s[+] 0.5s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━━━  14.2MB /  47.0MB @  30.0MB/s  0.5s
# conda-forge/noarch   ━━━━━━━━━━━━╸━━━━━━━━━━  12.9MB /  22.2MB @  27.1MB/s  0.5s[+] 0.6s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  20.4MB /  47.0MB @  35.3MB/s  0.6s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━━━╸━━━━  19.0MB /  22.2MB @  32.9MB/s  0.6sconda-forge/noarch                                  22.2MB @  35.1MB/s  0.7s
# [+] 0.7s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━  26.5MB /  47.0MB @  39.1MB/s  0.7s[+] 0.8s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━╸━━━━━  37.7MB /  47.0MB @  48.3MB/s  0.8s[+] 0.9s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━  47.0MB @  54.4MB/s Downloaded  0.9sconda-forge/linux-64                               @  54.4MB/s  0.9s
#
# Pinned packages:
#   - python 3.12.*
#
#
# Transaction
#
#   Prefix: /home/ubuntu/miniforge3
#
#   Updating specs:
#
#    - bioconda::harmonypy
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                Version  Build                 Channel           Size
# ────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────
#
#   + joblib                 1.5.2  pyhd8ed1ab_0          conda-forge      225kB
#   + threadpoolctl          3.6.0  pyhecae5ae_0          conda-forge       24kB
#   + pytz                  2025.2  pyhd8ed1ab_0          conda-forge      189kB
#   + python-tzdata         2025.2  pyhd8ed1ab_0          conda-forge      144kB
#   + six                   1.17.0  pyhe01879c_1          conda-forge     Cached
#   + python-dateutil  2.9.0.post0  pyhe01879c_2          conda-forge     Cached
#   + libgfortran5          14.2.0  hf1ad2bd_2            conda-forge        1MB
#   + libgfortran           14.2.0  h69a702a_2            conda-forge       54kB
#   + libopenblas           0.3.29  pthreads_h94d23a6_0   conda-forge        6MB
#   + libblas                3.9.0  31_h59b9bed_openblas  conda-forge       17kB
#   + libcblas               3.9.0  31_he106b2a_openblas  conda-forge       17kB
#   + liblapack              3.9.0  31_h7ac8fdf_openblas  conda-forge       17kB
#   + numpy                  2.3.3  py312h33ff503_0       conda-forge        9MB
#   + scipy                 1.16.0  py312hf734454_0       conda-forge       17MB
#   + pandas                 2.3.2  py312hf79963d_0       conda-forge       15MB
#   + scikit-learn           1.7.2  py312h4f0b9e3_0       conda-forge       10MB
#   + harmonypy             0.0.10  pyhdfd78af_0          bioconda          30kB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2024.12.14  hbcca054_0            conda-forge     Cached
#   + ca-certificates     2025.8.3  hbd8a1cb_0            conda-forge     Cached
#   - certifi           2024.12.14  pyhd8ed1ab_0          conda-forge     Cached
#   + certifi             2025.8.3  pyhd8ed1ab_0          conda-forge      159kB
#   - openssl                3.4.0  h7b32b05_1            conda-forge     Cached
#   + openssl                3.5.3  h26f9b46_0            conda-forge        3MB
#
#   Summary:
#
#   Install: 17 packages
#   Upgrade: 3 packages
#
#   Total download: 62MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (2) ━━━━━━━━━━━━━━━━━━━━━━━   0.0 B certifi                    0.0s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0s[+] 0.1s
# Downloading  (5) ━━━━━━━━━━━━━━━━━━━━━━━  14.1kB certifi                    0.1s
# Extracting       ━━━━━━━━━━━━━━━━━━━━━━━       0                            0.0sthreadpoolctl                                       23.9kB @ 231.2kB/s  0.1s
# python-tzdata                                      144.2kB @   1.1MB/s  0.1s
# pytz                                               189.0kB @   1.2MB/s  0.2s
# joblib                                             224.7kB @   1.3MB/s  0.2s
# certifi                                            158.7kB @ 850.0kB/s  0.2s
# [+] 0.2s
# Downloading  (5) ━━━━━━━━╸━━━━━━━━━━━━━━ 740.4kB libgfortran5               0.2s
# Extracting   (4) ╸━━━━━╸━━━━━━━━━━━━━━━━       1 certifi                    0.0sliblapack                                           16.8kB @  81.3kB/s  0.1s
# libgfortran5                                         1.5MB @   5.8MB/s  0.1s
# libcblas                                            16.8kB @  63.0kB/s  0.1s
# libopenblas                                          5.9MB @  20.5MB/s  0.2s
# [+] 0.3s
# Downloading  (5) ━━╸━━━━━━━━━╸━━━━━━━━━━  10.5MB harmonypy                  0.3s
# Extracting   (3) ━━━━━━━╸━━━━╸━━━━━━━━━━       6 libcblas                   0.1sopenssl                                              3.1MB @   9.8MB/s  0.1s
# libblas                                             16.9kB @  50.0kB/s  0.1s
# harmonypy                                           30.0kB @  88.9kB/s  0.0s
# libgfortran                                         53.7kB @ 136.9kB/s  0.1s
# [+] 0.4s
# Downloading  (4) ━━━━━━━━╸━━━━━━━━━━━━━━  25.5MB numpy                      0.4s
# Extracting   (5) ━━━━━━━━━╸━━━━━━━╸━━━━━       8 harmonypy                  0.2sscikit-learn                                         9.7MB @  22.7MB/s  0.2s
# pandas                                              15.1MB @  34.9MB/s  0.3s
# numpy                                                8.8MB @  18.7MB/s  0.1s
# [+] 0.5s
# Downloading  (1) ━━━━━━━━━━━━━━━━━━━╸━━━  54.9MB scipy                      0.5s
# Extracting   (3) ━━━━━━━━━━━━━━━━╸━━━━╸━      13 numpy                      0.3sscipy                                               16.8MB @  31.1MB/s  0.2s
# [+] 0.6s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  61.8MB                            0.6s
# Extracting   (4) ━━━━━━━━━━━━━━━━╸━━━━━━      13 numpy                      0.4s[+] 0.7s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  61.8MB                            0.6s
# Extracting   (4) ━━━━━━━━━━━━━━━━╸━━━━━━      13 numpy                      0.5s[+] 0.8s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  61.8MB                            0.6s
# Extracting   (2) ━━━━━━━━━━━━━━━━━━━╸━━━      15 pandas                     0.6s[+] 0.9s
# Downloading      ━━━━━━━━━━━━━━━━━━━━━━━  61.8MB                            0.6s
# Extracting   (1) ━━━━━━━━━━━━━━━━━━━━╸━━      16 pandas                     0.7s
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
adata = integration_harmony(
    adata,
    batch_key="slide",
    save_path=save_path / "plots",
    logger=logger,  ################
)
# Out:
# 2025-09-17 10:09:10,435 [INFO]: Integration: Run Harmony
# 2025-09-17 10:09:10,853 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2025-09-17 10:09:57,750 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2025-09-17 10:09:59,675 - harmonypy - INFO - Iteration 1 of 10
# 2025-09-17 10:12:56,241 - harmonypy - INFO - Iteration 2 of 10
# 2025-09-17 10:15:53,019 - harmonypy - INFO - Iteration 3 of 10
# 2025-09-17 10:18:49,596 - harmonypy - INFO - Iteration 4 of 10
# 2025-09-17 10:21:37,827 - harmonypy - INFO - Iteration 5 of 10
# 2025-09-17 10:22:31,845 - harmonypy - INFO - Iteration 6 of 10
# 2025-09-17 10:23:25,674 - harmonypy - INFO - Iteration 7 of 10
# 2025-09-17 10:24:19,556 - harmonypy - INFO - Iteration 8 of 10
# 2025-09-17 10:25:13,462 - harmonypy - INFO - Converged after 8 iterations
# 2025-09-17 10:25:13,527 [INFO]: Integration: Compute neighbors and UMAP

# %%
import logging
from os.path import join
from typing import Tuple

import matplotlib.pyplot as plt
import scanpy as sc
from anndata import AnnData
from matplotlib.path import Path


def _plot_integration_comparison(
    adata: AnnData,
    save_path: str,
    umap_key: str,
    batch_key: str,
    point_size_factor: int = 320000,
) -> None:
    """Helper function to plot before/after integration comparison."""

    fig, axes = plt.subplots(
        4, 2, figsize=(17, 22), gridspec_kw={"hspace": 0.01, "wspace": -0.54}
    )

    fig.text(0.40, 0.89, "Unintegrated", fontsize=16, ha="center")
    fig.text(
        0.62,
        0.89,
        f"Integrated (Harmony{f'; by {batch_key}' if batch_key else ''})",
        fontsize=16,
        ha="center",
    )

    plot_configs = [
        ("sample", "Sample"),
        ("slide", "Slide"),
        ("condition", "Condition"),
        ("cell_type_mmc_raw_revised", "Cell Type"),
    ]

    for i, (color_key, label) in enumerate(plot_configs):
        # Unintegrated
        sc.pl.embedding(
            adata,
            basis=umap_key.replace("_harmony", ""),
            color=color_key,
            show=False,
            ax=axes[i, 0],
            size=point_size_factor / adata.shape[0],
            legend_loc=None,
            title="",
        )

        # Integrated
        sc.pl.embedding(
            adata,
            basis=umap_key,
            color=color_key,
            show=False,
            ax=axes[i, 1],
            size=point_size_factor / adata.shape[0],
            legend_loc="right margin",
            title="",
        )

        axes[i, 0].text(
            -0.05,
            0.5,
            label,
            transform=axes[i, 0].transAxes,
            fontsize=14,
            rotation=90,
            va="center",
            ha="center",
        )

    for ax in axes.ravel():
        ax.set_aspect("equal", adjustable="box")
        ax.set_xlabel("")
        ax.set_ylabel("")

    plt.savefig(
        join(save_path, "UMAP_integrated_harmony2.png"), dpi=150, bbox_inches="tight"
    )
    plt.close()

# %%
_plot_integration_comparison(
    adata,
    save_path=save_path / "plots",
    umap_key="X_umap_harmony_20_50",
    batch_key="slide",
    point_size_factor=200000,
)

# %% [markdown]
# # tbc here
# - add plotting code above to script

# %%
# Save result
logger.info("Saving integrated object...")
if "fov" not in adata.obs.columns:
    adata.obs["fov"] = ""
adata.obs["fov"] = adata.obs["fov"].astype(str)
output_path = save_path / "adatas"
output_path.mkdir(parents=True, exist_ok=True)
adata.write(output_path / "adata_integrated.h5ad.gz", compression="gzip")
logger.info("Done.")
# Out:
# 2025-09-17 10:58:27,720 [INFO]: Saving integrated object...
# 2025-09-17 11:00:46,394 [INFO]: Done.

# %%
# %%time
logger.info("Loading data...")
adata = sc.read_h5ad(save_path / "adatas" / "adata_integrated.h5ad.gz")
# Out:
# 2025-09-04 11:44:15,699 [INFO]: Loading data...
# CPU times: user 35.6 s, sys: 4.15 s, total: 39.8 s
# Wall time: 42.9 s

# %%
save_path
# Out:
# PosixPath('/dss/dssfs03/pn52re/pn52re-dss-0001/cellseg-benchmark/analysis/foxf2/Cellpose_1_nuclei_model')

# %%
adata.obs.drop(columns=["spt_region"], inplace=True, errors="ignore")
